# %%
from keras.datasets import cifar10
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.optimizers import SGD, Adam, RMSprop
import matplotlib.pyplot as plt

# CIFAR_10 is a set of 60K images 32x32 pixels on 3 channels
IMG_CHANNELS = 3
IMG_ROWS = 32
IMG_COLS = 32

# constants
BATCH_SIZE = 128
NB_EPOCH = 20
NB_CLASSES = 10
VERBOSE = 1
VALIDATION_SPLIT = 0.2
OPTIM = RMSprop()

# load dataset
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
print('X_train shape: ', X_train.shape)
print(X_train.shape[0], ' train samples')
print(X_test.shape[0], ' test samples')

# convert to catagorical 
Y_train = np_utils.to_categorical(y_train, NB_CLASSES)
Y_test = np_utils.to_categorical(y_test, NB_CLASSES)

# float and normalization
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

# network
model = Sequential()
model.add(Conv2D(32, (3, 3), padding = 'same',
                input_shape=(IMG_ROWS, IMG_COLS, IMG_CHANNELS)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# network with 512 units and ReLU activation
model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(NB_CLASSES))
model.add(Activation('softmax'))
model.summary()

# train
model.compile(loss='categorical_crossentropy', optimizer=OPTIM,
             metrics=['accuracy'])
model.fit(X_train, Y_train, batch_size = BATCH_SIZE,
          epochs=NB_EPOCH, validation_split=VALIDATION_SPLIT,
          verbose=VERBOSE)
score = model.evaluate(X_test, Y_test,
                      batch_size=BATCH_SIZE, verbose=VERBOSE)
print("Test score: ", score[0])
print('Test accuracy: ', score[1])

# Save model
model_json = model.to_json()
open('cifar10_architecture.json', 'w').write(model_json)
# Save weights
model.save_weights('cifar10_weights.h5', overwrite=True)

# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# X_train shape:  (50000, 32, 32, 3)
# 50000  train samples
# 10000  test samples
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 32, 32, 32)        896
#
#  activation_12 (Activation)  (None, 32, 32, 32)        0
#
#  max_pooling2d_4 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  dropout_7 (Dropout)         (None, 16, 16, 32)        0
#
#  flatten_3 (Flatten)         (None, 8192)              0
#
#  dense_6 (Dense)             (None, 512)               4194816
#
#  activation_13 (Activation)  (None, 512)               0
#
#  dropout_8 (Dropout)         (None, 512)               0
#
#  dense_7 (Dense)             (None, 10)                5130
#
#  activation_14 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 4,200,842
# Trainable params: 4,200,842
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 313/313 [==============================] - 27s 83ms/step - loss: 1.7572 - accuracy: 0.3786 - val_loss: 1.4251 - val_accuracy: 0.5030
# Epoch 2/20
# 313/313 [==============================] - 21s 68ms/step - loss: 1.3883 - accuracy: 0.5096 - val_loss: 1.3224 - val_accuracy: 0.5254
# Epoch 3/20
# 313/313 [==============================] - 28s 89ms/step - loss: 1.2534 - accuracy: 0.5574 - val_loss: 1.1936 - val_accuracy: 0.5940
# Epoch 4/20
# 313/313 [==============================] - 31s 98ms/step - loss: 1.1676 - accuracy: 0.5879 - val_loss: 1.1764 - val_accuracy: 0.5906
# Epoch 5/20
# 313/313 [==============================] - 29s 92ms/step - loss: 1.0914 - accuracy: 0.6184 - val_loss: 1.1235 - val_accuracy: 0.6133
# Epoch 6/20
# 313/313 [==============================] - 32s 103ms/step - loss: 1.0383 - accuracy: 0.6340 - val_loss: 1.1365 - val_accuracy: 0.6037
# Epoch 7/20
# 313/313 [==============================] - 31s 100ms/step - loss: 0.9897 - accuracy: 0.6555 - val_loss: 1.0988 - val_accuracy: 0.6118
# Epoch 8/20
# 313/313 [==============================] - 29s 92ms/step - loss: 0.9433 - accuracy: 0.6691 - val_loss: 1.0540 - val_accuracy: 0.6416
# Epoch 9/20
# 313/313 [==============================] - 29s 92ms/step - loss: 0.9033 - accuracy: 0.6850 - val_loss: 1.1013 - val_accuracy: 0.6374
# Epoch 10/20
# 313/313 [==============================] - 28s 90ms/step - loss: 0.8636 - accuracy: 0.6988 - val_loss: 1.1612 - val_accuracy: 0.6161
# Epoch 11/20
# 313/313 [==============================] - 34s 109ms/step - loss: 0.8330 - accuracy: 0.7125 - val_loss: 0.9994 - val_accuracy: 0.6592
# Epoch 12/20
# 313/313 [==============================] - 31s 99ms/step - loss: 0.8083 - accuracy: 0.7196 - val_loss: 0.9880 - val_accuracy: 0.6707
# Epoch 13/20
# 313/313 [==============================] - 31s 100ms/step - loss: 0.7721 - accuracy: 0.7324 - val_loss: 1.0619 - val_accuracy: 0.6518
# Epoch 14/20
# 313/313 [==============================] - 31s 98ms/step - loss: 0.7435 - accuracy: 0.7435 - val_loss: 1.0047 - val_accuracy: 0.6686
# Epoch 15/20
# 313/313 [==============================] - 29s 92ms/step - loss: 0.7158 - accuracy: 0.7556 - val_loss: 1.0276 - val_accuracy: 0.6703
# Epoch 16/20
# 313/313 [==============================] - 33s 107ms/step - loss: 0.6987 - accuracy: 0.7574 - val_loss: 0.9863 - val_accuracy: 0.6770
# Epoch 17/20
# 313/313 [==============================] - 28s 90ms/step - loss: 0.6698 - accuracy: 0.7673 - val_loss: 1.0017 - val_accuracy: 0.6762
# Epoch 18/20
# 313/313 [==============================] - 30s 97ms/step - loss: 0.6555 - accuracy: 0.7728 - val_loss: 1.1886 - val_accuracy: 0.6535
# Epoch 19/20
# 313/313 [==============================] - 31s 99ms/step - loss: 0.6410 - accuracy: 0.7774 - val_loss: 1.1601 - val_accuracy: 0.6560
# Epoch 20/20
# 313/313 [==============================] - 30s 96ms/step - loss: 0.6176 - accuracy: 0.7893 - val_loss: 1.0931 - val_accuracy: 0.6708
# 79/79 [==============================] - 3s 32ms/step - loss: 1.0983 - accuracy: 0.6601
# Test score:  1.0983045101165771
# Test accuracy:  0.660099983215332
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
from keras.datasets import cifar10
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.optimizers import SGD, Adam, RMSprop
import matplotlib.pyplot as plt

# CIFAR_10 is a set of 60K images 32x32 pixels on 3 channels
IMG_CHANNELS = 3
IMG_ROWS = 32
IMG_COLS = 32

# constants
BATCH_SIZE = 128
NB_EPOCH = 40
NB_CLASSES = 10
VERBOSE = 1
VALIDATION_SPLIT = 0.2
OPTIM = RMSprop()

# load dataset
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
print('X_train shape: ', X_train.shape)
print(X_train.shape[0], ' train samples')
print(X_test.shape[0], ' test samples')

# convert to catagorical 
Y_train = np_utils.to_categorical(y_train, NB_CLASSES)
Y_test = np_utils.to_categorical(y_test, NB_CLASSES)

# float and normalization
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

# network
model = Sequential()
model.add(Conv2D(32, (3, 3), padding = 'same',
                input_shape=(IMG_ROWS, IMG_COLS, IMG_CHANNELS)))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, 3, 3))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# network with 512 units and ReLU activation

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(NB_CLASSES))
model.add(Activation('softmax'))

model.summary()

# train
model.compile(loss='categorical_crossentropy', optimizer=OPTIM,
             metrics=['accuracy'])
model.fit(X_train, Y_train, batch_size = BATCH_SIZE,
          epochs=NB_EPOCH, validation_split=VALIDATION_SPLIT,
          verbose=VERBOSE)
score = model.evaluate(X_test, Y_test,
                      batch_size=BATCH_SIZE, verbose=VERBOSE)
print("Test score: ", score[0])
print('Test accuracy: ', score[1])

# Save model
model_json = model.to_json()
open('cifar10_architecture.json', 'w').write(model_json)
# Save weights
model.save_weights('cifar10_weights.h5', overwrite=True)

# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# X_train shape:  (50000, 32, 32, 3)
# 50000  train samples
# 10000  test samples
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 32, 32, 32)        896
#
#  activation_7 (Activation)   (None, 32, 32, 32)        0
#
#  conv2d_4 (Conv2D)           (None, 32, 32, 32)        9248
#
#  activation_8 (Activation)   (None, 32, 32, 32)        0
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 16, 16, 32)        0
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 64)        18496
#
#  activation_9 (Activation)   (None, 16, 16, 64)        0
#
#  conv2d_6 (Conv2D)           (None, 5, 5, 64)          36928
#
#  activation_10 (Activation)  (None, 5, 5, 64)          0
#
#  max_pooling2d_4 (MaxPooling  (None, 2, 2, 64)         0
#  2D)
#
#  dropout_6 (Dropout)         (None, 2, 2, 64)          0
#
#  flatten_2 (Flatten)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 512)               131584
#
#  activation_11 (Activation)  (None, 512)               0
#
#  dropout_7 (Dropout)         (None, 512)               0
#
#  dense_5 (Dense)             (None, 10)                5130
#
#  activation_12 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 202,282
# Trainable params: 202,282
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 313/313 [==============================] - 50s 157ms/step - loss: 1.9619 - accuracy: 0.2719 - val_loss: 1.7463 - val_accuracy: 0.3683
# Epoch 2/40
# 313/313 [==============================] - 50s 158ms/step - loss: 1.6496 - accuracy: 0.3947 - val_loss: 1.4980 - val_accuracy: 0.4634
# Epoch 3/40
# 313/313 [==============================] - 40s 129ms/step - loss: 1.4830 - accuracy: 0.4573 - val_loss: 1.3680 - val_accuracy: 0.5076
# Epoch 4/40
# 313/313 [==============================] - 39s 125ms/step - loss: 1.3741 - accuracy: 0.5027 - val_loss: 1.3978 - val_accuracy: 0.4990
# Epoch 5/40
# 313/313 [==============================] - 44s 139ms/step - loss: 1.2907 - accuracy: 0.5362 - val_loss: 1.1462 - val_accuracy: 0.5892
# Epoch 6/40
# 313/313 [==============================] - 47s 150ms/step - loss: 1.2203 - accuracy: 0.5643 - val_loss: 1.1170 - val_accuracy: 0.6081
# Epoch 7/40
# 313/313 [==============================] - 40s 127ms/step - loss: 1.1722 - accuracy: 0.5840 - val_loss: 1.1196 - val_accuracy: 0.6029
# Epoch 8/40
# 313/313 [==============================] - 40s 127ms/step - loss: 1.1292 - accuracy: 0.5974 - val_loss: 1.0479 - val_accuracy: 0.6348
# Epoch 9/40
# 313/313 [==============================] - 41s 132ms/step - loss: 1.0796 - accuracy: 0.6180 - val_loss: 0.9832 - val_accuracy: 0.6508
# Epoch 10/40
# 313/313 [==============================] - 40s 128ms/step - loss: 1.0476 - accuracy: 0.6280 - val_loss: 1.0069 - val_accuracy: 0.6436
# Epoch 11/40
# 313/313 [==============================] - 40s 126ms/step - loss: 1.0242 - accuracy: 0.6386 - val_loss: 0.9587 - val_accuracy: 0.6598
# Epoch 12/40
# 313/313 [==============================] - 41s 132ms/step - loss: 0.9926 - accuracy: 0.6497 - val_loss: 1.0183 - val_accuracy: 0.6551
# Epoch 13/40
# 313/313 [==============================] - 41s 132ms/step - loss: 0.9702 - accuracy: 0.6563 - val_loss: 0.9501 - val_accuracy: 0.6708
# Epoch 14/40
# 313/313 [==============================] - 40s 128ms/step - loss: 0.9434 - accuracy: 0.6678 - val_loss: 0.9897 - val_accuracy: 0.6593
# Epoch 15/40
# 313/313 [==============================] - 42s 133ms/step - loss: 0.9304 - accuracy: 0.6703 - val_loss: 0.9646 - val_accuracy: 0.6606
# Epoch 16/40
# 313/313 [==============================] - 45s 143ms/step - loss: 0.9084 - accuracy: 0.6802 - val_loss: 0.8669 - val_accuracy: 0.6974
# Epoch 17/40
# 313/313 [==============================] - 44s 139ms/step - loss: 0.8976 - accuracy: 0.6874 - val_loss: 0.9037 - val_accuracy: 0.6854
# Epoch 18/40
# 313/313 [==============================] - 41s 130ms/step - loss: 0.8801 - accuracy: 0.6916 - val_loss: 0.8828 - val_accuracy: 0.7017
# Epoch 19/40
# 313/313 [==============================] - 48s 152ms/step - loss: 0.8615 - accuracy: 0.6980 - val_loss: 0.8482 - val_accuracy: 0.7053
# Epoch 20/40
# 313/313 [==============================] - 50s 160ms/step - loss: 0.8564 - accuracy: 0.7013 - val_loss: 1.0316 - val_accuracy: 0.6406
# Epoch 21/40
# 313/313 [==============================] - 46s 146ms/step - loss: 0.8408 - accuracy: 0.7072 - val_loss: 0.8655 - val_accuracy: 0.7052
# Epoch 22/40
# 313/313 [==============================] - 54s 174ms/step - loss: 0.8254 - accuracy: 0.7085 - val_loss: 0.8239 - val_accuracy: 0.7158
# Epoch 23/40
# 313/313 [==============================] - 52s 168ms/step - loss: 0.8152 - accuracy: 0.7134 - val_loss: 0.8268 - val_accuracy: 0.7199
# Epoch 24/40
# 313/313 [==============================] - 52s 168ms/step - loss: 0.8166 - accuracy: 0.7132 - val_loss: 0.8426 - val_accuracy: 0.7117
# Epoch 25/40
# 313/313 [==============================] - 53s 168ms/step - loss: 0.8081 - accuracy: 0.7172 - val_loss: 0.9214 - val_accuracy: 0.6858
# Epoch 26/40
# 313/313 [==============================] - 53s 170ms/step - loss: 0.7977 - accuracy: 0.7220 - val_loss: 0.9578 - val_accuracy: 0.6880
# Epoch 27/40
# 313/313 [==============================] - 55s 174ms/step - loss: 0.7899 - accuracy: 0.7203 - val_loss: 0.8348 - val_accuracy: 0.7196
# Epoch 28/40
# 313/313 [==============================] - 55s 175ms/step - loss: 0.7846 - accuracy: 0.7222 - val_loss: 0.8569 - val_accuracy: 0.7073
# Epoch 29/40
# 313/313 [==============================] - 53s 170ms/step - loss: 0.7769 - accuracy: 0.7270 - val_loss: 0.7971 - val_accuracy: 0.7334
# Epoch 30/40
# 313/313 [==============================] - 55s 175ms/step - loss: 0.7723 - accuracy: 0.7291 - val_loss: 0.9011 - val_accuracy: 0.7094
# Epoch 31/40
# 313/313 [==============================] - 54s 172ms/step - loss: 0.7601 - accuracy: 0.7332 - val_loss: 0.8805 - val_accuracy: 0.7045
# Epoch 32/40
# 313/313 [==============================] - 55s 177ms/step - loss: 0.7603 - accuracy: 0.7345 - val_loss: 0.8740 - val_accuracy: 0.7145
# Epoch 33/40
# 313/313 [==============================] - 52s 166ms/step - loss: 0.7596 - accuracy: 0.7347 - val_loss: 0.8950 - val_accuracy: 0.6933
# Epoch 34/40
# 313/313 [==============================] - 55s 176ms/step - loss: 0.7407 - accuracy: 0.7402 - val_loss: 0.8028 - val_accuracy: 0.7352
# Epoch 35/40
# 313/313 [==============================] - 53s 170ms/step - loss: 0.7465 - accuracy: 0.7393 - val_loss: 0.8009 - val_accuracy: 0.7292
# Epoch 36/40
# 313/313 [==============================] - 53s 168ms/step - loss: 0.7430 - accuracy: 0.7389 - val_loss: 0.8869 - val_accuracy: 0.7111
# Epoch 37/40
# 313/313 [==============================] - 51s 162ms/step - loss: 0.7386 - accuracy: 0.7418 - val_loss: 0.8483 - val_accuracy: 0.7219
# Epoch 38/40
# 313/313 [==============================] - 54s 172ms/step - loss: 0.7364 - accuracy: 0.7405 - val_loss: 0.8663 - val_accuracy: 0.7230
# Epoch 39/40
# 313/313 [==============================] - 53s 169ms/step - loss: 0.7345 - accuracy: 0.7471 - val_loss: 0.8466 - val_accuracy: 0.7220
# Epoch 40/40
# 313/313 [==============================] - 53s 168ms/step - loss: 0.7305 - accuracy: 0.7442 - val_loss: 0.9012 - val_accuracy: 0.7021
# 79/79 [==============================] - 4s 45ms/step - loss: 0.9151 - accuracy: 0.6980
# Test score:  0.9150885939598083
# Test accuracy:  0.6980000138282776

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.datasets import cifar10
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.optimizers import SGD, Adam, RMSprop
import matplotlib.pyplot as plt
import numpy as np
import scipy.misc

# CIFAR_10 is a set of 60K images 32x32 pixels on 3 channels
IMG_CHANNELS = 3
IMG_ROWS = 32
IMG_COLS = 32
NUM_TO_AUGMENT = 5

# constants
BATCH_SIZE = 128
NB_EPOCH = 40
NB_CLASSES = 10
VERBOSE = 1
VALIDATION_SPLIT = 0.2
OPTIM = RMSprop()

# load dataset
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
print('X_train shape: ', X_train.shape)
print(X_train.shape[0], ' train samples')
print(X_test.shape[0], ' test samples')

# Augment
print("Augmenting training set images...")
datagen = ImageDataGenerator(
        rotation_range=40,
        width_shift_range=0.2,
        height_shift_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest')
xtas, ytas = [], []
for i in range (X_train.shape[0]):
    num_aug = 0
    x = X_train[i] # (3, 32, 32)
    x = x.reshape((1,) + x.shape) # (1, 3, 32, 32)
    for x_aug in datagen.flow(x, batch_size = 1,
                             save_to_dir='preview',
                             save_prefix='cifar',
                             save_format='jpeg'):
        if num_aug >= NUM_TO_AUGMENT:
            break
        xtas.append(x_aug[0])
        num_aug += 1

# convert to catagorical 
Y_train = np_utils.to_categorical(y_train, NB_CLASSES)
Y_test = np_utils.to_categorical(y_test, NB_CLASSES)

# float and normalization
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

# network
model = Sequential()
model.add(Conv2D(32, (3, 3), padding = 'same',
                input_shape=(IMG_ROWS, IMG_COLS, IMG_CHANNELS)))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, 3, 3))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# network with 512 units and ReLU activation

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(NB_CLASSES))
model.add(Activation('softmax'))

model.summary()

# train



model.compile(loss='categorical_crossentropy', optimizer=OPTIM,
             metrics=['accuracy'])
model.fit(X_train, Y_train, batch_size = BATCH_SIZE,
          epochs=NB_EPOCH, validation_split=VALIDATION_SPLIT,
          verbose=VERBOSE)

history = model.fit(X_train, Y_train, batch_size=BATCH_SIZE,
    epochs=NB_EPOCH, validation_split=VALIDATION_SPLIT, 
    verbose=VERBOSE)

score = model.evaluate(X_test, Y_test,
                      batch_size=BATCH_SIZE, verbose=VERBOSE)



print("Test score: ", score[0])
print('Test accuracy: ', score[1])

# Save model
model_json = model.to_json()
open('cifar10_architecture.json', 'w').write(model_json)
# Save weights
model.save_weights('cifar10_weights.h5', overwrite=True)

# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# X_train shape:  (50000, 32, 32, 3)
# 50000  train samples
# 10000  test samples
# Augmenting training set images...
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  activation (Activation)     (None, 32, 32, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  activation_1 (Activation)   (None, 32, 32, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  dropout (Dropout)           (None, 16, 16, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        18496
#
#  activation_2 (Activation)   (None, 16, 16, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 5, 5, 64)          36928
#
#  activation_3 (Activation)   (None, 5, 5, 64)          0
#
#  max_pooling2d_1 (MaxPooling  (None, 2, 2, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 2, 2, 64)          0
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 512)               131584
#
#  activation_4 (Activation)   (None, 512)               0
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
#  activation_5 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 202,282
# Trainable params: 202,282
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 313/313 [==============================] - 54s 170ms/step - loss: 1.9509 - accuracy: 0.2771 - val_loss: 1.7466 - val_accuracy: 0.3680
# Epoch 2/40
# 313/313 [==============================] - 55s 176ms/step - loss: 1.6188 - accuracy: 0.4048 - val_loss: 1.4588 - val_accuracy: 0.4581
# Epoch 3/40
# 313/313 [==============================] - 56s 180ms/step - loss: 1.4712 - accuracy: 0.4652 - val_loss: 1.4295 - val_accuracy: 0.4719
# Epoch 4/40
# 313/313 [==============================] - 57s 183ms/step - loss: 1.3698 - accuracy: 0.5047 - val_loss: 1.3002 - val_accuracy: 0.5306
# Epoch 5/40
# 313/313 [==============================] - 57s 181ms/step - loss: 1.2953 - accuracy: 0.5335 - val_loss: 1.2392 - val_accuracy: 0.5563
# Epoch 6/40
# 313/313 [==============================] - 54s 173ms/step - loss: 1.2246 - accuracy: 0.5618 - val_loss: 1.1843 - val_accuracy: 0.5697
# Epoch 7/40
# 313/313 [==============================] - 58s 185ms/step - loss: 1.1766 - accuracy: 0.5776 - val_loss: 1.0690 - val_accuracy: 0.6212
# Epoch 8/40
# 313/313 [==============================] - 58s 184ms/step - loss: 1.1312 - accuracy: 0.5999 - val_loss: 1.1647 - val_accuracy: 0.5920
# Epoch 9/40
# 313/313 [==============================] - 55s 176ms/step - loss: 1.0880 - accuracy: 0.6137 - val_loss: 1.0438 - val_accuracy: 0.6225
# Epoch 10/40
# 313/313 [==============================] - 58s 187ms/step - loss: 1.0556 - accuracy: 0.6314 - val_loss: 0.9780 - val_accuracy: 0.6536
# Epoch 11/40
# 313/313 [==============================] - 54s 173ms/step - loss: 1.0169 - accuracy: 0.6424 - val_loss: 0.9337 - val_accuracy: 0.6672
# Epoch 12/40
# 313/313 [==============================] - 58s 185ms/step - loss: 0.9921 - accuracy: 0.6490 - val_loss: 0.9399 - val_accuracy: 0.6678
# Epoch 13/40
# 313/313 [==============================] - 59s 189ms/step - loss: 0.9699 - accuracy: 0.6570 - val_loss: 1.0252 - val_accuracy: 0.6396
# Epoch 14/40
# 313/313 [==============================] - 56s 180ms/step - loss: 0.9448 - accuracy: 0.6665 - val_loss: 0.9050 - val_accuracy: 0.6830
# Epoch 15/40
# 313/313 [==============================] - 54s 174ms/step - loss: 0.9288 - accuracy: 0.6763 - val_loss: 0.9182 - val_accuracy: 0.6859
# Epoch 16/40
# 313/313 [==============================] - 59s 188ms/step - loss: 0.9041 - accuracy: 0.6827 - val_loss: 0.8675 - val_accuracy: 0.6924
# Epoch 17/40
# 313/313 [==============================] - 57s 182ms/step - loss: 0.8883 - accuracy: 0.6866 - val_loss: 0.9922 - val_accuracy: 0.6631
# Epoch 18/40
# 313/313 [==============================] - 59s 188ms/step - loss: 0.8739 - accuracy: 0.6939 - val_loss: 0.8524 - val_accuracy: 0.7022
# Epoch 19/40
# 313/313 [==============================] - 56s 178ms/step - loss: 0.8619 - accuracy: 0.6977 - val_loss: 0.8632 - val_accuracy: 0.7057
# Epoch 20/40
# 313/313 [==============================] - 55s 174ms/step - loss: 0.8518 - accuracy: 0.7016 - val_loss: 0.8390 - val_accuracy: 0.7143
# Epoch 21/40
# 313/313 [==============================] - 58s 184ms/step - loss: 0.8349 - accuracy: 0.7089 - val_loss: 0.8954 - val_accuracy: 0.6938
# Epoch 22/40
# 313/313 [==============================] - 58s 184ms/step - loss: 0.8240 - accuracy: 0.7135 - val_loss: 0.8179 - val_accuracy: 0.7194
# Epoch 23/40
# 313/313 [==============================] - 61s 196ms/step - loss: 0.8203 - accuracy: 0.7146 - val_loss: 0.9219 - val_accuracy: 0.6820
# Epoch 24/40
# 313/313 [==============================] - 60s 191ms/step - loss: 0.8064 - accuracy: 0.7184 - val_loss: 0.8480 - val_accuracy: 0.7110
# Epoch 25/40
# 313/313 [==============================] - 60s 190ms/step - loss: 0.7936 - accuracy: 0.7247 - val_loss: 0.9791 - val_accuracy: 0.6791
# Epoch 26/40
# 313/313 [==============================] - 59s 187ms/step - loss: 0.7961 - accuracy: 0.7208 - val_loss: 0.8322 - val_accuracy: 0.7193
# Epoch 27/40
# 313/313 [==============================] - 59s 189ms/step - loss: 0.7869 - accuracy: 0.7235 - val_loss: 0.8633 - val_accuracy: 0.7028
# Epoch 28/40
# 313/313 [==============================] - 62s 199ms/step - loss: 0.7658 - accuracy: 0.7336 - val_loss: 0.8513 - val_accuracy: 0.7122
# Epoch 29/40
# 313/313 [==============================] - 59s 188ms/step - loss: 0.7628 - accuracy: 0.7348 - val_loss: 0.9223 - val_accuracy: 0.6980
# Epoch 30/40
# 313/313 [==============================] - 56s 178ms/step - loss: 0.7667 - accuracy: 0.7340 - val_loss: 0.7821 - val_accuracy: 0.7317
# Epoch 31/40
# 313/313 [==============================] - 60s 192ms/step - loss: 0.7547 - accuracy: 0.7369 - val_loss: 0.8104 - val_accuracy: 0.7272
# Epoch 32/40
# 313/313 [==============================] - 57s 183ms/step - loss: 0.7559 - accuracy: 0.7362 - val_loss: 0.8238 - val_accuracy: 0.7163
# Epoch 33/40
# 313/313 [==============================] - 57s 181ms/step - loss: 0.7426 - accuracy: 0.7416 - val_loss: 0.8891 - val_accuracy: 0.7024
# Epoch 34/40
# 313/313 [==============================] - 58s 184ms/step - loss: 0.7483 - accuracy: 0.7400 - val_loss: 1.0013 - val_accuracy: 0.6709
# Epoch 35/40
# 313/313 [==============================] - 57s 181ms/step - loss: 0.7406 - accuracy: 0.7413 - val_loss: 0.8197 - val_accuracy: 0.7235
# Epoch 36/40
# 313/313 [==============================] - 57s 182ms/step - loss: 0.7346 - accuracy: 0.7458 - val_loss: 0.8060 - val_accuracy: 0.7257
# Epoch 37/40
# 313/313 [==============================] - 59s 189ms/step - loss: 0.7327 - accuracy: 0.7466 - val_loss: 0.8779 - val_accuracy: 0.7120
# Epoch 38/40
# 313/313 [==============================] - 59s 189ms/step - loss: 0.7295 - accuracy: 0.7452 - val_loss: 0.8172 - val_accuracy: 0.7299
# Epoch 39/40
# 313/313 [==============================] - 55s 175ms/step - loss: 0.7272 - accuracy: 0.7455 - val_loss: 0.8033 - val_accuracy: 0.7247
# Epoch 40/40
# 313/313 [==============================] - 59s 188ms/step - loss: 0.7204 - accuracy: 0.7481 - val_loss: 0.7956 - val_accuracy: 0.7362
# Epoch 1/40
# 313/313 [==============================] - 57s 182ms/step - loss: 0.7230 - accuracy: 0.7473 - val_loss: 0.8749 - val_accuracy: 0.7034
# Epoch 2/40
# 313/313 [==============================] - 57s 182ms/step - loss: 0.7175 - accuracy: 0.7506 - val_loss: 0.8214 - val_accuracy: 0.7284
# Epoch 3/40
# 313/313 [==============================] - 56s 179ms/step - loss: 0.7211 - accuracy: 0.7500 - val_loss: 0.8023 - val_accuracy: 0.7306
# Epoch 4/40
# 313/313 [==============================] - 57s 183ms/step - loss: 0.7138 - accuracy: 0.7533 - val_loss: 0.8766 - val_accuracy: 0.7111
# Epoch 5/40
# 313/313 [==============================] - 57s 183ms/step - loss: 0.7157 - accuracy: 0.7533 - val_loss: 0.8121 - val_accuracy: 0.7296
# Epoch 6/40
# 313/313 [==============================] - 57s 181ms/step - loss: 0.7056 - accuracy: 0.7544 - val_loss: 0.8126 - val_accuracy: 0.7298
# Epoch 7/40
# 313/313 [==============================] - 54s 173ms/step - loss: 0.7062 - accuracy: 0.7573 - val_loss: 0.8290 - val_accuracy: 0.7289
# Epoch 8/40
# 313/313 [==============================] - 55s 174ms/step - loss: 0.7046 - accuracy: 0.7547 - val_loss: 0.8007 - val_accuracy: 0.7308
# Epoch 9/40
# 313/313 [==============================] - 56s 180ms/step - loss: 0.7093 - accuracy: 0.7561 - val_loss: 0.7931 - val_accuracy: 0.7351
# Epoch 10/40
# 313/313 [==============================] - 57s 182ms/step - loss: 0.7046 - accuracy: 0.7585 - val_loss: 0.8058 - val_accuracy: 0.7351
# Epoch 11/40
# 313/313 [==============================] - 57s 182ms/step - loss: 0.7027 - accuracy: 0.7574 - val_loss: 0.7951 - val_accuracy: 0.7399
# Epoch 12/40
# 313/313 [==============================] - 56s 180ms/step - loss: 0.6956 - accuracy: 0.7596 - val_loss: 0.8368 - val_accuracy: 0.7262
# Epoch 13/40
# 313/313 [==============================] - 60s 190ms/step - loss: 0.6964 - accuracy: 0.7601 - val_loss: 0.8568 - val_accuracy: 0.7185
# Epoch 14/40
# 313/313 [==============================] - 57s 181ms/step - loss: 0.7053 - accuracy: 0.7587 - val_loss: 0.8182 - val_accuracy: 0.7336
# Epoch 15/40
# 313/313 [==============================] - 54s 174ms/step - loss: 0.6980 - accuracy: 0.7613 - val_loss: 0.8570 - val_accuracy: 0.7227
# Epoch 16/40
# 313/313 [==============================] - 57s 181ms/step - loss: 0.6997 - accuracy: 0.7593 - val_loss: 0.8425 - val_accuracy: 0.7268
# Epoch 17/40
# 313/313 [==============================] - 56s 178ms/step - loss: 0.6986 - accuracy: 0.7601 - val_loss: 0.7922 - val_accuracy: 0.7390
# Epoch 18/40
# 313/313 [==============================] - 56s 180ms/step - loss: 0.7008 - accuracy: 0.7582 - val_loss: 0.8514 - val_accuracy: 0.7240
# Epoch 19/40
# 313/313 [==============================] - 55s 176ms/step - loss: 0.7022 - accuracy: 0.7601 - val_loss: 0.7999 - val_accuracy: 0.7341
# Epoch 20/40
# 313/313 [==============================] - 56s 178ms/step - loss: 0.7003 - accuracy: 0.7606 - val_loss: 0.7921 - val_accuracy: 0.7389
# Epoch 21/40
# 313/313 [==============================] - 56s 179ms/step - loss: 0.6971 - accuracy: 0.7606 - val_loss: 0.8623 - val_accuracy: 0.7297
# Epoch 22/40
# 313/313 [==============================] - 58s 184ms/step - loss: 0.6997 - accuracy: 0.7610 - val_loss: 0.8955 - val_accuracy: 0.7138
# Epoch 23/40
# 313/313 [==============================] - 54s 172ms/step - loss: 0.6985 - accuracy: 0.7619 - val_loss: 0.8643 - val_accuracy: 0.7251
# Epoch 24/40
# 313/313 [==============================] - 58s 184ms/step - loss: 0.7049 - accuracy: 0.7593 - val_loss: 0.8109 - val_accuracy: 0.7326
# Epoch 25/40
# 313/313 [==============================] - 55s 177ms/step - loss: 0.7080 - accuracy: 0.7596 - val_loss: 0.8304 - val_accuracy: 0.7262
# Epoch 26/40
# 313/313 [==============================] - 57s 181ms/step - loss: 0.7024 - accuracy: 0.7599 - val_loss: 0.8095 - val_accuracy: 0.7370
# Epoch 27/40
# 313/313 [==============================] - 56s 180ms/step - loss: 0.7082 - accuracy: 0.7590 - val_loss: 0.8219 - val_accuracy: 0.7198
# Epoch 28/40
# 313/313 [==============================] - 57s 182ms/step - loss: 0.7046 - accuracy: 0.7618 - val_loss: 0.8441 - val_accuracy: 0.7138
# Epoch 29/40
# 313/313 [==============================] - 55s 177ms/step - loss: 0.7040 - accuracy: 0.7599 - val_loss: 0.8063 - val_accuracy: 0.7358
# Epoch 30/40
# 313/313 [==============================] - 58s 185ms/step - loss: 0.7005 - accuracy: 0.7615 - val_loss: 0.8313 - val_accuracy: 0.7272
# Epoch 31/40
# 313/313 [==============================] - 57s 182ms/step - loss: 0.6956 - accuracy: 0.7652 - val_loss: 0.7985 - val_accuracy: 0.7365
# Epoch 32/40
# 313/313 [==============================] - 53s 171ms/step - loss: 0.7017 - accuracy: 0.7599 - val_loss: 0.8170 - val_accuracy: 0.7351
# Epoch 33/40
# 313/313 [==============================] - 58s 186ms/step - loss: 0.7033 - accuracy: 0.7624 - val_loss: 0.8094 - val_accuracy: 0.7329
# Epoch 34/40
# 313/313 [==============================] - 57s 182ms/step - loss: 0.7052 - accuracy: 0.7602 - val_loss: 0.8630 - val_accuracy: 0.7220
# Epoch 35/40
# 313/313 [==============================] - 56s 180ms/step - loss: 0.7072 - accuracy: 0.7581 - val_loss: 1.0152 - val_accuracy: 0.6958
# Epoch 36/40
# 313/313 [==============================] - 56s 179ms/step - loss: 0.7033 - accuracy: 0.7600 - val_loss: 0.8869 - val_accuracy: 0.7172
# Epoch 37/40
# 313/313 [==============================] - 55s 174ms/step - loss: 0.7077 - accuracy: 0.7584 - val_loss: 0.8425 - val_accuracy: 0.7304
# Epoch 38/40
# 313/313 [==============================] - 55s 177ms/step - loss: 0.7037 - accuracy: 0.7601 - val_loss: 0.8195 - val_accuracy: 0.7267
# Epoch 39/40
# 313/313 [==============================] - 56s 180ms/step - loss: 0.7098 - accuracy: 0.7576 - val_loss: 0.8705 - val_accuracy: 0.7095
# Epoch 40/40
# 313/313 [==============================] - 57s 183ms/step - loss: 0.7081 - accuracy: 0.7576 - val_loss: 0.8383 - val_accuracy: 0.7195
# 79/79 [==============================] - 3s 34ms/step - loss: 0.8560 - accuracy: 0.7125
# Test score:  0.856036901473999
# Test accuracy:  0.7124999761581421
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [1], in <cell line: 127>()
#     125 print(history.history.keys())
#     126 # summarize history for accuracy
# --> 127 plt.plot(history.history['acc'])
#     128 plt.plot(history.history['val_acc'])
#     129 plt.title('model accuracy')
#
# KeyError: 'acc'

# %%
import numpy as np
import scipy.misc
from keras.models import model_from_json
from keras.optimizers import SGD

# load model
model_architecture = 'cifar10_architecture.json'
model_weights = 'cifar10_weights.h5'
model = model_from_json(open(model_architecture).read())
model.load_weights(model_weights)

# load images
img_names = ['cat-standing.jpg', 'dog.jpg']
imgs = [np.transpose(scipy.misc.imresize(scipy.misc.imread(img_name),
                                        (32, 32)),
                    (1, 0, 2)).astype('float32')
       for img_name in img_names]
imgs = np.array(imgs) / 255
    
# Train
optim = SGD()
model.compile(loss='categorical_crossentropy', optimizer=optim,
    metrics=['accuracy'])
 
# Predict
predictions = model.predict_classes(imgs)
print(predictions)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [6], in <cell line: 14>()
#      12 # load images
#      13 img_names = ['cat-standing.jpg', 'dog.jpg']
# ---> 14 imgs = [np.transpose(scipy.misc.imresize(scipy.misc.imread(img_name),
#      15                                         (32, 32)),
#      16                     (1, 0, 2)).astype('float32')
#      17        for img_name in img_names]
#      18 imgs = np.array(imgs) / 255
#      20 # Train
#
# Input In [6], in <listcomp>(.0)
#      12 # load images
#      13 img_names = ['cat-standing.jpg', 'dog.jpg']
# ---> 14 imgs = [np.transpose(scipy.misc.imresize(scipy.misc.imread(img_name),
#      15                                         (32, 32)),
#      16                     (1, 0, 2)).astype('float32')
#      17        for img_name in img_names]
#      18 imgs = np.array(imgs) / 255
#      20 # Train
#
# AttributeError: module 'scipy.misc' has no attribute 'imresize'

# %%
"NOTE: The latest version of scipy no longer supports the above commands"

# %%
"""
Assignment 3-2 : Identifying CIFAR-10 Images

When considering what is ethical to 'train' a computer to recognize, human faces and their environment
come to mind. Currently, there are a variety of consumer level products that use the technology
to discern different people from one another, and this data is used for various purposes. However,
is there cause for concern when these products are brought into our homes and allowed full access
to our private life?

One such product (as mentioned in a previous discussion post) is Meta's latest foray into the 
hardware market, the "Portal". Designed as a device that allows users to video chat with others
or present to an audience from the comfort of your home, the Portal employs various technologies
that allow it to recognize a person and follow them around the space that they are in. The details
of how it does this are intricate, and as such this write-up will focus on the ethical concerns that
users may or may not have when considering this technology.

Various technology hubs have reported extensively on the Portal, and while the general consensus
is that it is 'safe' and private, there are some concerns that have come to light regarding
the data that the Portal has access to and transfers to Meta (the parent company of Facebook). Most
alarmingly, Facebook has told various publications that it does in fact use Portal to collect various
usage data in order to serve ads to users on other platforms (Terekhov). While this data collection is minimal
(for now) it is still something that users should consider when purchasing a Portal.

Digging deeper into the Portal and the technology within it's silicon, it can be assumed that the
device is able to discern between different people within the home. If this is the case, the device
could potentially be used to identify particular people and link them to various online profiles.
Likewise, the technology must discern human faces from backgrounds, meaning that it must know what
objects are in a persons home by simply viewing it. This implication leads one to believe that the
device could potentially be used to build particular types of data profiles about users. Shopping
habits, exercise schedules, even overall wealth could be devised based on background information
in users' videos. While this is very much an extreme scenario, and Facebook has assured users that
it does not collect any such data (Bates), the idea that it could potentially happen is worrisome. 

In general, any technology that can distinguish a person's face from another person's face is
somewhat of cause for concern because such things are very rarely used for non-nefarious purposes.
A person's face is the the main part of their uniqueness and their identification. Software trained
to recognize peoples faces can be used to track them in real time like some TV shows would have us
believe already takes place. They could be used to push very focused ad campaigns towards us and
even help to shape our opinions about things like politics or ethics simply based on the demographic
information found in our face. 

On the other end of the spectrum, if the trained algorithm was to be
innacurate in discerning certain faces from others, this could result in other issues like 
accidental profiling or fugitive reporting in the event a crime was committed. The algorithm above
only has an accuracy rating of 71% when viewing images of different animals. Human faces are far more
complex and some can look very similar. Consider a suspect in a crime on the run, and facial 
recognition software attempting to track them reports any other person it spots that looks
70% like the wanted individual. This would result in a lot of unecessary arrests and wasted time
for the police, while the suspect could still pose a danger to the community. 

China has taken a step similar to the one just mentioned above, in the form of a "social credit" system. 
In China, facial tracking software is used to conduct surveilance on citizens, making note of anything
they do that is deemed "untrustworthy" in any way. While it is not directly reported that AI and facial
recognition are deployed, nor is facial tracking the only way citizens are surveiled, China makes
a variety of services that require a person's face to be registered in order to use them. With many
citizens faces in a database, it is relatively easy for China to track each person's movements and 
thus, their actions. These actions are then compiled to create a social credit profile that is then used
to determine benefits that citizens have access to. Gaining employment can be much easier with a high
social credit score, low scores can make employment harder to procure. This is absolutely an ethics issue,
but unfortunately China is a communist society in which citizens have very little rights. 

While facial recognizing software does have it's uses and has the potential to make some aspects
of our daily lives easier, in this authors opinion the potential for negative uses far outweigh 
these benefits. Only in very regulated circumstances with total transparency should this technology
be considered for use.

References

Bates, P. (2019, November 8). Can you trust facebook portal devices with your privacy? 
    MUO. Retrieved September 6, 2022, from 
    https://www.makeuseof.com/tag/trust-facebook-portal-privacy/ 
    
Donnelly, D. (2022, July 22). China Social Credit System explained - how it works [2022]. 
    Horizons. Retrieved September 13, 2022, from https://nhglobalpartners.com/china-
    social-credit-system-explained/ 
   
Terekhov, A. (2018, November 8). Facebook portal privacy issues continue as it admits 
    to collecting user data. Hotspot Shield VPN. Retrieved September 6, 2022, from 
    https://www.hotspotshield.com/blog/facebook-portal-privacy/ 

"""
