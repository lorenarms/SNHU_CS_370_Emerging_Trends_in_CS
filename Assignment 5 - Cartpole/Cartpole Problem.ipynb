# %% [markdown]
# ### Lawrence Artl
# #### CS370 22EW1
# #### Assignment 5 - Cartpol Problem with DQN
# #### September 24, 2022

# %% [markdown]
# # Module Five Assignment: Cartpole Problem
# Review the code in this notebook and in the score_logger.py file in the *scores* folder (directory). Once you have reviewed the code, return to this notebook and select **Cell** and then **Run All** from the menu bar to run this code. The code takes several minutes to run.

# %% [markdown]
# ### Standard Run
# (Below)
# Solved in 134 runs, 234 total runs.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95                # calculat the future discounted reward
LEARNING_RATE = 0.001       # how much the nn learns each iteraction
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20             # how much memory is used to learn
  
EXPLORATION_MAX = 1.0       # rate at which agent randomly decides actions
                            # as opposed to predictions
EXPLORATION_MIN = 0.1      # explore at least this amount
EXPLORATION_DECAY = 0.995   # decrease number of explorations over time as
                            # agent ability improves
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 16
# Scores: (min: 16, avg: 16, max: 16)
#
# Run: 2, exploration: 0.9275689688183278, score: 19
# Scores: (min: 16, avg: 17.5, max: 19)
#
# Run: 3, exploration: 0.7822236754458713, score: 35
# Scores: (min: 16, avg: 23.333333333333332, max: 35)
#
# Run: 4, exploration: 0.7076077347272662, score: 21
# Scores: (min: 16, avg: 22.75, max: 35)
#
# Run: 5, exploration: 0.6629680834613705, score: 14
# Scores: (min: 14, avg: 21, max: 35)
#
# Run: 6, exploration: 0.6337242817644086, score: 10
# Scores: (min: 10, avg: 19.166666666666668, max: 35)
#
# Run: 7, exploration: 0.5535075230322891, score: 28
# Scores: (min: 10, avg: 20.428571428571427, max: 35)
#
# Run: 8, exploration: 0.5159963842937159, score: 15
# Scores: (min: 10, avg: 19.75, max: 35)
#
# Run: 9, exploration: 0.49571413690105054, score: 9
# Scores: (min: 9, avg: 18.555555555555557, max: 35)
#
# Run: 10, exploration: 0.46912134373457726, score: 12
# Scores: (min: 9, avg: 17.9, max: 35)
#
# Run: 11, exploration: 0.43952667968844233, score: 14
# Scores: (min: 9, avg: 17.545454545454547, max: 35)
#
# Run: 12, exploration: 0.4180382776616619, score: 11
# Scores: (min: 9, avg: 17, max: 35)
#
# Run: 13, exploration: 0.3819719776053028, score: 19
# Scores: (min: 9, avg: 17.153846153846153, max: 35)
#
# Run: 14, exploration: 0.3614809303671764, score: 12
# Scores: (min: 9, avg: 16.785714285714285, max: 35)
#
# Run: 15, exploration: 0.33362200135903064, score: 17
# Scores: (min: 9, avg: 16.8, max: 35)
#
# Run: 16, exploration: 0.3173112652388396, score: 11
# Scores: (min: 9, avg: 16.4375, max: 35)
#
# Run: 17, exploration: 0.2913921604631864, score: 18
# Scores: (min: 9, avg: 16.529411764705884, max: 35)
#
# Run: 18, exploration: 0.2799384215094006, score: 9
# Scores: (min: 9, avg: 16.11111111111111, max: 35)
#
# Run: 19, exploration: 0.26759021970270175, score: 10
# Scores: (min: 9, avg: 15.789473684210526, max: 35)
#
# Run: 20, exploration: 0.24450384299593592, score: 19
# Scores: (min: 9, avg: 15.95, max: 35)
#
# Run: 21, exploration: 0.2290792429684691, score: 14
# Scores: (min: 9, avg: 15.857142857142858, max: 35)
#
# Run: 22, exploration: 0.2167901907234072, score: 12
# Scores: (min: 9, avg: 15.681818181818182, max: 35)
#
# Run: 23, exploration: 0.20722748400265262, score: 10
# Scores: (min: 9, avg: 15.434782608695652, max: 35)
#
# Run: 24, exploration: 0.19513012515638165, score: 13
# Scores: (min: 9, avg: 15.333333333333334, max: 35)
#
# Run: 25, exploration: 0.1865228530605915, score: 10
# Scores: (min: 9, avg: 15.12, max: 35)
#
# Run: 26, exploration: 0.17919120740315364, score: 9
# Scores: (min: 9, avg: 14.884615384615385, max: 35)
#
# Run: 27, exploration: 0.1712870076899825, score: 10
# Scores: (min: 9, avg: 14.703703703703704, max: 35)
#
# Run: 28, exploration: 0.16373146555890544, score: 10
# Scores: (min: 9, avg: 14.535714285714286, max: 35)
#
# Run: 29, exploration: 0.15650920157696743, score: 10
# Scores: (min: 9, avg: 14.379310344827585, max: 35)
#
# Run: 30, exploration: 0.15035730121053842, score: 9
# Scores: (min: 9, avg: 14.2, max: 35)
#
# Run: 31, exploration: 0.14444721332374086, score: 9
# Scores: (min: 9, avg: 14.03225806451613, max: 35)
#
# Run: 32, exploration: 0.138769433003975, score: 9
# Scores: (min: 9, avg: 13.875, max: 35)
#
# Run: 33, exploration: 0.13264825480308728, score: 10
# Scores: (min: 9, avg: 13.757575757575758, max: 35)
#
# Run: 34, exploration: 0.12679708435358925, score: 10
# Scores: (min: 9, avg: 13.647058823529411, max: 35)
#
# Run: 35, exploration: 0.12120401149972035, score: 10
# Scores: (min: 9, avg: 13.542857142857143, max: 35)
#
# Run: 36, exploration: 0.11585765144771248, score: 10
# Scores: (min: 9, avg: 13.444444444444445, max: 35)
#
# Run: 37, exploration: 0.11019338598389174, score: 11
# Scores: (min: 9, avg: 13.378378378378379, max: 35)
#
# Run: 38, exploration: 0.10533270926593409, score: 10
# Scores: (min: 9, avg: 13.289473684210526, max: 35)
#
# Run: 39, exploration: 0.10018300685223579, score: 11
# Scores: (min: 9, avg: 13.23076923076923, max: 35)
#
# Run: 40, exploration: 0.1, score: 9
# Scores: (min: 9, avg: 13.125, max: 35)
#
# Run: 41, exploration: 0.1, score: 10
# Scores: (min: 9, avg: 13.048780487804878, max: 35)
#
# Run: 42, exploration: 0.1, score: 9
# Scores: (min: 9, avg: 12.952380952380953, max: 35)
#
# Run: 43, exploration: 0.1, score: 9
# Scores: (min: 9, avg: 12.86046511627907, max: 35)
#
# Run: 44, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 12.75, max: 35)
#
# Run: 45, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 12.666666666666666, max: 35)
#
# Run: 46, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 12.608695652173912, max: 35)
#
# Run: 47, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 12.53191489361702, max: 35)
#
# Run: 48, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 12.479166666666666, max: 35)
#
# Run: 49, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 12.428571428571429, max: 35)
#
# Run: 50, exploration: 0.1, score: 13
# Scores: (min: 8, avg: 12.44, max: 35)
#
# Run: 51, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 12.392156862745098, max: 35)
#
# Run: 52, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 12.346153846153847, max: 35)
#
# Run: 53, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 12.283018867924529, max: 35)
#
# Run: 54, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 12.222222222222221, max: 35)
#
# Run: 55, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 12.163636363636364, max: 35)
#
# Run: 56, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 12.125, max: 35)
#
# Run: 57, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 12.070175438596491, max: 35)
#
# Run: 58, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 12.03448275862069, max: 35)
#
# Run: 59, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 12, max: 35)
#
# Run: 60, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 11.983333333333333, max: 35)
#
# Run: 61, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 11.950819672131148, max: 35)
#
# Run: 62, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 11.903225806451612, max: 35)
#
# Run: 63, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 11.841269841269842, max: 35)
#
# Run: 64, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 11.796875, max: 35)
#
# Run: 65, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 11.76923076923077, max: 35)
#
# Run: 66, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 11.727272727272727, max: 35)
#
# Run: 67, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 11.686567164179104, max: 35)
#
# Run: 68, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 11.661764705882353, max: 35)
#
# Run: 69, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 11.63768115942029, max: 35)
#
# Run: 70, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 11.614285714285714, max: 35)
#
# Run: 71, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 11.591549295774648, max: 35)
#
# Run: 72, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 11.555555555555555, max: 35)
#
# Run: 73, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 11.547945205479452, max: 35)
#
# Run: 74, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 11.513513513513514, max: 35)
#
# Run: 75, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 11.48, max: 35)
#
# Run: 76, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 11.486842105263158, max: 35)
#
# Run: 77, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 11.493506493506494, max: 35)
#
# Run: 78, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 11.5, max: 35)
#
# Run: 79, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 11.468354430379748, max: 35)
#
# Run: 80, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 11.475, max: 35)
#
# Run: 81, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 11.444444444444445, max: 35)
#
# Run: 82, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 11.414634146341463, max: 35)
#
# Run: 83, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 11.397590361445783, max: 35)
#
# Run: 84, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 11.380952380952381, max: 35)
#
# Run: 85, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 11.364705882352942, max: 35)
#
# Run: 86, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 11.348837209302326, max: 35)
#
# Run: 87, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 11.32183908045977, max: 35)
#
# Run: 88, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 11.306818181818182, max: 35)
#
# Run: 89, exploration: 0.1, score: 15
# Scores: (min: 8, avg: 11.348314606741573, max: 35)
#
# Run: 90, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 11.333333333333334, max: 35)
# Run: 91, exploration: 0.1, score: 13
# Scores: (min: 8, avg: 11.351648351648352, max: 35)
#
# Run: 92, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 11.358695652173912, max: 35)
#
# Run: 93, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 11.365591397849462, max: 35)
#
# Run: 94, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 11.351063829787234, max: 35)
#
# Run: 95, exploration: 0.1, score: 13
# Scores: (min: 8, avg: 11.368421052631579, max: 35)
#
# Run: 96, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 11.354166666666666, max: 35)
#
# Run: 97, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 11.329896907216495, max: 35)
#
# Run: 98, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 11.316326530612244, max: 35)
#
# Run: 99, exploration: 0.1, score: 14
# Scores: (min: 8, avg: 11.343434343434344, max: 35)
#
# Run: 100, exploration: 0.1, score: 17
# Scores: (min: 8, avg: 11.4, max: 35)
#
# Run: 101, exploration: 0.1, score: 22
# Scores: (min: 8, avg: 11.46, max: 35)
#
# Run: 102, exploration: 0.1, score: 16
# Scores: (min: 8, avg: 11.43, max: 35)
#
# Run: 103, exploration: 0.1, score: 24
# Scores: (min: 8, avg: 11.32, max: 28)
#
# Run: 104, exploration: 0.1, score: 21
# Scores: (min: 8, avg: 11.32, max: 28)
#
# Run: 105, exploration: 0.1, score: 16
# Scores: (min: 8, avg: 11.34, max: 28)
#
# Run: 106, exploration: 0.1, score: 13
# Scores: (min: 8, avg: 11.37, max: 28)
#
# Run: 107, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 11.2, max: 24)
#
# Run: 108, exploration: 0.1, score: 29
# Scores: (min: 8, avg: 11.34, max: 29)
#
# Run: 109, exploration: 0.1, score: 58
# Scores: (min: 8, avg: 11.83, max: 58)
#
# Run: 110, exploration: 0.1, score: 19
# Scores: (min: 8, avg: 11.9, max: 58)
#
# Run: 111, exploration: 0.1, score: 23
# Scores: (min: 8, avg: 11.99, max: 58)
#
# Run: 112, exploration: 0.1, score: 14
# Scores: (min: 8, avg: 12.02, max: 58)
#
# Run: 113, exploration: 0.1, score: 27
# Scores: (min: 8, avg: 12.1, max: 58)
#
# Run: 114, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 12.09, max: 58)
#
# Run: 115, exploration: 0.1, score: 40
# Scores: (min: 8, avg: 12.32, max: 58)
#
# Run: 116, exploration: 0.1, score: 23
# Scores: (min: 8, avg: 12.44, max: 58)
#
# Run: 117, exploration: 0.1, score: 17
# Scores: (min: 8, avg: 12.43, max: 58)
#
# Run: 118, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 12.44, max: 58)
#
# Run: 119, exploration: 0.1, score: 16
# Scores: (min: 8, avg: 12.5, max: 58)
#
# Run: 120, exploration: 0.1, score: 16
# Scores: (min: 8, avg: 12.47, max: 58)
#
# Run: 121, exploration: 0.1, score: 16
# Scores: (min: 8, avg: 12.49, max: 58)
#
# Run: 122, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 12.47, max: 58)
#
# Run: 123, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 12.49, max: 58)
#
# Run: 124, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 12.48, max: 58)
#
# Run: 125, exploration: 0.1, score: 16
# Scores: (min: 8, avg: 12.54, max: 58)
#
# Run: 126, exploration: 0.1, score: 15
# Scores: (min: 8, avg: 12.6, max: 58)
#
# Run: 127, exploration: 0.1, score: 14
# Scores: (min: 8, avg: 12.64, max: 58)
#
# Run: 128, exploration: 0.1, score: 13
# Scores: (min: 8, avg: 12.67, max: 58)
#
# Run: 129, exploration: 0.1, score: 14
# Scores: (min: 8, avg: 12.71, max: 58)
#
# Run: 130, exploration: 0.1, score: 16
# Scores: (min: 8, avg: 12.78, max: 58)
#
# Run: 131, exploration: 0.1, score: 15
# Scores: (min: 8, avg: 12.84, max: 58)
#
# Run: 132, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 12.85, max: 58)
#
# Run: 133, exploration: 0.1, score: 16
# Scores: (min: 8, avg: 12.91, max: 58)
#
# Run: 134, exploration: 0.1, score: 13
# Scores: (min: 8, avg: 12.94, max: 58)
#
# Run: 135, exploration: 0.1, score: 21
# Scores: (min: 8, avg: 13.05, max: 58)
#
# Run: 136, exploration: 0.1, score: 30
# Scores: (min: 8, avg: 13.25, max: 58)
#
# Run: 137, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 13.24, max: 58)
#
# Run: 138, exploration: 0.1, score: 34
# Scores: (min: 8, avg: 13.48, max: 58)
#
# Run: 139, exploration: 0.1, score: 19
# Scores: (min: 8, avg: 13.56, max: 58)
#
# Run: 140, exploration: 0.1, score: 22
# Scores: (min: 8, avg: 13.69, max: 58)
#
# Run: 141, exploration: 0.1, score: 61
# Scores: (min: 8, avg: 14.2, max: 61)
#
# Run: 142, exploration: 0.1, score: 19
# Scores: (min: 8, avg: 14.3, max: 61)
#
# Run: 143, exploration: 0.1, score: 52
# Scores: (min: 8, avg: 14.73, max: 61)
#
# Run: 144, exploration: 0.1, score: 81
# Scores: (min: 8, avg: 15.46, max: 81)
#
# Run: 145, exploration: 0.1, score: 26
# Scores: (min: 8, avg: 15.63, max: 81)
#
# Run: 146, exploration: 0.1, score: 51
# Scores: (min: 8, avg: 16.04, max: 81)
#
# Run: 147, exploration: 0.1, score: 68
# Scores: (min: 8, avg: 16.63, max: 81)
#
# Run: 148, exploration: 0.1, score: 122
# Scores: (min: 8, avg: 17.75, max: 122)
#
# Run: 149, exploration: 0.1, score: 54
# Scores: (min: 8, avg: 18.19, max: 122)
#
# Run: 150, exploration: 0.1, score: 42
# Scores: (min: 8, avg: 18.48, max: 122)
#
# Run: 151, exploration: 0.1, score: 64
# Scores: (min: 8, avg: 19.02, max: 122)
#
# Run: 152, exploration: 0.1, score: 79
# Scores: (min: 8, avg: 19.71, max: 122)
#
# Run: 153, exploration: 0.1, score: 101
# Scores: (min: 8, avg: 20.63, max: 122)
#
# Run: 154, exploration: 0.1, score: 37
# Scores: (min: 8, avg: 20.91, max: 122)
#
# Run: 155, exploration: 0.1, score: 75
# Scores: (min: 8, avg: 21.57, max: 122)
#
# Run: 156, exploration: 0.1, score: 166
# Scores: (min: 8, avg: 23.13, max: 166)
#
# Run: 157, exploration: 0.1, score: 191
# Scores: (min: 8, avg: 24.95, max: 191)
#
# Run: 158, exploration: 0.1, score: 165
# Scores: (min: 8, avg: 26.5, max: 191)
#
# Run: 159, exploration: 0.1, score: 182
# Scores: (min: 8, avg: 28.22, max: 191)
#
# Run: 160, exploration: 0.1, score: 149
# Scores: (min: 8, avg: 29.6, max: 191)
#
# Run: 161, exploration: 0.1, score: 178
# Scores: (min: 8, avg: 31.28, max: 191)
#
# Run: 162, exploration: 0.1, score: 150
# Scores: (min: 8, avg: 32.69, max: 191)
#
# Run: 163, exploration: 0.1, score: 153
# Scores: (min: 9, avg: 34.14, max: 191)
#
# Run: 164, exploration: 0.1, score: 274
# Scores: (min: 9, avg: 36.79, max: 274)
#
# Run: 165, exploration: 0.1, score: 289
# Scores: (min: 9, avg: 39.58, max: 289)
#
# Run: 166, exploration: 0.1, score: 289
# Scores: (min: 9, avg: 42.38, max: 289)
#
# Run: 167, exploration: 0.1, score: 203
# Scores: (min: 9, avg: 44.32, max: 289)
#
# Run: 168, exploration: 0.1, score: 225
# Scores: (min: 9, avg: 46.47, max: 289)
#
# Run: 169, exploration: 0.1, score: 315
# Scores: (min: 9, avg: 49.52, max: 315)
#
# Run: 170, exploration: 0.1, score: 248
# Scores: (min: 9, avg: 51.9, max: 315)
#
# Run: 171, exploration: 0.1, score: 249
# Scores: (min: 9, avg: 54.29, max: 315)
#
# Run: 172, exploration: 0.1, score: 324
# Scores: (min: 9, avg: 57.44, max: 324)
#
# Run: 173, exploration: 0.1, score: 224
# Scores: (min: 9, avg: 59.57, max: 324)
#
# Run: 174, exploration: 0.1, score: 414
# Scores: (min: 9, avg: 63.62, max: 414)
#
# Run: 175, exploration: 0.1, score: 295
# Scores: (min: 9, avg: 66.48, max: 414)
#
# Run: 176, exploration: 0.1, score: 356
# Scores: (min: 9, avg: 69.92, max: 414)
#
# Run: 177, exploration: 0.1, score: 270
# Scores: (min: 9, avg: 72.5, max: 414)
#
# Run: 178, exploration: 0.1, score: 273
# Scores: (min: 9, avg: 75.11, max: 414)
#
# Run: 179, exploration: 0.1, score: 191
# Scores: (min: 9, avg: 76.93, max: 414)
#
# Run: 180, exploration: 0.1, score: 280
# Scores: (min: 9, avg: 79.61, max: 414)
#
# Run: 181, exploration: 0.1, score: 247
# Scores: (min: 9, avg: 81.99, max: 414)
#
# Run: 182, exploration: 0.1, score: 205
# Scores: (min: 9, avg: 83.95, max: 414)
#
# Run: 183, exploration: 0.1, score: 229
# Scores: (min: 9, avg: 86.14, max: 414)
#
# Run: 184, exploration: 0.1, score: 342
# Scores: (min: 9, avg: 89.46, max: 414)
#
# Run: 185, exploration: 0.1, score: 343
# Scores: (min: 9, avg: 92.79, max: 414)
#
# Run: 186, exploration: 0.1, score: 246
# Scores: (min: 9, avg: 95.15, max: 414)
#
# Run: 187, exploration: 0.1, score: 277
# Scores: (min: 9, avg: 97.83, max: 414)
#
# Run: 188, exploration: 0.1, score: 334
# Scores: (min: 9, avg: 101.07, max: 414)
#
# Run: 189, exploration: 0.1, score: 291
# Scores: (min: 9, avg: 103.83, max: 414)
#
# Run: 190, exploration: 0.1, score: 273
# Scores: (min: 9, avg: 106.46, max: 414)
#
# Run: 191, exploration: 0.1, score: 221
# Scores: (min: 9, avg: 108.54, max: 414)
#
# Run: 192, exploration: 0.1, score: 359
# Scores: (min: 9, avg: 112.01, max: 414)
#
# Run: 193, exploration: 0.1, score: 210
# Scores: (min: 9, avg: 113.99, max: 414)
#
# Run: 194, exploration: 0.1, score: 191
# Scores: (min: 9, avg: 115.8, max: 414)
# Run: 195, exploration: 0.1, score: 186
# Scores: (min: 9, avg: 117.53, max: 414)
#
# Run: 196, exploration: 0.1, score: 224
# Scores: (min: 9, avg: 119.67, max: 414)
#
# Run: 197, exploration: 0.1, score: 221
# Scores: (min: 10, avg: 121.79, max: 414)
#
# Run: 198, exploration: 0.1, score: 243
# Scores: (min: 10, avg: 124.12, max: 414)
#
# Run: 199, exploration: 0.1, score: 248
# Scores: (min: 10, avg: 126.46, max: 414)
#
# Run: 200, exploration: 0.1, score: 163
# Scores: (min: 10, avg: 127.92, max: 414)
#
# Run: 201, exploration: 0.1, score: 285
# Scores: (min: 10, avg: 130.55, max: 414)
#
# Run: 202, exploration: 0.1, score: 237
# Scores: (min: 10, avg: 132.76, max: 414)
#
# Run: 203, exploration: 0.1, score: 231
# Scores: (min: 10, avg: 134.83, max: 414)
#
# Run: 204, exploration: 0.1, score: 260
# Scores: (min: 10, avg: 137.22, max: 414)
#
# Run: 205, exploration: 0.1, score: 195
# Scores: (min: 10, avg: 139.01, max: 414)
#
# Run: 206, exploration: 0.1, score: 308
# Scores: (min: 10, avg: 141.96, max: 414)
#
# Run: 207, exploration: 0.1, score: 295
# Scores: (min: 10, avg: 144.8, max: 414)
#
# Run: 208, exploration: 0.1, score: 187
# Scores: (min: 10, avg: 146.38, max: 414)
#
# Run: 209, exploration: 0.1, score: 250
# Scores: (min: 10, avg: 148.3, max: 414)
#
# Run: 210, exploration: 0.1, score: 204
# Scores: (min: 10, avg: 150.15, max: 414)
#
# Run: 211, exploration: 0.1, score: 259
# Scores: (min: 10, avg: 152.51, max: 414)
#
# Run: 212, exploration: 0.1, score: 358
# Scores: (min: 10, avg: 155.95, max: 414)
#
# Run: 213, exploration: 0.1, score: 198
# Scores: (min: 10, avg: 157.66, max: 414)
#
# Run: 214, exploration: 0.1, score: 273
# Scores: (min: 10, avg: 160.28, max: 414)
#
# Run: 215, exploration: 0.1, score: 201
# Scores: (min: 10, avg: 161.89, max: 414)
#
# Run: 216, exploration: 0.1, score: 190
# Scores: (min: 10, avg: 163.56, max: 414)
#
# Run: 217, exploration: 0.1, score: 220
# Scores: (min: 10, avg: 165.59, max: 414)
#
# Run: 218, exploration: 0.1, score: 199
# Scores: (min: 10, avg: 167.48, max: 414)
#
# Run: 219, exploration: 0.1, score: 194
# Scores: (min: 10, avg: 169.26, max: 414)
#
# Run: 220, exploration: 0.1, score: 196
# Scores: (min: 10, avg: 171.06, max: 414)
#
# Run: 221, exploration: 0.1, score: 212
# Scores: (min: 10, avg: 173.02, max: 414)
#
# Run: 222, exploration: 0.1, score: 221
# Scores: (min: 10, avg: 175.13, max: 414)
#
# Run: 223, exploration: 0.1, score: 175
# Scores: (min: 10, avg: 176.76, max: 414)
#
# Run: 224, exploration: 0.1, score: 189
# Scores: (min: 10, avg: 178.53, max: 414)
#
# Run: 225, exploration: 0.1, score: 171
# Scores: (min: 10, avg: 180.08, max: 414)
#
# Run: 226, exploration: 0.1, score: 229
# Scores: (min: 10, avg: 182.22, max: 414)
#
# Run: 227, exploration: 0.1, score: 141
# Scores: (min: 10, avg: 183.49, max: 414)
#
# Run: 228, exploration: 0.1, score: 141
# Scores: (min: 10, avg: 184.77, max: 414)
#
# Run: 229, exploration: 0.1, score: 266
# Scores: (min: 10, avg: 187.29, max: 414)
#
# Run: 230, exploration: 0.1, score: 208
# Scores: (min: 10, avg: 189.21, max: 414)
#
# Run: 231, exploration: 0.1, score: 180
# Scores: (min: 10, avg: 190.86, max: 414)
#
# Run: 232, exploration: 0.1, score: 170
# Scores: (min: 10, avg: 192.46, max: 414)
#
# Run: 233, exploration: 0.1, score: 256
# Scores: (min: 10, avg: 194.86, max: 414)
#
# Run: 234, exploration: 0.1, score: 183
# Scores: (min: 10, avg: 196.56, max: 414)
#
# Solved in 134 runs, 234 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-1-a4d31b12e33b> in cartpole()
#      86             if terminal:
#      87                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 88                 score_logger.add_score(step, run)
#      89                 break
#      90             dqn_solver.experience_replay()
#
# U:\Artl - Notebooks\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# ### Modified Run 1
# In this run we changed the `LEARNING RATE = 0.001` to `0.01`and saw a significant increase in runs. A keyboard interupt was used to keep the file short, but in some tests the Run count reached over 700! In reaching for an average score of **195**, one can see how this block-run would easily reach 1000 or more Runs.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95                # calculat the future discounted reward
LEARNING_RATE = 0.01        # how much the nn learns each iteraction
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20             # how much memory is used to learn
  
EXPLORATION_MAX = 1.0       # rate at which agent randomly decides actions
                            # as opposed to predictions
EXPLORATION_MIN = 0.1      # explore at least this amount
EXPLORATION_DECAY = 0.995   # decrease number of explorations over time as
                            # agent ability improves
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 12
# Scores: (min: 12, avg: 12, max: 12)
#
# Run: 2, exploration: 0.9322301194154049, score: 22
# Scores: (min: 12, avg: 17, max: 22)
#
# Run: 3, exploration: 0.8690529955452602, score: 15
# Scores: (min: 12, avg: 16.333333333333332, max: 22)
#
# Run: 4, exploration: 0.8224322824348486, score: 12
# Scores: (min: 12, avg: 15.25, max: 22)
#
# Run: 5, exploration: 0.6900935609921609, score: 36
# Scores: (min: 12, avg: 19.4, max: 36)
#
# Run: 6, exploration: 0.6337242817644086, score: 18
# Scores: (min: 12, avg: 19.166666666666668, max: 36)
#
# Run: 7, exploration: 0.5848838636585911, score: 17
# Scores: (min: 12, avg: 18.857142857142858, max: 36)
#
# Run: 8, exploration: 0.5618938591163328, score: 9
# Scores: (min: 9, avg: 17.625, max: 36)
#
# Run: 9, exploration: 0.531750826943791, score: 12
# Scores: (min: 9, avg: 17, max: 36)
#
# Run: 10, exploration: 0.5082950737585841, score: 10
# Scores: (min: 9, avg: 16.3, max: 36)
#
# Run: 11, exploration: 0.47862223409330756, score: 13
# Scores: (min: 9, avg: 16, max: 36)
#
# Run: 12, exploration: 0.4529463432347434, score: 12
# Scores: (min: 9, avg: 15.666666666666666, max: 36)
#
# Run: 13, exploration: 0.4286478463299511, score: 12
# Scores: (min: 9, avg: 15.384615384615385, max: 36)
#
# Run: 14, exploration: 0.4016064652978155, score: 14
# Scores: (min: 9, avg: 15.285714285714286, max: 36)
#
# Run: 15, exploration: 0.3743896431025813, score: 15
# Scores: (min: 9, avg: 15.266666666666667, max: 36)
#
# Run: 16, exploration: 0.3507711574848344, score: 14
# Scores: (min: 9, avg: 15.1875, max: 36)
#
# Run: 17, exploration: 0.33698341088258443, score: 9
# Scores: (min: 9, avg: 14.823529411764707, max: 36)
#
# Run: 18, exploration: 0.3125753549412418, score: 16
# Scores: (min: 9, avg: 14.88888888888889, max: 36)
#
# Run: 19, exploration: 0.2943280830920294, score: 13
# Scores: (min: 9, avg: 14.789473684210526, max: 36)
#
# Run: 20, exploration: 0.27714603575484437, score: 13
# Scores: (min: 9, avg: 14.7, max: 36)
#
# Run: 21, exploration: 0.2662522686041882, score: 9
# Scores: (min: 9, avg: 14.428571428571429, max: 36)
#
# Run: 22, exploration: 0.2519690537792925, score: 12
# Scores: (min: 9, avg: 14.318181818181818, max: 36)
#
# Run: 23, exploration: 0.2384520680152932, score: 12
# Scores: (min: 9, avg: 14.217391304347826, max: 36)
#
# Run: 24, exploration: 0.22679417751985861, score: 11
# Scores: (min: 9, avg: 14.083333333333334, max: 36)
#
# Run: 25, exploration: 0.21570623976979014, score: 11
# Scores: (min: 9, avg: 13.96, max: 36)
#
# Run: 26, exploration: 0.20619134658263935, score: 10
# Scores: (min: 9, avg: 13.807692307692308, max: 36)
#
# Run: 27, exploration: 0.19513012515638165, score: 12
# Scores: (min: 9, avg: 13.74074074074074, max: 36)
#
# Run: 28, exploration: 0.1846622876013121, score: 12
# Scores: (min: 9, avg: 13.678571428571429, max: 36)
#
# Run: 29, exploration: 0.17388222158237718, score: 13
# Scores: (min: 9, avg: 13.655172413793103, max: 36)
#
# Run: 30, exploration: 0.16291280823111093, score: 14
# Scores: (min: 9, avg: 13.666666666666666, max: 36)
#
# Run: 31, exploration: 0.1346580429260134, score: 39
# Scores: (min: 9, avg: 14.483870967741936, max: 39)
#
# Run: 32, exploration: 0.1242800989098765, score: 17
# Scores: (min: 9, avg: 14.5625, max: 39)
#
# Run: 33, exploration: 0.1135578192100607, score: 19
# Scores: (min: 9, avg: 14.696969696969697, max: 39)
#
# Run: 34, exploration: 0.1, score: 31
# Scores: (min: 9, avg: 15.176470588235293, max: 39)
#
# Run: 35, exploration: 0.1, score: 20
# Scores: (min: 9, avg: 15.314285714285715, max: 39)
#
# Run: 36, exploration: 0.1, score: 26
# Scores: (min: 9, avg: 15.61111111111111, max: 39)
#
# Run: 37, exploration: 0.1, score: 13
# Scores: (min: 9, avg: 15.54054054054054, max: 39)
#
# Run: 38, exploration: 0.1, score: 23
# Scores: (min: 9, avg: 15.736842105263158, max: 39)
#
# Run: 39, exploration: 0.1, score: 12
# Scores: (min: 9, avg: 15.64102564102564, max: 39)
#
# Run: 40, exploration: 0.1, score: 40
# Scores: (min: 9, avg: 16.25, max: 40)
#
# Run: 41, exploration: 0.1, score: 20
# Scores: (min: 9, avg: 16.341463414634145, max: 40)
#
# Run: 42, exploration: 0.1, score: 15
# Scores: (min: 9, avg: 16.30952380952381, max: 40)
#
# Run: 43, exploration: 0.1, score: 9
# Scores: (min: 9, avg: 16.13953488372093, max: 40)
#
# Run: 44, exploration: 0.1, score: 26
# Scores: (min: 9, avg: 16.363636363636363, max: 40)
#
# Run: 45, exploration: 0.1, score: 17
# Scores: (min: 9, avg: 16.377777777777776, max: 40)
#
# Run: 46, exploration: 0.1, score: 20
# Scores: (min: 9, avg: 16.456521739130434, max: 40)
#
# Run: 47, exploration: 0.1, score: 23
# Scores: (min: 9, avg: 16.595744680851062, max: 40)
#
# Run: 48, exploration: 0.1, score: 40
# Scores: (min: 9, avg: 17.083333333333332, max: 40)
#
# Run: 49, exploration: 0.1, score: 37
# Scores: (min: 9, avg: 17.489795918367346, max: 40)
#
# Run: 50, exploration: 0.1, score: 11
# Scores: (min: 9, avg: 17.36, max: 40)
#
# Run: 51, exploration: 0.1, score: 13
# Scores: (min: 9, avg: 17.274509803921568, max: 40)
#
# Run: 52, exploration: 0.1, score: 14
# Scores: (min: 9, avg: 17.21153846153846, max: 40)
#
# Run: 53, exploration: 0.1, score: 10
# Scores: (min: 9, avg: 17.07547169811321, max: 40)
#
# Run: 54, exploration: 0.1, score: 9
# Scores: (min: 9, avg: 16.925925925925927, max: 40)
#
# Run: 55, exploration: 0.1, score: 12
# Scores: (min: 9, avg: 16.836363636363636, max: 40)
#
# Run: 56, exploration: 0.1, score: 11
# Scores: (min: 9, avg: 16.732142857142858, max: 40)
#
# Run: 57, exploration: 0.1, score: 13
# Scores: (min: 9, avg: 16.666666666666668, max: 40)
#
# Run: 58, exploration: 0.1, score: 22
# Scores: (min: 9, avg: 16.75862068965517, max: 40)
#
# Run: 59, exploration: 0.1, score: 21
# Scores: (min: 9, avg: 16.83050847457627, max: 40)
#
# Run: 60, exploration: 0.1, score: 13
# Scores: (min: 9, avg: 16.766666666666666, max: 40)
#
# Run: 61, exploration: 0.1, score: 21
# Scores: (min: 9, avg: 16.83606557377049, max: 40)
#
# Run: 62, exploration: 0.1, score: 13
# Scores: (min: 9, avg: 16.774193548387096, max: 40)
#
# Run: 63, exploration: 0.1, score: 20
# Scores: (min: 9, avg: 16.825396825396826, max: 40)
#
# Run: 64, exploration: 0.1, score: 19
# Scores: (min: 9, avg: 16.859375, max: 40)
#
# Run: 65, exploration: 0.1, score: 21
# Scores: (min: 9, avg: 16.923076923076923, max: 40)
#
# Run: 66, exploration: 0.1, score: 38
# Scores: (min: 9, avg: 17.242424242424242, max: 40)
#
# Run: 67, exploration: 0.1, score: 48
# Scores: (min: 9, avg: 17.70149253731343, max: 48)
#
# Run: 68, exploration: 0.1, score: 21
# Scores: (min: 9, avg: 17.75, max: 48)
#
# Run: 69, exploration: 0.1, score: 39
# Scores: (min: 9, avg: 18.057971014492754, max: 48)
#
# Run: 70, exploration: 0.1, score: 20
# Scores: (min: 9, avg: 18.085714285714285, max: 48)
#
# Run: 71, exploration: 0.1, score: 23
# Scores: (min: 9, avg: 18.154929577464788, max: 48)
#
# Run: 72, exploration: 0.1, score: 10
# Scores: (min: 9, avg: 18.041666666666668, max: 48)
#
# Run: 73, exploration: 0.1, score: 17
# Scores: (min: 9, avg: 18.027397260273972, max: 48)
#
# Run: 74, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 17.89189189189189, max: 48)
#
# Run: 75, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 17.786666666666665, max: 48)
#
# Run: 76, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 17.710526315789473, max: 48)
#
# Run: 77, exploration: 0.1, score: 19
# Scores: (min: 8, avg: 17.727272727272727, max: 48)
#
# Run: 78, exploration: 0.1, score: 35
# Scores: (min: 8, avg: 17.94871794871795, max: 48)
#
# Run: 79, exploration: 0.1, score: 30
# Scores: (min: 8, avg: 18.10126582278481, max: 48)
#
# Run: 80, exploration: 0.1, score: 62
# Scores: (min: 8, avg: 18.65, max: 62)
#
# Run: 81, exploration: 0.1, score: 97
# Scores: (min: 8, avg: 19.617283950617285, max: 97)
#
# Run: 82, exploration: 0.1, score: 93
# Scores: (min: 8, avg: 20.51219512195122, max: 97)
#
# Run: 83, exploration: 0.1, score: 56
# Scores: (min: 8, avg: 20.93975903614458, max: 97)
#
# Run: 84, exploration: 0.1, score: 48
# Scores: (min: 8, avg: 21.261904761904763, max: 97)
#
# Run: 85, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 21.11764705882353, max: 97)
#
# Run: 86, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 20.988372093023255, max: 97)
#
# Run: 87, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 20.839080459770116, max: 97)
#
# Run: 88, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 20.727272727272727, max: 97)
#
# Run: 89, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 20.584269662921347, max: 97)
#
# Run: 90, exploration: 0.1, score: 13
# Scores: (min: 8, avg: 20.5, max: 97)
# Run: 91, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 20.395604395604394, max: 97)
#
# Run: 92, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 20.293478260869566, max: 97)
#
# Run: 93, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 20.182795698924732, max: 97)
#
# Run: 94, exploration: 0.1, score: 14
# Scores: (min: 8, avg: 20.117021276595743, max: 97)
#
# Run: 95, exploration: 0.1, score: 40
# Scores: (min: 8, avg: 20.326315789473686, max: 97)
#
# Run: 96, exploration: 0.1, score: 29
# Scores: (min: 8, avg: 20.416666666666668, max: 97)
#
# Run: 97, exploration: 0.1, score: 27
# Scores: (min: 8, avg: 20.484536082474225, max: 97)
#
# Run: 98, exploration: 0.1, score: 66
# Scores: (min: 8, avg: 20.948979591836736, max: 97)
#
# Run: 99, exploration: 0.1, score: 32
# Scores: (min: 8, avg: 21.060606060606062, max: 97)
#
# Run: 100, exploration: 0.1, score: 25
# Scores: (min: 8, avg: 21.1, max: 97)
#
# Run: 101, exploration: 0.1, score: 41
# Scores: (min: 8, avg: 21.39, max: 97)
#
# Run: 102, exploration: 0.1, score: 29
# Scores: (min: 8, avg: 21.46, max: 97)
#
# Run: 103, exploration: 0.1, score: 34
# Scores: (min: 8, avg: 21.65, max: 97)
#
# Run: 104, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 21.62, max: 97)
#
# Run: 105, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 21.36, max: 97)
#
# Run: 106, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 21.27, max: 97)
#
# Run: 107, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 21.19, max: 97)
#
# Run: 108, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 21.19, max: 97)
#
# Run: 109, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 21.16, max: 97)
#
# Run: 110, exploration: 0.1, score: 69
# Scores: (min: 8, avg: 21.75, max: 97)
#
# Run: 111, exploration: 0.1, score: 51
# Scores: (min: 8, avg: 22.13, max: 97)
#
# Run: 112, exploration: 0.1, score: 37
# Scores: (min: 8, avg: 22.38, max: 97)
#
# Run: 113, exploration: 0.1, score: 56
# Scores: (min: 8, avg: 22.82, max: 97)
#
# Run: 114, exploration: 0.1, score: 31
# Scores: (min: 8, avg: 22.99, max: 97)
#
# Run: 115, exploration: 0.1, score: 55
# Scores: (min: 8, avg: 23.39, max: 97)
#
# Run: 116, exploration: 0.1, score: 110
# Scores: (min: 8, avg: 24.35, max: 110)
#
# Run: 117, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 24.36, max: 110)
#
# Run: 118, exploration: 0.1, score: 32
# Scores: (min: 8, avg: 24.52, max: 110)
#
# Run: 119, exploration: 0.1, score: 66
# Scores: (min: 8, avg: 25.05, max: 110)
#
# Run: 120, exploration: 0.1, score: 136
# Scores: (min: 8, avg: 26.28, max: 136)
#
# Run: 121, exploration: 0.1, score: 71
# Scores: (min: 8, avg: 26.9, max: 136)
#
# Run: 122, exploration: 0.1, score: 32
# Scores: (min: 8, avg: 27.1, max: 136)
#
# Run: 123, exploration: 0.1, score: 33
# Scores: (min: 8, avg: 27.31, max: 136)
#
# Run: 124, exploration: 0.1, score: 41
# Scores: (min: 8, avg: 27.61, max: 136)
#
# Run: 125, exploration: 0.1, score: 82
# Scores: (min: 8, avg: 28.32, max: 136)
#
# Run: 126, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 28.31, max: 136)
#
# Run: 127, exploration: 0.1, score: 55
# Scores: (min: 8, avg: 28.74, max: 136)
#
# Run: 128, exploration: 0.1, score: 27
# Scores: (min: 8, avg: 28.89, max: 136)
#
# Run: 129, exploration: 0.1, score: 31
# Scores: (min: 8, avg: 29.07, max: 136)
#
# Run: 130, exploration: 0.1, score: 199
# Scores: (min: 8, avg: 30.92, max: 199)
#
# Run: 131, exploration: 0.1, score: 61
# Scores: (min: 8, avg: 31.14, max: 199)
#
# Run: 132, exploration: 0.1, score: 325
# Scores: (min: 8, avg: 34.22, max: 325)
#
# Run: 133, exploration: 0.1, score: 66
# Scores: (min: 8, avg: 34.69, max: 325)
#
# Run: 134, exploration: 0.1, score: 131
# Scores: (min: 8, avg: 35.69, max: 325)
#
# Run: 135, exploration: 0.1, score: 188
# Scores: (min: 8, avg: 37.37, max: 325)
#
# Run: 136, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 37.2, max: 325)
#
# Run: 137, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 37.16, max: 325)
#
# Run: 138, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 37.02, max: 325)
#
# Run: 139, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 36.98, max: 325)
#
# Run: 140, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 36.67, max: 325)
#
# Run: 141, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 36.58, max: 325)
#
# Run: 142, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 36.53, max: 325)
#
# Run: 143, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 36.53, max: 325)
#
# Run: 144, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 36.38, max: 325)
#
# Run: 145, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 36.29, max: 325)
#
# Run: 146, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 36.18, max: 325)
#
# Run: 147, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 36.05, max: 325)
#
# Run: 148, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 35.74, max: 325)
#
# Run: 149, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 35.46, max: 325)
#
# Run: 150, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 35.44, max: 325)
#
# Run: 151, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 35.4, max: 325)
#
# Run: 152, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 35.36, max: 325)
#
# Run: 153, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 35.36, max: 325)
#
# Run: 154, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 35.36, max: 325)
#
# Run: 155, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 35.36, max: 325)
#
# Run: 156, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 35.35, max: 325)
#
# Run: 157, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 35.32, max: 325)
#
# Run: 158, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 35.2, max: 325)
#
# Run: 159, exploration: 0.1, score: 14
# Scores: (min: 8, avg: 35.13, max: 325)
#
# Run: 160, exploration: 0.1, score: 28
# Scores: (min: 8, avg: 35.28, max: 325)
#
# Run: 161, exploration: 0.1, score: 38
# Scores: (min: 8, avg: 35.45, max: 325)
#
# Run: 162, exploration: 0.1, score: 49
# Scores: (min: 8, avg: 35.81, max: 325)
#
# Run: 163, exploration: 0.1, score: 60
# Scores: (min: 8, avg: 36.21, max: 325)
#
# Run: 164, exploration: 0.1, score: 99
# Scores: (min: 8, avg: 37.01, max: 325)
#
# Run: 165, exploration: 0.1, score: 27
# Scores: (min: 8, avg: 37.07, max: 325)
#
# Run: 166, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 36.79, max: 325)
#
# Run: 167, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 36.39, max: 325)
#
# Run: 168, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 36.3, max: 325)
#
# Run: 169, exploration: 0.1, score: 35
# Scores: (min: 8, avg: 36.26, max: 325)
#
# Run: 170, exploration: 0.1, score: 61
# Scores: (min: 8, avg: 36.67, max: 325)
#
# Run: 171, exploration: 0.1, score: 22
# Scores: (min: 8, avg: 36.66, max: 325)
#
# Run: 172, exploration: 0.1, score: 25
# Scores: (min: 8, avg: 36.81, max: 325)
#
# Run: 173, exploration: 0.1, score: 36
# Scores: (min: 8, avg: 37, max: 325)
#
# Run: 174, exploration: 0.1, score: 30
# Scores: (min: 8, avg: 37.22, max: 325)
#
# Run: 175, exploration: 0.1, score: 33
# Scores: (min: 8, avg: 37.45, max: 325)
#
# Run: 176, exploration: 0.1, score: 105
# Scores: (min: 8, avg: 38.38, max: 325)
#
# Run: 177, exploration: 0.1, score: 16
# Scores: (min: 8, avg: 38.35, max: 325)
#
# Run: 178, exploration: 0.1, score: 71
# Scores: (min: 8, avg: 38.71, max: 325)
#
# Run: 179, exploration: 0.1, score: 76
# Scores: (min: 8, avg: 39.17, max: 325)
#
# Run: 180, exploration: 0.1, score: 19
# Scores: (min: 8, avg: 38.74, max: 325)
#
# Run: 181, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 37.87, max: 325)
#
# Run: 182, exploration: 0.1, score: 29
# Scores: (min: 8, avg: 37.23, max: 325)
#
# Run: 183, exploration: 0.1, score: 21
# Scores: (min: 8, avg: 36.88, max: 325)
#
# Run: 184, exploration: 0.1, score: 20
# Scores: (min: 8, avg: 36.6, max: 325)
#
# Run: 185, exploration: 0.1, score: 34
# Scores: (min: 8, avg: 36.85, max: 325)
#
# Run: 186, exploration: 0.1, score: 33
# Scores: (min: 8, avg: 37.08, max: 325)
#
# Run: 187, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 37.12, max: 325)
#
# Run: 188, exploration: 0.1, score: 33
# Scores: (min: 8, avg: 37.34, max: 325)
#
# Run: 189, exploration: 0.1, score: 27
# Scores: (min: 8, avg: 37.53, max: 325)
#
# Run: 190, exploration: 0.1, score: 29
# Scores: (min: 8, avg: 37.69, max: 325)
#
# Run: 191, exploration: 0.1, score: 67
# Scores: (min: 8, avg: 38.25, max: 325)
#
# Run: 192, exploration: 0.1, score: 59
# Scores: (min: 8, avg: 38.73, max: 325)
#
# Run: 193, exploration: 0.1, score: 39
# Scores: (min: 8, avg: 39.02, max: 325)
#
# Run: 194, exploration: 0.1, score: 22
# Scores: (min: 8, avg: 39.1, max: 325)
#
# Run: 195, exploration: 0.1, score: 92
# Scores: (min: 8, avg: 39.62, max: 325)
# Run: 196, exploration: 0.1, score: 14
# Scores: (min: 8, avg: 39.47, max: 325)
#
# Run: 197, exploration: 0.1, score: 74
# Scores: (min: 8, avg: 39.94, max: 325)
#
# Run: 198, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 39.4, max: 325)
#
# Run: 199, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 39.17, max: 325)
#
# Run: 200, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 39.02, max: 325)
#
# Run: 201, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 38.71, max: 325)
#
# Run: 202, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 38.53, max: 325)
#
# Run: 203, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 38.28, max: 325)
#
# Run: 204, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 38.28, max: 325)
#
# Run: 205, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 38.27, max: 325)
#
# Run: 206, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 38.27, max: 325)
#
# Run: 207, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 38.27, max: 325)
#
# Run: 208, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 38.28, max: 325)
#
# Run: 209, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 38.28, max: 325)
#
# Run: 210, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 37.7, max: 325)
#
# Run: 211, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 37.29, max: 325)
#
# Run: 212, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 37.02, max: 325)
#
# Run: 213, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 36.55, max: 325)
#
# Run: 214, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 36.32, max: 325)
#
# Run: 215, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 35.85, max: 325)
#
# Run: 216, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 34.86, max: 325)
#
# Run: 217, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 34.85, max: 325)
#
# Run: 218, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 34.63, max: 325)
#
# Run: 219, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 34.06, max: 325)
#
# Run: 220, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 32.79, max: 325)
#
# Run: 221, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 32.16, max: 325)
#
# Run: 222, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 31.93, max: 325)
#
# Run: 223, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 31.7, max: 325)
#
# Run: 224, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 31.39, max: 325)
#
# Run: 225, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 30.65, max: 325)
#
# Run: 226, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 30.66, max: 325)
#
# Run: 227, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 30.22, max: 325)
#
# Run: 228, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 30.04, max: 325)
#
# Run: 229, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 29.85, max: 325)
#
# Run: 230, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 27.96, max: 325)
#
# Run: 231, exploration: 0.1, score: 23
# Scores: (min: 8, avg: 27.58, max: 325)
#
# Run: 232, exploration: 0.1, score: 18
# Scores: (min: 8, avg: 24.51, max: 188)
#
# Run: 233, exploration: 0.1, score: 14
# Scores: (min: 8, avg: 23.99, max: 188)
#
# Run: 234, exploration: 0.1, score: 27
# Scores: (min: 8, avg: 22.95, max: 188)
#
# Run: 235, exploration: 0.1, score: 14
# Scores: (min: 8, avg: 21.21, max: 105)
#
# Run: 236, exploration: 0.1, score: 68
# Scores: (min: 8, avg: 21.8, max: 105)
#
# Run: 237, exploration: 0.1, score: 17
# Scores: (min: 8, avg: 21.88, max: 105)
#
# Run: 238, exploration: 0.1, score: 21
# Scores: (min: 8, avg: 22, max: 105)
#
# Run: 239, exploration: 0.1, score: 18
# Scores: (min: 8, avg: 22.1, max: 105)
#
# Run: 240, exploration: 0.1, score: 26
# Scores: (min: 8, avg: 22.27, max: 105)
#
# Run: 241, exploration: 0.1, score: 35
# Scores: (min: 8, avg: 22.51, max: 105)
#
# Run: 242, exploration: 0.1, score: 16
# Scores: (min: 8, avg: 22.57, max: 105)
#
# Run: 243, exploration: 0.1, score: 36
# Scores: (min: 8, avg: 22.84, max: 105)
#
# Run: 244, exploration: 0.1, score: 24
# Scores: (min: 8, avg: 22.97, max: 105)
#
# Run: 245, exploration: 0.1, score: 44
# Scores: (min: 8, avg: 23.33, max: 105)
#
# Run: 246, exploration: 0.1, score: 22
# Scores: (min: 8, avg: 23.46, max: 105)
#
# Run: 247, exploration: 0.1, score: 18
# Scores: (min: 8, avg: 23.54, max: 105)
#
# Run: 248, exploration: 0.1, score: 45
# Scores: (min: 8, avg: 23.9, max: 105)
#
# Run: 249, exploration: 0.1, score: 13
# Scores: (min: 8, avg: 23.94, max: 105)
#
# Run: 250, exploration: 0.1, score: 51
# Scores: (min: 8, avg: 24.36, max: 105)
#
# Run: 251, exploration: 0.1, score: 13
# Scores: (min: 8, avg: 24.4, max: 105)
#
# Run: 252, exploration: 0.1, score: 17
# Scores: (min: 8, avg: 24.47, max: 105)
#
# Run: 253, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 24.47, max: 105)
#
# Run: 254, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 24.5, max: 105)
#
# Run: 255, exploration: 0.1, score: 41
# Scores: (min: 8, avg: 24.79, max: 105)
#
# Run: 256, exploration: 0.1, score: 38
# Scores: (min: 8, avg: 25.07, max: 105)
#
# Run: 257, exploration: 0.1, score: 36
# Scores: (min: 8, avg: 25.33, max: 105)
#
# Run: 258, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 25.33, max: 105)
#
# Run: 259, exploration: 0.1, score: 14
# Scores: (min: 8, avg: 25.33, max: 105)
#
# Run: 260, exploration: 0.1, score: 68
# Scores: (min: 8, avg: 25.73, max: 105)
#
# Run: 261, exploration: 0.1, score: 93
# Scores: (min: 8, avg: 26.28, max: 105)
#
# Run: 262, exploration: 0.1, score: 93
# Scores: (min: 8, avg: 26.72, max: 105)
#
# Run: 263, exploration: 0.1, score: 101
# Scores: (min: 8, avg: 27.13, max: 105)
#
# Run: 264, exploration: 0.1, score: 78
# Scores: (min: 8, avg: 26.92, max: 105)
#
# Run: 265, exploration: 0.1, score: 88
# Scores: (min: 8, avg: 27.53, max: 105)
#
# Run: 266, exploration: 0.1, score: 40
# Scores: (min: 8, avg: 27.83, max: 105)
#
# Run: 267, exploration: 0.1, score: 34
# Scores: (min: 8, avg: 28.09, max: 105)
#
# Run: 268, exploration: 0.1, score: 96
# Scores: (min: 8, avg: 28.93, max: 105)
#
# Run: 269, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 28.7, max: 105)
#
# Run: 270, exploration: 0.1, score: 171
# Scores: (min: 8, avg: 29.8, max: 171)
#
# Run: 271, exploration: 0.1, score: 50
# Scores: (min: 8, avg: 30.08, max: 171)
#
# Run: 272, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 29.92, max: 171)
#
# Run: 273, exploration: 0.1, score: 13
# Scores: (min: 8, avg: 29.69, max: 171)
#
# Run: 274, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 29.47, max: 171)
#
# Run: 275, exploration: 0.1, score: 304
# Scores: (min: 8, avg: 32.18, max: 304)
#
# Run: 276, exploration: 0.1, score: 78
# Scores: (min: 8, avg: 31.91, max: 304)
#
# Run: 277, exploration: 0.1, score: 68
# Scores: (min: 8, avg: 32.43, max: 304)
#
# Run: 278, exploration: 0.1, score: 148
# Scores: (min: 8, avg: 33.2, max: 304)
#
# Run: 279, exploration: 0.1, score: 131
# Scores: (min: 8, avg: 33.75, max: 304)
#
# Run: 280, exploration: 0.1, score: 17
# Scores: (min: 8, avg: 33.73, max: 304)
#
# Run: 281, exploration: 0.1, score: 38
# Scores: (min: 8, avg: 34.01, max: 304)
#
# Run: 282, exploration: 0.1, score: 87
# Scores: (min: 8, avg: 34.59, max: 304)
#
# Run: 283, exploration: 0.1, score: 82
# Scores: (min: 8, avg: 35.2, max: 304)
#
# Run: 284, exploration: 0.1, score: 38
# Scores: (min: 8, avg: 35.38, max: 304)
#
# Run: 285, exploration: 0.1, score: 52
# Scores: (min: 8, avg: 35.56, max: 304)
#
# Run: 286, exploration: 0.1, score: 144
# Scores: (min: 8, avg: 36.67, max: 304)
#
# Run: 287, exploration: 0.1, score: 50
# Scores: (min: 8, avg: 37.05, max: 304)
#
# Run: 288, exploration: 0.1, score: 57
# Scores: (min: 8, avg: 37.29, max: 304)
#
# Run: 289, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 37.12, max: 304)
#
# Run: 290, exploration: 0.1, score: 13
# Scores: (min: 8, avg: 36.96, max: 304)
#
# Run: 291, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 36.39, max: 304)
#
# Run: 292, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 35.89, max: 304)
#
# Run: 293, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 35.59, max: 304)
#
# Run: 294, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 35.46, max: 304)
#
# Run: 295, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 34.63, max: 304)
#
# Run: 296, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 34.58, max: 304)
#
# Run: 297, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 33.94, max: 304)
#
# Run: 298, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 33.93, max: 304)
#
# Run: 299, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 33.95, max: 304)
#
# Run: 300, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 33.95, max: 304)
#
# Run: 301, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 33.94, max: 304)
# Run: 302, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 33.93, max: 304)
#
# Run: 303, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 33.94, max: 304)
#
# Run: 304, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 33.95, max: 304)
#
# Run: 305, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 33.94, max: 304)
#
# Run: 306, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 33.95, max: 304)
#
# Run: 307, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 33.95, max: 304)
#
# Run: 308, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 33.95, max: 304)
#
# Run: 309, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 33.97, max: 304)
#
# Run: 310, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 33.95, max: 304)
#
# Run: 311, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 33.94, max: 304)
#
# Run: 312, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 33.93, max: 304)
#
# Run: 313, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 33.96, max: 304)
#
# Run: 314, exploration: 0.1, score: 20
# Scores: (min: 8, avg: 34.08, max: 304)
#
# Run: 315, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 34.1, max: 304)
#
# Run: 316, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 34.08, max: 304)
#
# Run: 317, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 34.09, max: 304)
#
# Run: 318, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 34.11, max: 304)
#
# Run: 319, exploration: 0.1, score: 15
# Scores: (min: 8, avg: 34.17, max: 304)
#
# Run: 320, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 34.17, max: 304)
#
# Run: 321, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 34.18, max: 304)
#
# Run: 322, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 34.18, max: 304)
#
# Run: 323, exploration: 0.1, score: 13
# Scores: (min: 8, avg: 34.21, max: 304)
#
# Run: 324, exploration: 0.1, score: 15
# Scores: (min: 8, avg: 34.26, max: 304)
#
# Run: 325, exploration: 0.1, score: 56
# Scores: (min: 8, avg: 34.74, max: 304)
#
# Run: 326, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 34.74, max: 304)
#
# Run: 327, exploration: 0.1, score: 79
# Scores: (min: 8, avg: 35.42, max: 304)
#
# Run: 328, exploration: 0.1, score: 53
# Scores: (min: 8, avg: 35.86, max: 304)
#
# Run: 329, exploration: 0.1, score: 103
# Scores: (min: 8, avg: 36.77, max: 304)
#
# Run: 330, exploration: 0.1, score: 103
# Scores: (min: 8, avg: 37.7, max: 304)
#
# Run: 331, exploration: 0.1, score: 44
# Scores: (min: 8, avg: 37.91, max: 304)
#
# Run: 332, exploration: 0.1, score: 57
# Scores: (min: 8, avg: 38.3, max: 304)
#
# Run: 333, exploration: 0.1, score: 36
# Scores: (min: 8, avg: 38.52, max: 304)
#
# Run: 334, exploration: 0.1, score: 19
# Scores: (min: 8, avg: 38.44, max: 304)
#
# Run: 335, exploration: 0.1, score: 55
# Scores: (min: 8, avg: 38.85, max: 304)
#
# Run: 336, exploration: 0.1, score: 21
# Scores: (min: 8, avg: 38.38, max: 304)
#
# Run: 337, exploration: 0.1, score: 266
# Scores: (min: 8, avg: 40.87, max: 304)
#
# Run: 338, exploration: 0.1, score: 95
# Scores: (min: 8, avg: 41.61, max: 304)
#
# Run: 339, exploration: 0.1, score: 133
# Scores: (min: 8, avg: 42.76, max: 304)
#
# Run: 340, exploration: 0.1, score: 133
# Scores: (min: 8, avg: 43.83, max: 304)
#
# Run: 341, exploration: 0.1, score: 27
# Scores: (min: 8, avg: 43.75, max: 304)
#
# Run: 342, exploration: 0.1, score: 146
# Scores: (min: 8, avg: 45.05, max: 304)
#
# Run: 343, exploration: 0.1, score: 36
# Scores: (min: 8, avg: 45.05, max: 304)
#
# Run: 344, exploration: 0.1, score: 109
# Scores: (min: 8, avg: 45.9, max: 304)
#
# Run: 345, exploration: 0.1, score: 63
# Scores: (min: 8, avg: 46.09, max: 304)
#
# Run: 346, exploration: 0.1, score: 26
# Scores: (min: 8, avg: 46.13, max: 304)
#
# Run: 347, exploration: 0.1, score: 93
# Scores: (min: 8, avg: 46.88, max: 304)
#
# Run: 348, exploration: 0.1, score: 31
# Scores: (min: 8, avg: 46.74, max: 304)
#
# Run: 349, exploration: 0.1, score: 140
# Scores: (min: 8, avg: 48.01, max: 304)
#
# Run: 350, exploration: 0.1, score: 103
# Scores: (min: 8, avg: 48.53, max: 304)
#
# Run: 351, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 48.51, max: 304)
#
# Run: 352, exploration: 0.1, score: 107
# Scores: (min: 8, avg: 49.41, max: 304)
#
# Run: 353, exploration: 0.1, score: 156
# Scores: (min: 8, avg: 50.87, max: 304)
#
# Run: 354, exploration: 0.1, score: 173
# Scores: (min: 8, avg: 52.48, max: 304)
#
# Run: 355, exploration: 0.1, score: 19
# Scores: (min: 8, avg: 52.26, max: 304)
#
# Run: 356, exploration: 0.1, score: 26
# Scores: (min: 8, avg: 52.14, max: 304)
#
# Run: 357, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 51.88, max: 304)
#
# Run: 358, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 51.89, max: 304)
#
# Run: 359, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 51.85, max: 304)
#
# Run: 360, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 51.26, max: 304)
#
# Run: 361, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 50.43, max: 304)
#
# Run: 362, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 49.58, max: 304)
#
# Run: 363, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 48.66, max: 304)
#
# Run: 364, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 47.98, max: 304)
#
# Run: 365, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 47.21, max: 304)
#
# Run: 366, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 46.91, max: 304)
#
# Run: 367, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 46.66, max: 304)
#
# Run: 368, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 45.8, max: 304)
#
# Run: 369, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 45.77, max: 304)
#
# Run: 370, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 44.14, max: 304)
#
# Run: 371, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 43.74, max: 304)
#
# Run: 372, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 43.74, max: 304)
#
# Run: 373, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 43.69, max: 304)
#
# Run: 374, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 43.71, max: 304)
#
# Run: 375, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 40.79, max: 266)
#
# Run: 376, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 40.12, max: 266)
#
# Run: 377, exploration: 0.1, score: 302
# Scores: (min: 8, avg: 42.46, max: 302)
#
# Run: 378, exploration: 0.1, score: 123
# Scores: (min: 8, avg: 42.21, max: 302)
#
# Run: 379, exploration: 0.1, score: 20
# Scores: (min: 8, avg: 41.1, max: 302)
#
# Run: 380, exploration: 0.1, score: 124
# Scores: (min: 8, avg: 42.17, max: 302)
#
# Run: 381, exploration: 0.1, score: 152
# Scores: (min: 8, avg: 43.31, max: 302)
#
# Run: 382, exploration: 0.1, score: 77
# Scores: (min: 8, avg: 43.21, max: 302)
#
# Run: 383, exploration: 0.1, score: 17
# Scores: (min: 8, avg: 42.56, max: 302)
#
# Run: 384, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 42.28, max: 302)
#
# Run: 385, exploration: 0.1, score: 15
# Scores: (min: 8, avg: 41.91, max: 302)
#
# Run: 386, exploration: 0.1, score: 24
# Scores: (min: 8, avg: 40.71, max: 302)
#
# Run: 387, exploration: 0.1, score: 128
# Scores: (min: 8, avg: 41.49, max: 302)
#
# Run: 388, exploration: 0.1, score: 98
# Scores: (min: 8, avg: 41.9, max: 302)
#
# Run: 389, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 41.89, max: 302)
#
# Run: 390, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 41.87, max: 302)
#
# Run: 391, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 41.89, max: 302)
#
# Run: 392, exploration: 0.1, score: 124
# Scores: (min: 8, avg: 43.04, max: 302)
#
# Run: 393, exploration: 0.1, score: 23
# Scores: (min: 8, avg: 43.18, max: 302)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-3-2acf7c5abb75> in cartpole()
#      88                 score_logger.add_score(step, run)
#      89                 break
# ---> 90             dqn_solver.experience_replay()
#      91
#
# <ipython-input-3-2acf7c5abb75> in experience_replay(self)
#      58             q_values = self.model.predict(state)
#      59             q_values[0][action] = q_update
# ---> 60             self.model.fit(state, q_values, verbose=0)
#      61         self.exploration_rate *= EXPLORATION_DECAY
#      62         self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     194                     ins_batch[i] = ins_batch[i].toarray()
#     195
# --> 196                 outs = fit_function(ins_batch)
#     197                 outs = to_list(outs)
#     198                 for l, o in zip(out_labels, outs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\keras\backend.py in __call__(self, inputs)
#    3725         value = math_ops.cast(value, tensor.dtype)
#    3726       converted_inputs.append(value)
# -> 3727     outputs = self._graph_fn(*converted_inputs)
#    3728
#    3729     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in __call__(self, *args, **kwargs)
#    1549       TypeError: For invalid positional/keyword argument combinations.
#    1550     """
# -> 1551     return self._call_impl(args, kwargs)
#    1552
#    1553   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1589       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1590           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1591     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1592
#    1593   def _filtered_call(self, args, kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Modified Run 2
# For this run we increased the `EXPLORATION_MIN = 0.1` to `0.9`. Once again the block-run was heading towards a very large total Run number (even more than the previous modification of `LEARNING_RATE`); the block was stopped at Run **302** with an average score of just **26.71**. At this rate we would be well into the 1000's of runs before reaching the goal of **195**.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95                # calculat the future discounted reward
LEARNING_RATE = 0.001        # how much the nn learns each iteraction
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20             # how much memory is used to learn
  
EXPLORATION_MAX = 1.0       # rate at which agent randomly decides actions
                            # as opposed to predictions
EXPLORATION_MIN = 0.9       # explore at least this amount
EXPLORATION_DECAY = 0.995   # decrease number of explorations over time as
                            # agent ability improves
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 0.995, score: 21
# Scores: (min: 21, avg: 21, max: 21)
#
# Run: 2, exploration: 0.9, score: 25
# Scores: (min: 21, avg: 23, max: 25)
#
# Run: 3, exploration: 0.9, score: 19
# Scores: (min: 19, avg: 21.666666666666668, max: 25)
#
# Run: 4, exploration: 0.9, score: 31
# Scores: (min: 19, avg: 24, max: 31)
#
# Run: 5, exploration: 0.9, score: 29
# Scores: (min: 19, avg: 25, max: 31)
#
# Run: 6, exploration: 0.9, score: 18
# Scores: (min: 18, avg: 23.833333333333332, max: 31)
#
# Run: 7, exploration: 0.9, score: 10
# Scores: (min: 10, avg: 21.857142857142858, max: 31)
#
# Run: 8, exploration: 0.9, score: 29
# Scores: (min: 10, avg: 22.75, max: 31)
#
# Run: 9, exploration: 0.9, score: 11
# Scores: (min: 10, avg: 21.444444444444443, max: 31)
#
# Run: 10, exploration: 0.9, score: 10
# Scores: (min: 10, avg: 20.3, max: 31)
#
# Run: 11, exploration: 0.9, score: 11
# Scores: (min: 10, avg: 19.454545454545453, max: 31)
#
# Run: 12, exploration: 0.9, score: 10
# Scores: (min: 10, avg: 18.666666666666668, max: 31)
#
# Run: 13, exploration: 0.9, score: 24
# Scores: (min: 10, avg: 19.076923076923077, max: 31)
#
# Run: 14, exploration: 0.9, score: 15
# Scores: (min: 10, avg: 18.785714285714285, max: 31)
#
# Run: 15, exploration: 0.9, score: 26
# Scores: (min: 10, avg: 19.266666666666666, max: 31)
#
# Run: 16, exploration: 0.9, score: 42
# Scores: (min: 10, avg: 20.6875, max: 42)
#
# Run: 17, exploration: 0.9, score: 38
# Scores: (min: 10, avg: 21.705882352941178, max: 42)
#
# Run: 18, exploration: 0.9, score: 11
# Scores: (min: 10, avg: 21.11111111111111, max: 42)
#
# Run: 19, exploration: 0.9, score: 115
# Scores: (min: 10, avg: 26.05263157894737, max: 115)
#
# Run: 20, exploration: 0.9, score: 26
# Scores: (min: 10, avg: 26.05, max: 115)
#
# Run: 21, exploration: 0.9, score: 19
# Scores: (min: 10, avg: 25.714285714285715, max: 115)
#
# Run: 22, exploration: 0.9, score: 16
# Scores: (min: 10, avg: 25.272727272727273, max: 115)
#
# Run: 23, exploration: 0.9, score: 12
# Scores: (min: 10, avg: 24.695652173913043, max: 115)
#
# Run: 24, exploration: 0.9, score: 37
# Scores: (min: 10, avg: 25.208333333333332, max: 115)
#
# Run: 25, exploration: 0.9, score: 21
# Scores: (min: 10, avg: 25.04, max: 115)
#
# Run: 26, exploration: 0.9, score: 43
# Scores: (min: 10, avg: 25.73076923076923, max: 115)
#
# Run: 27, exploration: 0.9, score: 30
# Scores: (min: 10, avg: 25.88888888888889, max: 115)
#
# Run: 28, exploration: 0.9, score: 12
# Scores: (min: 10, avg: 25.392857142857142, max: 115)
#
# Run: 29, exploration: 0.9, score: 29
# Scores: (min: 10, avg: 25.517241379310345, max: 115)
#
# Run: 30, exploration: 0.9, score: 27
# Scores: (min: 10, avg: 25.566666666666666, max: 115)
#
# Run: 31, exploration: 0.9, score: 14
# Scores: (min: 10, avg: 25.193548387096776, max: 115)
#
# Run: 32, exploration: 0.9, score: 14
# Scores: (min: 10, avg: 24.84375, max: 115)
#
# Run: 33, exploration: 0.9, score: 26
# Scores: (min: 10, avg: 24.87878787878788, max: 115)
#
# Run: 34, exploration: 0.9, score: 12
# Scores: (min: 10, avg: 24.5, max: 115)
#
# Run: 35, exploration: 0.9, score: 24
# Scores: (min: 10, avg: 24.485714285714284, max: 115)
#
# Run: 36, exploration: 0.9, score: 37
# Scores: (min: 10, avg: 24.833333333333332, max: 115)
#
# Run: 37, exploration: 0.9, score: 30
# Scores: (min: 10, avg: 24.972972972972972, max: 115)
#
# Run: 38, exploration: 0.9, score: 12
# Scores: (min: 10, avg: 24.63157894736842, max: 115)
#
# Run: 39, exploration: 0.9, score: 34
# Scores: (min: 10, avg: 24.871794871794872, max: 115)
#
# Run: 40, exploration: 0.9, score: 27
# Scores: (min: 10, avg: 24.925, max: 115)
#
# Run: 41, exploration: 0.9, score: 12
# Scores: (min: 10, avg: 24.609756097560975, max: 115)
#
# Run: 42, exploration: 0.9, score: 36
# Scores: (min: 10, avg: 24.88095238095238, max: 115)
#
# Run: 43, exploration: 0.9, score: 14
# Scores: (min: 10, avg: 24.627906976744185, max: 115)
#
# Run: 44, exploration: 0.9, score: 33
# Scores: (min: 10, avg: 24.818181818181817, max: 115)
#
# Run: 45, exploration: 0.9, score: 35
# Scores: (min: 10, avg: 25.044444444444444, max: 115)
#
# Run: 46, exploration: 0.9, score: 10
# Scores: (min: 10, avg: 24.717391304347824, max: 115)
#
# Run: 47, exploration: 0.9, score: 11
# Scores: (min: 10, avg: 24.425531914893618, max: 115)
#
# Run: 48, exploration: 0.9, score: 66
# Scores: (min: 10, avg: 25.291666666666668, max: 115)
#
# Run: 49, exploration: 0.9, score: 33
# Scores: (min: 10, avg: 25.448979591836736, max: 115)
#
# Run: 50, exploration: 0.9, score: 11
# Scores: (min: 10, avg: 25.16, max: 115)
#
# Run: 51, exploration: 0.9, score: 11
# Scores: (min: 10, avg: 24.88235294117647, max: 115)
#
# Run: 52, exploration: 0.9, score: 46
# Scores: (min: 10, avg: 25.28846153846154, max: 115)
#
# Run: 53, exploration: 0.9, score: 14
# Scores: (min: 10, avg: 25.07547169811321, max: 115)
#
# Run: 54, exploration: 0.9, score: 15
# Scores: (min: 10, avg: 24.88888888888889, max: 115)
#
# Run: 55, exploration: 0.9, score: 39
# Scores: (min: 10, avg: 25.145454545454545, max: 115)
#
# Run: 56, exploration: 0.9, score: 30
# Scores: (min: 10, avg: 25.232142857142858, max: 115)
#
# Run: 57, exploration: 0.9, score: 17
# Scores: (min: 10, avg: 25.087719298245613, max: 115)
#
# Run: 58, exploration: 0.9, score: 23
# Scores: (min: 10, avg: 25.051724137931036, max: 115)
#
# Run: 59, exploration: 0.9, score: 16
# Scores: (min: 10, avg: 24.89830508474576, max: 115)
#
# Run: 60, exploration: 0.9, score: 14
# Scores: (min: 10, avg: 24.716666666666665, max: 115)
#
# Run: 61, exploration: 0.9, score: 11
# Scores: (min: 10, avg: 24.491803278688526, max: 115)
#
# Run: 62, exploration: 0.9, score: 38
# Scores: (min: 10, avg: 24.70967741935484, max: 115)
#
# Run: 63, exploration: 0.9, score: 15
# Scores: (min: 10, avg: 24.555555555555557, max: 115)
#
# Run: 64, exploration: 0.9, score: 41
# Scores: (min: 10, avg: 24.8125, max: 115)
#
# Run: 65, exploration: 0.9, score: 26
# Scores: (min: 10, avg: 24.83076923076923, max: 115)
#
# Run: 66, exploration: 0.9, score: 22
# Scores: (min: 10, avg: 24.78787878787879, max: 115)
#
# Run: 67, exploration: 0.9, score: 12
# Scores: (min: 10, avg: 24.597014925373134, max: 115)
#
# Run: 68, exploration: 0.9, score: 41
# Scores: (min: 10, avg: 24.83823529411765, max: 115)
#
# Run: 69, exploration: 0.9, score: 18
# Scores: (min: 10, avg: 24.73913043478261, max: 115)
#
# Run: 70, exploration: 0.9, score: 25
# Scores: (min: 10, avg: 24.742857142857144, max: 115)
#
# Run: 71, exploration: 0.9, score: 11
# Scores: (min: 10, avg: 24.549295774647888, max: 115)
#
# Run: 72, exploration: 0.9, score: 29
# Scores: (min: 10, avg: 24.61111111111111, max: 115)
#
# Run: 73, exploration: 0.9, score: 26
# Scores: (min: 10, avg: 24.63013698630137, max: 115)
#
# Run: 74, exploration: 0.9, score: 52
# Scores: (min: 10, avg: 25, max: 115)
#
# Run: 75, exploration: 0.9, score: 17
# Scores: (min: 10, avg: 24.893333333333334, max: 115)
#
# Run: 76, exploration: 0.9, score: 16
# Scores: (min: 10, avg: 24.776315789473685, max: 115)
#
# Run: 77, exploration: 0.9, score: 38
# Scores: (min: 10, avg: 24.948051948051948, max: 115)
#
# Run: 78, exploration: 0.9, score: 16
# Scores: (min: 10, avg: 24.833333333333332, max: 115)
#
# Run: 79, exploration: 0.9, score: 10
# Scores: (min: 10, avg: 24.645569620253166, max: 115)
#
# Run: 80, exploration: 0.9, score: 86
# Scores: (min: 10, avg: 25.4125, max: 115)
#
# Run: 81, exploration: 0.9, score: 32
# Scores: (min: 10, avg: 25.493827160493826, max: 115)
#
# Run: 82, exploration: 0.9, score: 49
# Scores: (min: 10, avg: 25.78048780487805, max: 115)
#
# Run: 83, exploration: 0.9, score: 78
# Scores: (min: 10, avg: 26.40963855421687, max: 115)
#
# Run: 84, exploration: 0.9, score: 15
# Scores: (min: 10, avg: 26.273809523809526, max: 115)
#
# Run: 85, exploration: 0.9, score: 10
# Scores: (min: 10, avg: 26.08235294117647, max: 115)
#
# Run: 86, exploration: 0.9, score: 24
# Scores: (min: 10, avg: 26.058139534883722, max: 115)
#
# Run: 87, exploration: 0.9, score: 37
# Scores: (min: 10, avg: 26.183908045977013, max: 115)
#
# Run: 88, exploration: 0.9, score: 12
# Scores: (min: 10, avg: 26.022727272727273, max: 115)
#
# Run: 89, exploration: 0.9, score: 70
# Scores: (min: 10, avg: 26.51685393258427, max: 115)
#
# Run: 90, exploration: 0.9, score: 37
# Scores: (min: 10, avg: 26.633333333333333, max: 115)
#
# Run: 91, exploration: 0.9, score: 16
# Scores: (min: 10, avg: 26.516483516483518, max: 115)
#
# Run: 92, exploration: 0.9, score: 36
# Scores: (min: 10, avg: 26.619565217391305, max: 115)
#
# Run: 93, exploration: 0.9, score: 58
# Scores: (min: 10, avg: 26.956989247311828, max: 115)
# Run: 94, exploration: 0.9, score: 12
# Scores: (min: 10, avg: 26.79787234042553, max: 115)
#
# Run: 95, exploration: 0.9, score: 14
# Scores: (min: 10, avg: 26.66315789473684, max: 115)
#
# Run: 96, exploration: 0.9, score: 17
# Scores: (min: 10, avg: 26.5625, max: 115)
#
# Run: 97, exploration: 0.9, score: 85
# Scores: (min: 10, avg: 27.164948453608247, max: 115)
#
# Run: 98, exploration: 0.9, score: 26
# Scores: (min: 10, avg: 27.153061224489797, max: 115)
#
# Run: 99, exploration: 0.9, score: 18
# Scores: (min: 10, avg: 27.060606060606062, max: 115)
#
# Run: 100, exploration: 0.9, score: 26
# Scores: (min: 10, avg: 27.05, max: 115)
#
# Run: 101, exploration: 0.9, score: 13
# Scores: (min: 10, avg: 26.97, max: 115)
#
# Run: 102, exploration: 0.9, score: 28
# Scores: (min: 10, avg: 27, max: 115)
#
# Run: 103, exploration: 0.9, score: 12
# Scores: (min: 10, avg: 26.93, max: 115)
#
# Run: 104, exploration: 0.9, score: 59
# Scores: (min: 10, avg: 27.21, max: 115)
#
# Run: 105, exploration: 0.9, score: 20
# Scores: (min: 10, avg: 27.12, max: 115)
#
# Run: 106, exploration: 0.9, score: 12
# Scores: (min: 10, avg: 27.06, max: 115)
#
# Run: 107, exploration: 0.9, score: 35
# Scores: (min: 10, avg: 27.31, max: 115)
#
# Run: 108, exploration: 0.9, score: 11
# Scores: (min: 10, avg: 27.13, max: 115)
#
# Run: 109, exploration: 0.9, score: 17
# Scores: (min: 10, avg: 27.19, max: 115)
#
# Run: 110, exploration: 0.9, score: 29
# Scores: (min: 10, avg: 27.38, max: 115)
#
# Run: 111, exploration: 0.9, score: 79
# Scores: (min: 10, avg: 28.06, max: 115)
#
# Run: 112, exploration: 0.9, score: 16
# Scores: (min: 10, avg: 28.12, max: 115)
#
# Run: 113, exploration: 0.9, score: 41
# Scores: (min: 10, avg: 28.29, max: 115)
#
# Run: 114, exploration: 0.9, score: 19
# Scores: (min: 10, avg: 28.33, max: 115)
#
# Run: 115, exploration: 0.9, score: 11
# Scores: (min: 10, avg: 28.18, max: 115)
#
# Run: 116, exploration: 0.9, score: 25
# Scores: (min: 10, avg: 28.01, max: 115)
#
# Run: 117, exploration: 0.9, score: 25
# Scores: (min: 10, avg: 27.88, max: 115)
#
# Run: 118, exploration: 0.9, score: 20
# Scores: (min: 10, avg: 27.97, max: 115)
#
# Run: 119, exploration: 0.9, score: 14
# Scores: (min: 10, avg: 26.96, max: 86)
#
# Run: 120, exploration: 0.9, score: 10
# Scores: (min: 10, avg: 26.8, max: 86)
#
# Run: 121, exploration: 0.9, score: 11
# Scores: (min: 10, avg: 26.72, max: 86)
#
# Run: 122, exploration: 0.9, score: 77
# Scores: (min: 10, avg: 27.33, max: 86)
#
# Run: 123, exploration: 0.9, score: 95
# Scores: (min: 10, avg: 28.16, max: 95)
#
# Run: 124, exploration: 0.9, score: 17
# Scores: (min: 10, avg: 27.96, max: 95)
#
# Run: 125, exploration: 0.9, score: 19
# Scores: (min: 10, avg: 27.94, max: 95)
#
# Run: 126, exploration: 0.9, score: 44
# Scores: (min: 10, avg: 27.95, max: 95)
#
# Run: 127, exploration: 0.9, score: 17
# Scores: (min: 10, avg: 27.82, max: 95)
#
# Run: 128, exploration: 0.9, score: 25
# Scores: (min: 10, avg: 27.95, max: 95)
#
# Run: 129, exploration: 0.9, score: 14
# Scores: (min: 10, avg: 27.8, max: 95)
#
# Run: 130, exploration: 0.9, score: 42
# Scores: (min: 10, avg: 27.95, max: 95)
#
# Run: 131, exploration: 0.9, score: 19
# Scores: (min: 10, avg: 28, max: 95)
#
# Run: 132, exploration: 0.9, score: 16
# Scores: (min: 10, avg: 28.02, max: 95)
#
# Run: 133, exploration: 0.9, score: 12
# Scores: (min: 10, avg: 27.88, max: 95)
#
# Run: 134, exploration: 0.9, score: 23
# Scores: (min: 10, avg: 27.99, max: 95)
#
# Run: 135, exploration: 0.9, score: 26
# Scores: (min: 10, avg: 28.01, max: 95)
#
# Run: 136, exploration: 0.9, score: 12
# Scores: (min: 10, avg: 27.76, max: 95)
#
# Run: 137, exploration: 0.9, score: 71
# Scores: (min: 10, avg: 28.17, max: 95)
#
# Run: 138, exploration: 0.9, score: 19
# Scores: (min: 10, avg: 28.24, max: 95)
#
# Run: 139, exploration: 0.9, score: 29
# Scores: (min: 10, avg: 28.19, max: 95)
#
# Run: 140, exploration: 0.9, score: 58
# Scores: (min: 10, avg: 28.5, max: 95)
#
# Run: 141, exploration: 0.9, score: 27
# Scores: (min: 10, avg: 28.65, max: 95)
#
# Run: 142, exploration: 0.9, score: 18
# Scores: (min: 10, avg: 28.47, max: 95)
#
# Run: 143, exploration: 0.9, score: 16
# Scores: (min: 10, avg: 28.49, max: 95)
#
# Run: 144, exploration: 0.9, score: 18
# Scores: (min: 10, avg: 28.34, max: 95)
#
# Run: 145, exploration: 0.9, score: 31
# Scores: (min: 10, avg: 28.3, max: 95)
#
# Run: 146, exploration: 0.9, score: 20
# Scores: (min: 10, avg: 28.4, max: 95)
#
# Run: 147, exploration: 0.9, score: 15
# Scores: (min: 10, avg: 28.44, max: 95)
#
# Run: 148, exploration: 0.9, score: 24
# Scores: (min: 10, avg: 28.02, max: 95)
#
# Run: 149, exploration: 0.9, score: 26
# Scores: (min: 10, avg: 27.95, max: 95)
#
# Run: 150, exploration: 0.9, score: 34
# Scores: (min: 10, avg: 28.18, max: 95)
#
# Run: 151, exploration: 0.9, score: 17
# Scores: (min: 10, avg: 28.24, max: 95)
#
# Run: 152, exploration: 0.9, score: 19
# Scores: (min: 10, avg: 27.97, max: 95)
#
# Run: 153, exploration: 0.9, score: 14
# Scores: (min: 10, avg: 27.97, max: 95)
#
# Run: 154, exploration: 0.9, score: 26
# Scores: (min: 10, avg: 28.08, max: 95)
#
# Run: 155, exploration: 0.9, score: 10
# Scores: (min: 10, avg: 27.79, max: 95)
#
# Run: 156, exploration: 0.9, score: 34
# Scores: (min: 10, avg: 27.83, max: 95)
#
# Run: 157, exploration: 0.9, score: 17
# Scores: (min: 10, avg: 27.83, max: 95)
#
# Run: 158, exploration: 0.9, score: 18
# Scores: (min: 10, avg: 27.78, max: 95)
#
# Run: 159, exploration: 0.9, score: 16
# Scores: (min: 10, avg: 27.78, max: 95)
#
# Run: 160, exploration: 0.9, score: 24
# Scores: (min: 10, avg: 27.88, max: 95)
#
# Run: 161, exploration: 0.9, score: 21
# Scores: (min: 10, avg: 27.98, max: 95)
#
# Run: 162, exploration: 0.9, score: 27
# Scores: (min: 10, avg: 27.87, max: 95)
#
# Run: 163, exploration: 0.9, score: 12
# Scores: (min: 10, avg: 27.84, max: 95)
#
# Run: 164, exploration: 0.9, score: 33
# Scores: (min: 10, avg: 27.76, max: 95)
#
# Run: 165, exploration: 0.9, score: 9
# Scores: (min: 9, avg: 27.59, max: 95)
#
# Run: 166, exploration: 0.9, score: 35
# Scores: (min: 9, avg: 27.72, max: 95)
#
# Run: 167, exploration: 0.9, score: 10
# Scores: (min: 9, avg: 27.7, max: 95)
#
# Run: 168, exploration: 0.9, score: 172
# Scores: (min: 9, avg: 29.01, max: 172)
#
# Run: 169, exploration: 0.9, score: 25
# Scores: (min: 9, avg: 29.08, max: 172)
#
# Run: 170, exploration: 0.9, score: 11
# Scores: (min: 9, avg: 28.94, max: 172)
#
# Run: 171, exploration: 0.9, score: 20
# Scores: (min: 9, avg: 29.03, max: 172)
#
# Run: 172, exploration: 0.9, score: 14
# Scores: (min: 9, avg: 28.88, max: 172)
#
# Run: 173, exploration: 0.9, score: 34
# Scores: (min: 9, avg: 28.96, max: 172)
#
# Run: 174, exploration: 0.9, score: 14
# Scores: (min: 9, avg: 28.58, max: 172)
#
# Run: 175, exploration: 0.9, score: 30
# Scores: (min: 9, avg: 28.71, max: 172)
#
# Run: 176, exploration: 0.9, score: 23
# Scores: (min: 9, avg: 28.78, max: 172)
#
# Run: 177, exploration: 0.9, score: 54
# Scores: (min: 9, avg: 28.94, max: 172)
#
# Run: 178, exploration: 0.9, score: 39
# Scores: (min: 9, avg: 29.17, max: 172)
#
# Run: 179, exploration: 0.9, score: 44
# Scores: (min: 9, avg: 29.51, max: 172)
#
# Run: 180, exploration: 0.9, score: 17
# Scores: (min: 9, avg: 28.82, max: 172)
#
# Run: 181, exploration: 0.9, score: 17
# Scores: (min: 9, avg: 28.67, max: 172)
#
# Run: 182, exploration: 0.9, score: 16
# Scores: (min: 9, avg: 28.34, max: 172)
#
# Run: 183, exploration: 0.9, score: 11
# Scores: (min: 9, avg: 27.67, max: 172)
#
# Run: 184, exploration: 0.9, score: 13
# Scores: (min: 9, avg: 27.65, max: 172)
#
# Run: 185, exploration: 0.9, score: 15
# Scores: (min: 9, avg: 27.7, max: 172)
#
# Run: 186, exploration: 0.9, score: 13
# Scores: (min: 9, avg: 27.59, max: 172)
#
# Run: 187, exploration: 0.9, score: 14
# Scores: (min: 9, avg: 27.36, max: 172)
#
# Run: 188, exploration: 0.9, score: 24
# Scores: (min: 9, avg: 27.48, max: 172)
#
# Run: 189, exploration: 0.9, score: 11
# Scores: (min: 9, avg: 26.89, max: 172)
#
# Run: 190, exploration: 0.9, score: 14
# Scores: (min: 9, avg: 26.66, max: 172)
#
# Run: 191, exploration: 0.9, score: 36
# Scores: (min: 9, avg: 26.86, max: 172)
#
# Run: 192, exploration: 0.9, score: 24
# Scores: (min: 9, avg: 26.74, max: 172)
#
# Run: 193, exploration: 0.9, score: 68
# Scores: (min: 9, avg: 26.84, max: 172)
#
# Run: 194, exploration: 0.9, score: 25
# Scores: (min: 9, avg: 26.97, max: 172)
#
# Run: 195, exploration: 0.9, score: 28
# Scores: (min: 9, avg: 27.11, max: 172)
#
# Run: 196, exploration: 0.9, score: 59
# Scores: (min: 9, avg: 27.53, max: 172)
#
# Run: 197, exploration: 0.9, score: 23
# Scores: (min: 9, avg: 26.91, max: 172)
#
# Run: 198, exploration: 0.9, score: 14
# Scores: (min: 9, avg: 26.79, max: 172)
# Run: 199, exploration: 0.9, score: 18
# Scores: (min: 9, avg: 26.79, max: 172)
#
# Run: 200, exploration: 0.9, score: 21
# Scores: (min: 9, avg: 26.74, max: 172)
#
# Run: 201, exploration: 0.9, score: 37
# Scores: (min: 9, avg: 26.98, max: 172)
#
# Run: 202, exploration: 0.9, score: 40
# Scores: (min: 9, avg: 27.1, max: 172)
#
# Run: 203, exploration: 0.9, score: 10
# Scores: (min: 9, avg: 27.08, max: 172)
#
# Run: 204, exploration: 0.9, score: 17
# Scores: (min: 9, avg: 26.66, max: 172)
#
# Run: 205, exploration: 0.9, score: 26
# Scores: (min: 9, avg: 26.72, max: 172)
#
# Run: 206, exploration: 0.9, score: 18
# Scores: (min: 9, avg: 26.78, max: 172)
#
# Run: 207, exploration: 0.9, score: 12
# Scores: (min: 9, avg: 26.55, max: 172)
#
# Run: 208, exploration: 0.9, score: 49
# Scores: (min: 9, avg: 26.93, max: 172)
#
# Run: 209, exploration: 0.9, score: 23
# Scores: (min: 9, avg: 26.99, max: 172)
#
# Run: 210, exploration: 0.9, score: 14
# Scores: (min: 9, avg: 26.84, max: 172)
#
# Run: 211, exploration: 0.9, score: 34
# Scores: (min: 9, avg: 26.39, max: 172)
#
# Run: 212, exploration: 0.9, score: 14
# Scores: (min: 9, avg: 26.37, max: 172)
#
# Run: 213, exploration: 0.9, score: 20
# Scores: (min: 9, avg: 26.16, max: 172)
#
# Run: 214, exploration: 0.9, score: 44
# Scores: (min: 9, avg: 26.41, max: 172)
#
# Run: 215, exploration: 0.9, score: 50
# Scores: (min: 9, avg: 26.8, max: 172)
#
# Run: 216, exploration: 0.9, score: 13
# Scores: (min: 9, avg: 26.68, max: 172)
#
# Run: 217, exploration: 0.9, score: 51
# Scores: (min: 9, avg: 26.94, max: 172)
#
# Run: 218, exploration: 0.9, score: 36
# Scores: (min: 9, avg: 27.1, max: 172)
#
# Run: 219, exploration: 0.9, score: 33
# Scores: (min: 9, avg: 27.29, max: 172)
#
# Run: 220, exploration: 0.9, score: 14
# Scores: (min: 9, avg: 27.33, max: 172)
#
# Run: 221, exploration: 0.9, score: 14
# Scores: (min: 9, avg: 27.36, max: 172)
#
# Run: 222, exploration: 0.9, score: 14
# Scores: (min: 9, avg: 26.73, max: 172)
#
# Run: 223, exploration: 0.9, score: 11
# Scores: (min: 9, avg: 25.89, max: 172)
#
# Run: 224, exploration: 0.9, score: 81
# Scores: (min: 9, avg: 26.53, max: 172)
#
# Run: 225, exploration: 0.9, score: 10
# Scores: (min: 9, avg: 26.44, max: 172)
#
# Run: 226, exploration: 0.9, score: 20
# Scores: (min: 9, avg: 26.2, max: 172)
#
# Run: 227, exploration: 0.9, score: 12
# Scores: (min: 9, avg: 26.15, max: 172)
#
# Run: 228, exploration: 0.9, score: 29
# Scores: (min: 9, avg: 26.19, max: 172)
#
# Run: 229, exploration: 0.9, score: 12
# Scores: (min: 9, avg: 26.17, max: 172)
#
# Run: 230, exploration: 0.9, score: 37
# Scores: (min: 9, avg: 26.12, max: 172)
#
# Run: 231, exploration: 0.9, score: 49
# Scores: (min: 9, avg: 26.42, max: 172)
#
# Run: 232, exploration: 0.9, score: 19
# Scores: (min: 9, avg: 26.45, max: 172)
#
# Run: 233, exploration: 0.9, score: 13
# Scores: (min: 9, avg: 26.46, max: 172)
#
# Run: 234, exploration: 0.9, score: 62
# Scores: (min: 9, avg: 26.85, max: 172)
#
# Run: 235, exploration: 0.9, score: 35
# Scores: (min: 9, avg: 26.94, max: 172)
#
# Run: 236, exploration: 0.9, score: 40
# Scores: (min: 9, avg: 27.22, max: 172)
#
# Run: 237, exploration: 0.9, score: 10
# Scores: (min: 9, avg: 26.61, max: 172)
#
# Run: 238, exploration: 0.9, score: 17
# Scores: (min: 9, avg: 26.59, max: 172)
#
# Run: 239, exploration: 0.9, score: 40
# Scores: (min: 9, avg: 26.7, max: 172)
#
# Run: 240, exploration: 0.9, score: 22
# Scores: (min: 9, avg: 26.34, max: 172)
#
# Run: 241, exploration: 0.9, score: 17
# Scores: (min: 9, avg: 26.24, max: 172)
#
# Run: 242, exploration: 0.9, score: 45
# Scores: (min: 9, avg: 26.51, max: 172)
#
# Run: 243, exploration: 0.9, score: 12
# Scores: (min: 9, avg: 26.47, max: 172)
#
# Run: 244, exploration: 0.9, score: 26
# Scores: (min: 9, avg: 26.55, max: 172)
#
# Run: 245, exploration: 0.9, score: 40
# Scores: (min: 9, avg: 26.64, max: 172)
#
# Run: 246, exploration: 0.9, score: 20
# Scores: (min: 9, avg: 26.64, max: 172)
#
# Run: 247, exploration: 0.9, score: 16
# Scores: (min: 9, avg: 26.65, max: 172)
#
# Run: 248, exploration: 0.9, score: 9
# Scores: (min: 9, avg: 26.5, max: 172)
#
# Run: 249, exploration: 0.9, score: 18
# Scores: (min: 9, avg: 26.42, max: 172)
#
# Run: 250, exploration: 0.9, score: 17
# Scores: (min: 9, avg: 26.25, max: 172)
#
# Run: 251, exploration: 0.9, score: 16
# Scores: (min: 9, avg: 26.24, max: 172)
#
# Run: 252, exploration: 0.9, score: 11
# Scores: (min: 9, avg: 26.16, max: 172)
#
# Run: 253, exploration: 0.9, score: 23
# Scores: (min: 9, avg: 26.25, max: 172)
#
# Run: 254, exploration: 0.9, score: 18
# Scores: (min: 9, avg: 26.17, max: 172)
#
# Run: 255, exploration: 0.9, score: 46
# Scores: (min: 9, avg: 26.53, max: 172)
#
# Run: 256, exploration: 0.9, score: 24
# Scores: (min: 9, avg: 26.43, max: 172)
#
# Run: 257, exploration: 0.9, score: 31
# Scores: (min: 9, avg: 26.57, max: 172)
#
# Run: 258, exploration: 0.9, score: 11
# Scores: (min: 9, avg: 26.5, max: 172)
#
# Run: 259, exploration: 0.9, score: 17
# Scores: (min: 9, avg: 26.51, max: 172)
#
# Run: 260, exploration: 0.9, score: 15
# Scores: (min: 9, avg: 26.42, max: 172)
#
# Run: 261, exploration: 0.9, score: 18
# Scores: (min: 9, avg: 26.39, max: 172)
#
# Run: 262, exploration: 0.9, score: 12
# Scores: (min: 9, avg: 26.24, max: 172)
#
# Run: 263, exploration: 0.9, score: 17
# Scores: (min: 9, avg: 26.29, max: 172)
#
# Run: 264, exploration: 0.9, score: 56
# Scores: (min: 9, avg: 26.52, max: 172)
#
# Run: 265, exploration: 0.9, score: 24
# Scores: (min: 9, avg: 26.67, max: 172)
#
# Run: 266, exploration: 0.9, score: 23
# Scores: (min: 9, avg: 26.55, max: 172)
#
# Run: 267, exploration: 0.9, score: 38
# Scores: (min: 9, avg: 26.83, max: 172)
#
# Run: 268, exploration: 0.9, score: 33
# Scores: (min: 9, avg: 25.44, max: 81)
#
# Run: 269, exploration: 0.9, score: 11
# Scores: (min: 9, avg: 25.3, max: 81)
#
# Run: 270, exploration: 0.9, score: 50
# Scores: (min: 9, avg: 25.69, max: 81)
#
# Run: 271, exploration: 0.9, score: 60
# Scores: (min: 9, avg: 26.09, max: 81)
#
# Run: 272, exploration: 0.9, score: 25
# Scores: (min: 9, avg: 26.2, max: 81)
#
# Run: 273, exploration: 0.9, score: 38
# Scores: (min: 9, avg: 26.24, max: 81)
#
# Run: 274, exploration: 0.9, score: 15
# Scores: (min: 9, avg: 26.25, max: 81)
#
# Run: 275, exploration: 0.9, score: 14
# Scores: (min: 9, avg: 26.09, max: 81)
#
# Run: 276, exploration: 0.9, score: 38
# Scores: (min: 9, avg: 26.24, max: 81)
#
# Run: 277, exploration: 0.9, score: 30
# Scores: (min: 9, avg: 26, max: 81)
#
# Run: 278, exploration: 0.9, score: 16
# Scores: (min: 9, avg: 25.77, max: 81)
#
# Run: 279, exploration: 0.9, score: 27
# Scores: (min: 9, avg: 25.6, max: 81)
#
# Run: 280, exploration: 0.9, score: 20
# Scores: (min: 9, avg: 25.63, max: 81)
#
# Run: 281, exploration: 0.9, score: 13
# Scores: (min: 9, avg: 25.59, max: 81)
#
# Run: 282, exploration: 0.9, score: 18
# Scores: (min: 9, avg: 25.61, max: 81)
#
# Run: 283, exploration: 0.9, score: 14
# Scores: (min: 9, avg: 25.64, max: 81)
#
# Run: 284, exploration: 0.9, score: 41
# Scores: (min: 9, avg: 25.92, max: 81)
#
# Run: 285, exploration: 0.9, score: 45
# Scores: (min: 9, avg: 26.22, max: 81)
#
# Run: 286, exploration: 0.9, score: 60
# Scores: (min: 9, avg: 26.69, max: 81)
#
# Run: 287, exploration: 0.9, score: 64
# Scores: (min: 9, avg: 27.19, max: 81)
#
# Run: 288, exploration: 0.9, score: 37
# Scores: (min: 9, avg: 27.32, max: 81)
#
# Run: 289, exploration: 0.9, score: 13
# Scores: (min: 9, avg: 27.34, max: 81)
#
# Run: 290, exploration: 0.9, score: 18
# Scores: (min: 9, avg: 27.38, max: 81)
#
# Run: 291, exploration: 0.9, score: 38
# Scores: (min: 9, avg: 27.4, max: 81)
#
# Run: 292, exploration: 0.9, score: 42
# Scores: (min: 9, avg: 27.58, max: 81)
#
# Run: 293, exploration: 0.9, score: 20
# Scores: (min: 9, avg: 27.1, max: 81)
#
# Run: 294, exploration: 0.9, score: 11
# Scores: (min: 9, avg: 26.96, max: 81)
#
# Run: 295, exploration: 0.9, score: 20
# Scores: (min: 9, avg: 26.88, max: 81)
#
# Run: 296, exploration: 0.9, score: 33
# Scores: (min: 9, avg: 26.62, max: 81)
#
# Run: 297, exploration: 0.9, score: 45
# Scores: (min: 9, avg: 26.84, max: 81)
#
# Run: 298, exploration: 0.9, score: 12
# Scores: (min: 9, avg: 26.82, max: 81)
#
# Run: 299, exploration: 0.9, score: 49
# Scores: (min: 9, avg: 27.13, max: 81)
#
# Run: 300, exploration: 0.9, score: 14
# Scores: (min: 9, avg: 27.06, max: 81)
#
# Run: 301, exploration: 0.9, score: 29
# Scores: (min: 9, avg: 26.98, max: 81)
#
# Run: 302, exploration: 0.9, score: 13
# Scores: (min: 9, avg: 26.71, max: 81)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-6-0a1474f2572e> in cartpole()
#      88                 score_logger.add_score(step, run)
#      89                 break
# ---> 90             dqn_solver.experience_replay()
#      91
#
# <ipython-input-6-0a1474f2572e> in experience_replay(self)
#      55             q_update = reward
#      56             if not terminal:
# ---> 57                 q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))
#      58             q_values = self.model.predict(state)
#      59             q_values[0][action] = q_update
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1460                                             verbose=verbose,
#    1461                                             steps=steps,
# -> 1462                                             callbacks=callbacks)
#    1463
#    1464     def train_on_batch(self, x, y,
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps, callbacks)
#     322             batch_logs = {'batch': batch_index, 'size': len(batch_ids)}
#     323             callbacks._call_batch_hook('predict', 'begin', batch_index, batch_logs)
# --> 324             batch_outs = f(ins_batch)
#     325             batch_outs = to_list(batch_outs)
#     326             if batch_index == 0:
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\keras\backend.py in __call__(self, inputs)
#    3725         value = math_ops.cast(value, tensor.dtype)
#    3726       converted_inputs.append(value)
# -> 3727     outputs = self._graph_fn(*converted_inputs)
#    3728
#    3729     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in __call__(self, *args, **kwargs)
#    1549       TypeError: For invalid positional/keyword argument combinations.
#    1550     """
# -> 1551     return self._call_impl(args, kwargs)
#    1552
#    1553   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1589       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1590           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1591     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1592
#    1593   def _filtered_call(self, args, kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Modified Run 3
# For this run, we have modified the `GAMMA = 0.95` to `0.65`; the Gamma variable determines the future discounted reward for the agent. Higher values tend to push the agent towards more consideration of the total sum of the future reward when determining what actions to take during the current state. A lower value increases the agent's myopia, and a value of zero sees the agent only considering the rewards gained in the present environmental state, disregarding all future rewards from future states.
#
# This lower gamma value drastically increased the amount of runs (the program never even reached a 'win' state)

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.65                 # calculat the future discounted reward
LEARNING_RATE = 0.001        # how much the nn learns each iteraction
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20             # how much memory is used to learn
  
EXPLORATION_MAX = 1.0       # rate at which agent randomly decides actions
                            # as opposed to predictions
EXPLORATION_MIN = 0.01       # explore at least this amount
EXPLORATION_DECAY = 0.995   # decrease number of explorations over time as
                            # agent ability improves
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()
# Out:
# Using TensorFlow backend.

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 13
# Scores: (min: 13, avg: 13, max: 13)
#
# Run: 2, exploration: 0.9511101304657719, score: 17
# Scores: (min: 13, avg: 15, max: 17)
#
# Run: 3, exploration: 0.8778091417340573, score: 17
# Scores: (min: 13, avg: 15.666666666666666, max: 17)
#
# Run: 4, exploration: 0.7901049725470279, score: 22
# Scores: (min: 13, avg: 17.25, max: 22)
#
# Run: 5, exploration: 0.7076077347272662, score: 23
# Scores: (min: 13, avg: 18.4, max: 23)
#
# Run: 6, exploration: 0.6337242817644086, score: 23
# Scores: (min: 13, avg: 19.166666666666668, max: 23)
#
# Run: 7, exploration: 0.5907768628656763, score: 15
# Scores: (min: 13, avg: 18.571428571428573, max: 23)
#
# Run: 8, exploration: 0.5398075216808175, score: 19
# Scores: (min: 13, avg: 18.625, max: 23)
#
# Run: 9, exploration: 0.47862223409330756, score: 25
# Scores: (min: 13, avg: 19.333333333333332, max: 25)
#
# Run: 10, exploration: 0.4506816115185697, score: 13
# Scores: (min: 13, avg: 18.7, max: 25)
#
# Run: 11, exploration: 0.42013897252428334, score: 15
# Scores: (min: 13, avg: 18.363636363636363, max: 25)
#
# Run: 12, exploration: 0.4016064652978155, score: 10
# Scores: (min: 10, avg: 17.666666666666668, max: 25)
#
# Run: 13, exploration: 0.37251769488706843, score: 16
# Scores: (min: 10, avg: 17.53846153846154, max: 25)
#
# Run: 14, exploration: 0.3507711574848344, score: 13
# Scores: (min: 10, avg: 17.214285714285715, max: 25)
#
# Run: 15, exploration: 0.3352984938281715, score: 10
# Scores: (min: 10, avg: 16.733333333333334, max: 25)
#
# Run: 16, exploration: 0.28704309604425327, score: 32
# Scores: (min: 10, avg: 17.6875, max: 32)
#
# Run: 17, exploration: 0.2507092085103961, score: 28
# Scores: (min: 10, avg: 18.294117647058822, max: 32)
#
# Run: 18, exploration: 0.23965031961336, score: 10
# Scores: (min: 10, avg: 17.833333333333332, max: 32)
#
# Run: 19, exploration: 0.21142436319205632, score: 26
# Scores: (min: 10, avg: 18.263157894736842, max: 32)
#
# Run: 20, exploration: 0.19709615934585656, score: 15
# Scores: (min: 10, avg: 18.1, max: 32)
#
# Run: 21, exploration: 0.17214774642209296, score: 28
# Scores: (min: 10, avg: 18.571428571428573, max: 32)
#
# Run: 22, exploration: 0.14663577052834775, score: 33
# Scores: (min: 10, avg: 19.227272727272727, max: 33)
#
# Run: 23, exploration: 0.1313250884614265, score: 23
# Scores: (min: 10, avg: 19.391304347826086, max: 33)
#
# Run: 24, exploration: 0.10533270926593409, score: 45
# Scores: (min: 10, avg: 20.458333333333332, max: 45)
#
# Run: 25, exploration: 0.09199970504166631, score: 28
# Scores: (min: 10, avg: 20.76, max: 45)
#
# Run: 26, exploration: 0.08157186144027828, score: 25
# Scores: (min: 10, avg: 20.923076923076923, max: 45)
#
# Run: 27, exploration: 0.07196434741762824, score: 26
# Scores: (min: 10, avg: 21.11111111111111, max: 45)
#
# Run: 28, exploration: 0.06477420436570952, score: 22
# Scores: (min: 10, avg: 21.142857142857142, max: 45)
#
# Run: 29, exploration: 0.05462441922520914, score: 35
# Scores: (min: 10, avg: 21.620689655172413, max: 45)
#
# Run: 30, exploration: 0.048190768399801194, score: 26
# Scores: (min: 10, avg: 21.766666666666666, max: 45)
#
# Run: 31, exploration: 0.04125526245077418, score: 32
# Scores: (min: 10, avg: 22.096774193548388, max: 45)
#
# Run: 32, exploration: 0.03549537564593805, score: 31
# Scores: (min: 10, avg: 22.375, max: 45)
#
# Run: 33, exploration: 0.02948667236521416, score: 38
# Scores: (min: 10, avg: 22.848484848484848, max: 45)
#
# Run: 34, exploration: 0.026144461565619025, score: 25
# Scores: (min: 10, avg: 22.91176470588235, max: 45)
#
# Run: 35, exploration: 0.023888845163905856, score: 19
# Scores: (min: 10, avg: 22.8, max: 45)
#
# Run: 36, exploration: 0.021610099696926857, score: 21
# Scores: (min: 10, avg: 22.75, max: 45)
#
# Run: 37, exploration: 0.020044857891939702, score: 16
# Scores: (min: 10, avg: 22.56756756756757, max: 45)
#
# Run: 38, exploration: 0.017160047465104442, score: 32
# Scores: (min: 10, avg: 22.81578947368421, max: 45)
#
# Run: 39, exploration: 0.014912990653247866, score: 29
# Scores: (min: 10, avg: 22.974358974358974, max: 45)
#
# Run: 40, exploration: 0.011150733307840981, score: 59
# Scores: (min: 10, avg: 23.875, max: 59)
#
# Run: 41, exploration: 0.010137759008060509, score: 20
# Scores: (min: 10, avg: 23.78048780487805, max: 59)
#
# Run: 42, exploration: 0.01, score: 18
# Scores: (min: 10, avg: 23.642857142857142, max: 59)
#
# Run: 43, exploration: 0.01, score: 31
# Scores: (min: 10, avg: 23.813953488372093, max: 59)
#
# Run: 44, exploration: 0.01, score: 21
# Scores: (min: 10, avg: 23.75, max: 59)
#
# Run: 45, exploration: 0.01, score: 22
# Scores: (min: 10, avg: 23.711111111111112, max: 59)
#
# Run: 46, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 23.391304347826086, max: 59)
#
# Run: 47, exploration: 0.01, score: 21
# Scores: (min: 9, avg: 23.340425531914892, max: 59)
#
# Run: 48, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 23.145833333333332, max: 59)
#
# Run: 49, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 23.040816326530614, max: 59)
#
# Run: 50, exploration: 0.01, score: 32
# Scores: (min: 9, avg: 23.22, max: 59)
#
# Run: 51, exploration: 0.01, score: 24
# Scores: (min: 9, avg: 23.235294117647058, max: 59)
#
# Run: 52, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 23.057692307692307, max: 59)
#
# Run: 53, exploration: 0.01, score: 22
# Scores: (min: 9, avg: 23.037735849056602, max: 59)
#
# Run: 54, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 22.98148148148148, max: 59)
#
# Run: 55, exploration: 0.01, score: 22
# Scores: (min: 9, avg: 22.963636363636365, max: 59)
#
# Run: 56, exploration: 0.01, score: 28
# Scores: (min: 9, avg: 23.053571428571427, max: 59)
#
# Run: 57, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 23, max: 59)
#
# Run: 58, exploration: 0.01, score: 24
# Scores: (min: 9, avg: 23.017241379310345, max: 59)
#
# Run: 59, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 22.796610169491526, max: 59)
#
# Run: 60, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 22.75, max: 59)
#
# Run: 61, exploration: 0.01, score: 23
# Scores: (min: 9, avg: 22.75409836065574, max: 59)
#
# Run: 62, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 22.548387096774192, max: 59)
#
# Run: 63, exploration: 0.01, score: 29
# Scores: (min: 9, avg: 22.650793650793652, max: 59)
#
# Run: 64, exploration: 0.01, score: 23
# Scores: (min: 9, avg: 22.65625, max: 59)
#
# Run: 65, exploration: 0.01, score: 23
# Scores: (min: 9, avg: 22.661538461538463, max: 59)
#
# Run: 66, exploration: 0.01, score: 24
# Scores: (min: 9, avg: 22.681818181818183, max: 59)
#
# Run: 67, exploration: 0.01, score: 24
# Scores: (min: 9, avg: 22.70149253731343, max: 59)
#
# Run: 68, exploration: 0.01, score: 32
# Scores: (min: 9, avg: 22.83823529411765, max: 59)
#
# Run: 69, exploration: 0.01, score: 28
# Scores: (min: 9, avg: 22.91304347826087, max: 59)
#
# Run: 70, exploration: 0.01, score: 25
# Scores: (min: 9, avg: 22.942857142857143, max: 59)
#
# Run: 71, exploration: 0.01, score: 21
# Scores: (min: 9, avg: 22.91549295774648, max: 59)
#
# Run: 72, exploration: 0.01, score: 23
# Scores: (min: 9, avg: 22.916666666666668, max: 59)
#
# Run: 73, exploration: 0.01, score: 27
# Scores: (min: 9, avg: 22.972602739726028, max: 59)
#
# Run: 74, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 22.93243243243243, max: 59)
#
# Run: 75, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 22.893333333333334, max: 59)
#
# Run: 76, exploration: 0.01, score: 21
# Scores: (min: 9, avg: 22.86842105263158, max: 59)
#
# Run: 77, exploration: 0.01, score: 29
# Scores: (min: 9, avg: 22.948051948051948, max: 59)
#
# Run: 78, exploration: 0.01, score: 43
# Scores: (min: 9, avg: 23.205128205128204, max: 59)
#
# Run: 79, exploration: 0.01, score: 25
# Scores: (min: 9, avg: 23.227848101265824, max: 59)
#
# Run: 80, exploration: 0.01, score: 25
# Scores: (min: 9, avg: 23.25, max: 59)
#
# Run: 81, exploration: 0.01, score: 37
# Scores: (min: 9, avg: 23.419753086419753, max: 59)
#
# Run: 82, exploration: 0.01, score: 25
# Scores: (min: 9, avg: 23.4390243902439, max: 59)
#
# Run: 83, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 23.265060240963855, max: 59)
#
# Run: 84, exploration: 0.01, score: 32
# Scores: (min: 9, avg: 23.36904761904762, max: 59)
#
# Run: 85, exploration: 0.01, score: 21
# Scores: (min: 9, avg: 23.341176470588234, max: 59)
#
# Run: 86, exploration: 0.01, score: 32
# Scores: (min: 9, avg: 23.441860465116278, max: 59)
#
# Run: 87, exploration: 0.01, score: 25
# Scores: (min: 9, avg: 23.45977011494253, max: 59)
#
# Run: 88, exploration: 0.01, score: 26
# Scores: (min: 9, avg: 23.488636363636363, max: 59)
# Run: 89, exploration: 0.01, score: 68
# Scores: (min: 9, avg: 23.98876404494382, max: 68)
#
# Run: 90, exploration: 0.01, score: 32
# Scores: (min: 9, avg: 24.07777777777778, max: 68)
#
# Run: 91, exploration: 0.01, score: 40
# Scores: (min: 9, avg: 24.252747252747252, max: 68)
#
# Run: 92, exploration: 0.01, score: 29
# Scores: (min: 9, avg: 24.304347826086957, max: 68)
#
# Run: 93, exploration: 0.01, score: 30
# Scores: (min: 9, avg: 24.365591397849464, max: 68)
#
# Run: 94, exploration: 0.01, score: 34
# Scores: (min: 9, avg: 24.46808510638298, max: 68)
#
# Run: 95, exploration: 0.01, score: 60
# Scores: (min: 9, avg: 24.842105263157894, max: 68)
#
# Run: 96, exploration: 0.01, score: 31
# Scores: (min: 9, avg: 24.90625, max: 68)
#
# Run: 97, exploration: 0.01, score: 35
# Scores: (min: 9, avg: 25.010309278350515, max: 68)
#
# Run: 98, exploration: 0.01, score: 26
# Scores: (min: 9, avg: 25.020408163265305, max: 68)
#
# Run: 99, exploration: 0.01, score: 34
# Scores: (min: 9, avg: 25.11111111111111, max: 68)
#
# Run: 100, exploration: 0.01, score: 25
# Scores: (min: 9, avg: 25.11, max: 68)
#
# Run: 101, exploration: 0.01, score: 39
# Scores: (min: 9, avg: 25.37, max: 68)
#
# Run: 102, exploration: 0.01, score: 52
# Scores: (min: 9, avg: 25.72, max: 68)
#
# Run: 103, exploration: 0.01, score: 30
# Scores: (min: 9, avg: 25.85, max: 68)
#
# Run: 104, exploration: 0.01, score: 34
# Scores: (min: 9, avg: 25.97, max: 68)
#
# Run: 105, exploration: 0.01, score: 33
# Scores: (min: 9, avg: 26.07, max: 68)
#
# Run: 106, exploration: 0.01, score: 47
# Scores: (min: 9, avg: 26.31, max: 68)
#
# Run: 107, exploration: 0.01, score: 26
# Scores: (min: 9, avg: 26.42, max: 68)
#
# Run: 108, exploration: 0.01, score: 26
# Scores: (min: 9, avg: 26.49, max: 68)
#
# Run: 109, exploration: 0.01, score: 22
# Scores: (min: 9, avg: 26.46, max: 68)
#
# Run: 110, exploration: 0.01, score: 39
# Scores: (min: 9, avg: 26.72, max: 68)
#
# Run: 111, exploration: 0.01, score: 48
# Scores: (min: 9, avg: 27.05, max: 68)
#
# Run: 112, exploration: 0.01, score: 43
# Scores: (min: 9, avg: 27.38, max: 68)
#
# Run: 113, exploration: 0.01, score: 39
# Scores: (min: 9, avg: 27.61, max: 68)
#
# Run: 114, exploration: 0.01, score: 48
# Scores: (min: 9, avg: 27.96, max: 68)
#
# Run: 115, exploration: 0.01, score: 23
# Scores: (min: 9, avg: 28.09, max: 68)
#
# Run: 116, exploration: 0.01, score: 58
# Scores: (min: 9, avg: 28.35, max: 68)
#
# Run: 117, exploration: 0.01, score: 32
# Scores: (min: 9, avg: 28.39, max: 68)
#
# Run: 118, exploration: 0.01, score: 41
# Scores: (min: 9, avg: 28.7, max: 68)
#
# Run: 119, exploration: 0.01, score: 34
# Scores: (min: 9, avg: 28.78, max: 68)
#
# Run: 120, exploration: 0.01, score: 47
# Scores: (min: 9, avg: 29.1, max: 68)
#
# Run: 121, exploration: 0.01, score: 33
# Scores: (min: 9, avg: 29.15, max: 68)
#
# Run: 122, exploration: 0.01, score: 40
# Scores: (min: 9, avg: 29.22, max: 68)
#
# Run: 123, exploration: 0.01, score: 36
# Scores: (min: 9, avg: 29.35, max: 68)
#
# Run: 124, exploration: 0.01, score: 32
# Scores: (min: 9, avg: 29.22, max: 68)
#
# Run: 125, exploration: 0.01, score: 39
# Scores: (min: 9, avg: 29.33, max: 68)
#
# Run: 126, exploration: 0.01, score: 33
# Scores: (min: 9, avg: 29.41, max: 68)
#
# Run: 127, exploration: 0.01, score: 34
# Scores: (min: 9, avg: 29.49, max: 68)
#
# Run: 128, exploration: 0.01, score: 58
# Scores: (min: 9, avg: 29.85, max: 68)
#
# Run: 129, exploration: 0.01, score: 37
# Scores: (min: 9, avg: 29.87, max: 68)
#
# Run: 130, exploration: 0.01, score: 40
# Scores: (min: 9, avg: 30.01, max: 68)
#
# Run: 131, exploration: 0.01, score: 34
# Scores: (min: 9, avg: 30.03, max: 68)
#
# Run: 132, exploration: 0.01, score: 39
# Scores: (min: 9, avg: 30.11, max: 68)
#
# Run: 133, exploration: 0.01, score: 55
# Scores: (min: 9, avg: 30.28, max: 68)
#
# Run: 134, exploration: 0.01, score: 32
# Scores: (min: 9, avg: 30.35, max: 68)
#
# Run: 135, exploration: 0.01, score: 44
# Scores: (min: 9, avg: 30.6, max: 68)
#
# Run: 136, exploration: 0.01, score: 77
# Scores: (min: 9, avg: 31.16, max: 77)
#
# Run: 137, exploration: 0.01, score: 55
# Scores: (min: 9, avg: 31.55, max: 77)
#
# Run: 138, exploration: 0.01, score: 62
# Scores: (min: 9, avg: 31.85, max: 77)
#
# Run: 139, exploration: 0.01, score: 32
# Scores: (min: 9, avg: 31.88, max: 77)
#
# Run: 140, exploration: 0.01, score: 72
# Scores: (min: 9, avg: 32.01, max: 77)
#
# Run: 141, exploration: 0.01, score: 51
# Scores: (min: 9, avg: 32.32, max: 77)
#
# Run: 142, exploration: 0.01, score: 45
# Scores: (min: 9, avg: 32.59, max: 77)
#
# Run: 143, exploration: 0.01, score: 94
# Scores: (min: 9, avg: 33.22, max: 94)
#
# Run: 144, exploration: 0.01, score: 59
# Scores: (min: 9, avg: 33.6, max: 94)
#
# Run: 145, exploration: 0.01, score: 95
# Scores: (min: 9, avg: 34.33, max: 95)
#
# Run: 146, exploration: 0.01, score: 59
# Scores: (min: 9, avg: 34.83, max: 95)
#
# Run: 147, exploration: 0.01, score: 86
# Scores: (min: 9, avg: 35.48, max: 95)
#
# Run: 148, exploration: 0.01, score: 26
# Scores: (min: 9, avg: 35.6, max: 95)
#
# Run: 149, exploration: 0.01, score: 43
# Scores: (min: 9, avg: 35.85, max: 95)
#
# Run: 150, exploration: 0.01, score: 30
# Scores: (min: 9, avg: 35.83, max: 95)
#
# Run: 151, exploration: 0.01, score: 30
# Scores: (min: 9, avg: 35.89, max: 95)
#
# Run: 152, exploration: 0.01, score: 72
# Scores: (min: 9, avg: 36.47, max: 95)
#
# Run: 153, exploration: 0.01, score: 31
# Scores: (min: 9, avg: 36.56, max: 95)
#
# Run: 154, exploration: 0.01, score: 36
# Scores: (min: 9, avg: 36.72, max: 95)
#
# Run: 155, exploration: 0.01, score: 77
# Scores: (min: 9, avg: 37.27, max: 95)
#
# Run: 156, exploration: 0.01, score: 93
# Scores: (min: 9, avg: 37.92, max: 95)
#
# Run: 157, exploration: 0.01, score: 91
# Scores: (min: 9, avg: 38.63, max: 95)
#
# Run: 158, exploration: 0.01, score: 81
# Scores: (min: 9, avg: 39.2, max: 95)
#
# Run: 159, exploration: 0.01, score: 89
# Scores: (min: 9, avg: 39.99, max: 95)
#
# Run: 160, exploration: 0.01, score: 81
# Scores: (min: 9, avg: 40.6, max: 95)
#
# Run: 161, exploration: 0.01, score: 55
# Scores: (min: 9, avg: 40.92, max: 95)
#
# Run: 162, exploration: 0.01, score: 82
# Scores: (min: 9, avg: 41.64, max: 95)
#
# Run: 163, exploration: 0.01, score: 58
# Scores: (min: 9, avg: 41.93, max: 95)
#
# Run: 164, exploration: 0.01, score: 73
# Scores: (min: 9, avg: 42.43, max: 95)
#
# Run: 165, exploration: 0.01, score: 109
# Scores: (min: 9, avg: 43.29, max: 109)
#
# Run: 166, exploration: 0.01, score: 73
# Scores: (min: 9, avg: 43.78, max: 109)
#
# Run: 167, exploration: 0.01, score: 25
# Scores: (min: 9, avg: 43.79, max: 109)
#
# Run: 168, exploration: 0.01, score: 86
# Scores: (min: 9, avg: 44.33, max: 109)
#
# Run: 169, exploration: 0.01, score: 76
# Scores: (min: 9, avg: 44.81, max: 109)
#
# Run: 170, exploration: 0.01, score: 64
# Scores: (min: 9, avg: 45.2, max: 109)
#
# Run: 171, exploration: 0.01, score: 94
# Scores: (min: 9, avg: 45.93, max: 109)
#
# Run: 172, exploration: 0.01, score: 79
# Scores: (min: 9, avg: 46.49, max: 109)
#
# Run: 173, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 46.36, max: 109)
#
# Run: 174, exploration: 0.01, score: 54
# Scores: (min: 9, avg: 46.7, max: 109)
#
# Run: 175, exploration: 0.01, score: 74
# Scores: (min: 9, avg: 47.24, max: 109)
#
# Run: 176, exploration: 0.01, score: 65
# Scores: (min: 9, avg: 47.68, max: 109)
#
# Run: 177, exploration: 0.01, score: 40
# Scores: (min: 9, avg: 47.79, max: 109)
#
# Run: 178, exploration: 0.01, score: 70
# Scores: (min: 9, avg: 48.06, max: 109)
#
# Run: 179, exploration: 0.01, score: 74
# Scores: (min: 9, avg: 48.55, max: 109)
#
# Run: 180, exploration: 0.01, score: 63
# Scores: (min: 9, avg: 48.93, max: 109)
#
# Run: 181, exploration: 0.01, score: 83
# Scores: (min: 9, avg: 49.39, max: 109)
#
# Run: 182, exploration: 0.01, score: 136
# Scores: (min: 9, avg: 50.5, max: 136)
#
# Run: 183, exploration: 0.01, score: 63
# Scores: (min: 14, avg: 51.04, max: 136)
#
# Run: 184, exploration: 0.01, score: 75
# Scores: (min: 14, avg: 51.47, max: 136)
#
# Run: 185, exploration: 0.01, score: 108
# Scores: (min: 14, avg: 52.34, max: 136)
#
# Run: 186, exploration: 0.01, score: 86
# Scores: (min: 14, avg: 52.88, max: 136)
#
# Run: 187, exploration: 0.01, score: 107
# Scores: (min: 14, avg: 53.7, max: 136)
#
# Run: 188, exploration: 0.01, score: 50
# Scores: (min: 14, avg: 53.94, max: 136)
#
# Run: 189, exploration: 0.01, score: 78
# Scores: (min: 14, avg: 54.04, max: 136)
#
# Run: 190, exploration: 0.01, score: 68
# Scores: (min: 14, avg: 54.4, max: 136)
#
# Run: 191, exploration: 0.01, score: 69
# Scores: (min: 14, avg: 54.69, max: 136)
#
# Run: 192, exploration: 0.01, score: 62
# Scores: (min: 14, avg: 55.02, max: 136)
# Run: 193, exploration: 0.01, score: 11
# Scores: (min: 11, avg: 54.83, max: 136)
#
# Run: 194, exploration: 0.01, score: 17
# Scores: (min: 11, avg: 54.66, max: 136)
#
# Run: 195, exploration: 0.01, score: 59
# Scores: (min: 11, avg: 54.65, max: 136)
#
# Run: 196, exploration: 0.01, score: 85
# Scores: (min: 11, avg: 55.19, max: 136)
#
# Run: 197, exploration: 0.01, score: 70
# Scores: (min: 11, avg: 55.54, max: 136)
#
# Run: 198, exploration: 0.01, score: 51
# Scores: (min: 11, avg: 55.79, max: 136)
#
# Run: 199, exploration: 0.01, score: 71
# Scores: (min: 11, avg: 56.16, max: 136)
#
# Run: 200, exploration: 0.01, score: 38
# Scores: (min: 11, avg: 56.29, max: 136)
#
# Run: 201, exploration: 0.01, score: 79
# Scores: (min: 11, avg: 56.69, max: 136)
#
# Run: 202, exploration: 0.01, score: 76
# Scores: (min: 11, avg: 56.93, max: 136)
#
# Run: 203, exploration: 0.01, score: 38
# Scores: (min: 11, avg: 57.01, max: 136)
#
# Run: 204, exploration: 0.01, score: 60
# Scores: (min: 11, avg: 57.27, max: 136)
#
# Run: 205, exploration: 0.01, score: 119
# Scores: (min: 11, avg: 58.13, max: 136)
#
# Run: 206, exploration: 0.01, score: 88
# Scores: (min: 11, avg: 58.54, max: 136)
#
# Run: 207, exploration: 0.01, score: 95
# Scores: (min: 11, avg: 59.23, max: 136)
#
# Run: 208, exploration: 0.01, score: 13
# Scores: (min: 11, avg: 59.1, max: 136)
#
# Run: 209, exploration: 0.01, score: 63
# Scores: (min: 11, avg: 59.51, max: 136)
#
# Run: 210, exploration: 0.01, score: 58
# Scores: (min: 11, avg: 59.7, max: 136)
#
# Run: 211, exploration: 0.01, score: 69
# Scores: (min: 11, avg: 59.91, max: 136)
#
# Run: 212, exploration: 0.01, score: 136
# Scores: (min: 11, avg: 60.84, max: 136)
#
# Run: 213, exploration: 0.01, score: 73
# Scores: (min: 11, avg: 61.18, max: 136)
#
# Run: 214, exploration: 0.01, score: 23
# Scores: (min: 11, avg: 60.93, max: 136)
#
# Run: 215, exploration: 0.01, score: 64
# Scores: (min: 11, avg: 61.34, max: 136)
#
# Run: 216, exploration: 0.01, score: 113
# Scores: (min: 11, avg: 61.89, max: 136)
#
# Run: 217, exploration: 0.01, score: 66
# Scores: (min: 11, avg: 62.23, max: 136)
#
# Run: 218, exploration: 0.01, score: 164
# Scores: (min: 11, avg: 63.46, max: 164)
#
# Run: 219, exploration: 0.01, score: 71
# Scores: (min: 11, avg: 63.83, max: 164)
#
# Run: 220, exploration: 0.01, score: 74
# Scores: (min: 11, avg: 64.1, max: 164)
#
# Run: 221, exploration: 0.01, score: 101
# Scores: (min: 11, avg: 64.78, max: 164)
#
# Run: 222, exploration: 0.01, score: 97
# Scores: (min: 11, avg: 65.35, max: 164)
#
# Run: 223, exploration: 0.01, score: 174
# Scores: (min: 11, avg: 66.73, max: 174)
#
# Run: 224, exploration: 0.01, score: 134
# Scores: (min: 11, avg: 67.75, max: 174)
#
# Run: 225, exploration: 0.01, score: 80
# Scores: (min: 11, avg: 68.16, max: 174)
#
# Run: 226, exploration: 0.01, score: 130
# Scores: (min: 11, avg: 69.13, max: 174)
#
# Run: 227, exploration: 0.01, score: 227
# Scores: (min: 11, avg: 71.06, max: 227)
#
# Run: 228, exploration: 0.01, score: 117
# Scores: (min: 11, avg: 71.65, max: 227)
#
# Run: 229, exploration: 0.01, score: 115
# Scores: (min: 11, avg: 72.43, max: 227)
#
# Run: 230, exploration: 0.01, score: 82
# Scores: (min: 11, avg: 72.85, max: 227)
#
# Run: 231, exploration: 0.01, score: 151
# Scores: (min: 11, avg: 74.02, max: 227)
#
# Run: 232, exploration: 0.01, score: 156
# Scores: (min: 11, avg: 75.19, max: 227)
#
# Run: 233, exploration: 0.01, score: 133
# Scores: (min: 11, avg: 75.97, max: 227)
#
# Run: 234, exploration: 0.01, score: 126
# Scores: (min: 11, avg: 76.91, max: 227)
#
# Run: 235, exploration: 0.01, score: 204
# Scores: (min: 11, avg: 78.51, max: 227)
#
# Run: 236, exploration: 0.01, score: 99
# Scores: (min: 11, avg: 78.73, max: 227)
#
# Run: 237, exploration: 0.01, score: 106
# Scores: (min: 11, avg: 79.24, max: 227)
#
# Run: 238, exploration: 0.01, score: 65
# Scores: (min: 11, avg: 79.27, max: 227)
#
# Run: 239, exploration: 0.01, score: 257
# Scores: (min: 11, avg: 81.52, max: 257)
#
# Run: 240, exploration: 0.01, score: 412
# Scores: (min: 11, avg: 84.92, max: 412)
#
# Run: 241, exploration: 0.01, score: 209
# Scores: (min: 11, avg: 86.5, max: 412)
#
# Run: 242, exploration: 0.01, score: 35
# Scores: (min: 11, avg: 86.4, max: 412)
#
# Run: 243, exploration: 0.01, score: 257
# Scores: (min: 11, avg: 88.03, max: 412)
#
# Run: 244, exploration: 0.01, score: 167
# Scores: (min: 11, avg: 89.11, max: 412)
#
# Run: 245, exploration: 0.01, score: 184
# Scores: (min: 11, avg: 90, max: 412)
#
# Run: 246, exploration: 0.01, score: 288
# Scores: (min: 11, avg: 92.29, max: 412)
#
# Run: 247, exploration: 0.01, score: 61
# Scores: (min: 11, avg: 92.04, max: 412)
#
# Run: 248, exploration: 0.01, score: 131
# Scores: (min: 11, avg: 93.09, max: 412)
#
# Run: 249, exploration: 0.01, score: 193
# Scores: (min: 11, avg: 94.59, max: 412)
#
# Run: 250, exploration: 0.01, score: 112
# Scores: (min: 11, avg: 95.41, max: 412)
#
# Run: 251, exploration: 0.01, score: 101
# Scores: (min: 11, avg: 96.12, max: 412)
#
# Run: 252, exploration: 0.01, score: 108
# Scores: (min: 11, avg: 96.48, max: 412)
#
# Run: 253, exploration: 0.01, score: 87
# Scores: (min: 11, avg: 97.04, max: 412)
#
# Run: 254, exploration: 0.01, score: 147
# Scores: (min: 11, avg: 98.15, max: 412)
#
# Run: 255, exploration: 0.01, score: 93
# Scores: (min: 11, avg: 98.31, max: 412)
#
# Run: 256, exploration: 0.01, score: 102
# Scores: (min: 11, avg: 98.4, max: 412)
#
# Run: 257, exploration: 0.01, score: 161
# Scores: (min: 11, avg: 99.1, max: 412)
#
# Run: 258, exploration: 0.01, score: 265
# Scores: (min: 11, avg: 100.94, max: 412)
#
# Run: 259, exploration: 0.01, score: 138
# Scores: (min: 11, avg: 101.43, max: 412)
#
# Run: 260, exploration: 0.01, score: 119
# Scores: (min: 11, avg: 101.81, max: 412)
#
# Run: 261, exploration: 0.01, score: 204
# Scores: (min: 11, avg: 103.3, max: 412)
#
# Run: 262, exploration: 0.01, score: 93
# Scores: (min: 11, avg: 103.41, max: 412)
#
# Run: 263, exploration: 0.01, score: 107
# Scores: (min: 11, avg: 103.9, max: 412)
#
# Run: 264, exploration: 0.01, score: 149
# Scores: (min: 11, avg: 104.66, max: 412)
#
# Run: 265, exploration: 0.01, score: 28
# Scores: (min: 11, avg: 103.85, max: 412)
#
# Run: 266, exploration: 0.01, score: 114
# Scores: (min: 11, avg: 104.26, max: 412)
#
# Run: 267, exploration: 0.01, score: 88
# Scores: (min: 11, avg: 104.89, max: 412)
#
# Run: 268, exploration: 0.01, score: 140
# Scores: (min: 11, avg: 105.43, max: 412)
#
# Run: 269, exploration: 0.01, score: 101
# Scores: (min: 11, avg: 105.68, max: 412)
#
# Run: 270, exploration: 0.01, score: 76
# Scores: (min: 11, avg: 105.8, max: 412)
#
# Run: 271, exploration: 0.01, score: 95
# Scores: (min: 11, avg: 105.81, max: 412)
#
# Run: 272, exploration: 0.01, score: 80
# Scores: (min: 11, avg: 105.82, max: 412)
#
# Run: 273, exploration: 0.01, score: 100
# Scores: (min: 11, avg: 106.68, max: 412)
#
# Run: 274, exploration: 0.01, score: 202
# Scores: (min: 11, avg: 108.16, max: 412)
#
# Run: 275, exploration: 0.01, score: 92
# Scores: (min: 11, avg: 108.34, max: 412)
#
# Run: 276, exploration: 0.01, score: 97
# Scores: (min: 11, avg: 108.66, max: 412)
#
# Run: 277, exploration: 0.01, score: 64
# Scores: (min: 11, avg: 108.9, max: 412)
#
# Run: 278, exploration: 0.01, score: 108
# Scores: (min: 11, avg: 109.28, max: 412)
#
# Run: 279, exploration: 0.01, score: 144
# Scores: (min: 11, avg: 109.98, max: 412)
#
# Run: 280, exploration: 0.01, score: 74
# Scores: (min: 11, avg: 110.09, max: 412)
#
# Run: 281, exploration: 0.01, score: 112
# Scores: (min: 11, avg: 110.38, max: 412)
#
# Run: 282, exploration: 0.01, score: 118
# Scores: (min: 11, avg: 110.2, max: 412)
#
# Run: 283, exploration: 0.01, score: 164
# Scores: (min: 11, avg: 111.21, max: 412)
#
# Run: 284, exploration: 0.01, score: 46
# Scores: (min: 11, avg: 110.92, max: 412)
#
# Run: 285, exploration: 0.01, score: 331
# Scores: (min: 11, avg: 113.15, max: 412)
#
# Run: 286, exploration: 0.01, score: 287
# Scores: (min: 11, avg: 115.16, max: 412)
#
# Run: 287, exploration: 0.01, score: 38
# Scores: (min: 11, avg: 114.47, max: 412)
#
# Run: 288, exploration: 0.01, score: 52
# Scores: (min: 11, avg: 114.49, max: 412)
#
# Run: 289, exploration: 0.01, score: 99
# Scores: (min: 11, avg: 114.7, max: 412)
#
# Run: 290, exploration: 0.01, score: 160
# Scores: (min: 11, avg: 115.62, max: 412)
#
# Run: 291, exploration: 0.01, score: 17
# Scores: (min: 11, avg: 115.1, max: 412)
#
# Run: 292, exploration: 0.01, score: 94
# Scores: (min: 11, avg: 115.42, max: 412)
#
# Run: 293, exploration: 0.01, score: 176
# Scores: (min: 13, avg: 117.07, max: 412)
#
# Run: 294, exploration: 0.01, score: 87
# Scores: (min: 13, avg: 117.77, max: 412)
# Run: 295, exploration: 0.01, score: 206
# Scores: (min: 13, avg: 119.24, max: 412)
#
# Run: 296, exploration: 0.01, score: 203
# Scores: (min: 13, avg: 120.42, max: 412)
#
# Run: 297, exploration: 0.01, score: 155
# Scores: (min: 13, avg: 121.27, max: 412)
#
# Run: 298, exploration: 0.01, score: 157
# Scores: (min: 13, avg: 122.33, max: 412)
#
# Run: 299, exploration: 0.01, score: 35
# Scores: (min: 13, avg: 121.97, max: 412)
#
# Run: 300, exploration: 0.01, score: 32
# Scores: (min: 13, avg: 121.91, max: 412)
#
# Run: 301, exploration: 0.01, score: 12
# Scores: (min: 12, avg: 121.24, max: 412)
#
# Run: 302, exploration: 0.01, score: 500
# Scores: (min: 12, avg: 125.48, max: 500)
#
# Run: 303, exploration: 0.01, score: 36
# Scores: (min: 12, avg: 125.46, max: 500)
#
# Run: 304, exploration: 0.01, score: 292
# Scores: (min: 12, avg: 127.78, max: 500)
#
# Run: 305, exploration: 0.01, score: 208
# Scores: (min: 12, avg: 128.67, max: 500)
#
# Run: 306, exploration: 0.01, score: 122
# Scores: (min: 12, avg: 129.01, max: 500)
#
# Run: 307, exploration: 0.01, score: 368
# Scores: (min: 12, avg: 131.74, max: 500)
#
# Run: 308, exploration: 0.01, score: 122
# Scores: (min: 12, avg: 132.83, max: 500)
#
# Run: 309, exploration: 0.01, score: 228
# Scores: (min: 12, avg: 134.48, max: 500)
#
# Run: 310, exploration: 0.01, score: 285
# Scores: (min: 12, avg: 136.75, max: 500)
#
# Run: 311, exploration: 0.01, score: 207
# Scores: (min: 12, avg: 138.13, max: 500)
#
# Run: 312, exploration: 0.01, score: 109
# Scores: (min: 12, avg: 137.86, max: 500)
#
# Run: 313, exploration: 0.01, score: 29
# Scores: (min: 12, avg: 137.42, max: 500)
#
# Run: 314, exploration: 0.01, score: 97
# Scores: (min: 12, avg: 138.16, max: 500)
#
# Run: 315, exploration: 0.01, score: 102
# Scores: (min: 12, avg: 138.54, max: 500)
#
# Run: 316, exploration: 0.01, score: 121
# Scores: (min: 12, avg: 138.62, max: 500)
#
# Run: 317, exploration: 0.01, score: 179
# Scores: (min: 12, avg: 139.75, max: 500)
#
# Run: 318, exploration: 0.01, score: 64
# Scores: (min: 12, avg: 138.75, max: 500)
#
# Run: 319, exploration: 0.01, score: 132
# Scores: (min: 12, avg: 139.36, max: 500)
#
# Run: 320, exploration: 0.01, score: 115
# Scores: (min: 12, avg: 139.77, max: 500)
#
# Run: 321, exploration: 0.01, score: 31
# Scores: (min: 12, avg: 139.07, max: 500)
#
# Run: 322, exploration: 0.01, score: 74
# Scores: (min: 12, avg: 138.84, max: 500)
#
# Run: 323, exploration: 0.01, score: 20
# Scores: (min: 12, avg: 137.3, max: 500)
#
# Run: 324, exploration: 0.01, score: 28
# Scores: (min: 12, avg: 136.24, max: 500)
#
# Run: 325, exploration: 0.01, score: 149
# Scores: (min: 12, avg: 136.93, max: 500)
#
# Run: 326, exploration: 0.01, score: 65
# Scores: (min: 12, avg: 136.28, max: 500)
#
# Run: 327, exploration: 0.01, score: 51
# Scores: (min: 12, avg: 134.52, max: 500)
#
# Run: 328, exploration: 0.01, score: 182
# Scores: (min: 12, avg: 135.17, max: 500)
#
# Run: 329, exploration: 0.01, score: 132
# Scores: (min: 12, avg: 135.34, max: 500)
#
# Run: 330, exploration: 0.01, score: 34
# Scores: (min: 12, avg: 134.86, max: 500)
#
# Run: 331, exploration: 0.01, score: 35
# Scores: (min: 12, avg: 133.7, max: 500)
#
# Run: 332, exploration: 0.01, score: 64
# Scores: (min: 12, avg: 132.78, max: 500)
#
# Run: 333, exploration: 0.01, score: 96
# Scores: (min: 12, avg: 132.41, max: 500)
#
# Run: 334, exploration: 0.01, score: 124
# Scores: (min: 12, avg: 132.39, max: 500)
#
# Run: 335, exploration: 0.01, score: 126
# Scores: (min: 12, avg: 131.61, max: 500)
#
# Run: 336, exploration: 0.01, score: 65
# Scores: (min: 12, avg: 131.27, max: 500)
#
# Run: 337, exploration: 0.01, score: 115
# Scores: (min: 12, avg: 131.36, max: 500)
#
# Run: 338, exploration: 0.01, score: 132
# Scores: (min: 12, avg: 132.03, max: 500)
#
# Run: 339, exploration: 0.01, score: 33
# Scores: (min: 12, avg: 129.79, max: 500)
#
# Run: 340, exploration: 0.01, score: 89
# Scores: (min: 12, avg: 126.56, max: 500)
#
# Run: 341, exploration: 0.01, score: 142
# Scores: (min: 12, avg: 125.89, max: 500)
#
# Run: 342, exploration: 0.01, score: 103
# Scores: (min: 12, avg: 126.57, max: 500)
#
# Run: 343, exploration: 0.01, score: 89
# Scores: (min: 12, avg: 124.89, max: 500)
#
# Run: 344, exploration: 0.01, score: 124
# Scores: (min: 12, avg: 124.46, max: 500)
#
# Run: 345, exploration: 0.01, score: 104
# Scores: (min: 12, avg: 123.66, max: 500)
#
# Run: 346, exploration: 0.01, score: 33
# Scores: (min: 12, avg: 121.11, max: 500)
#
# Run: 347, exploration: 0.01, score: 64
# Scores: (min: 12, avg: 121.14, max: 500)
#
# Run: 348, exploration: 0.01, score: 98
# Scores: (min: 12, avg: 120.81, max: 500)
#
# Run: 349, exploration: 0.01, score: 93
# Scores: (min: 12, avg: 119.81, max: 500)
#
# Run: 350, exploration: 0.01, score: 42
# Scores: (min: 12, avg: 119.11, max: 500)
#
# Run: 351, exploration: 0.01, score: 16
# Scores: (min: 12, avg: 118.26, max: 500)
#
# Run: 352, exploration: 0.01, score: 115
# Scores: (min: 12, avg: 118.33, max: 500)
#
# Run: 353, exploration: 0.01, score: 114
# Scores: (min: 12, avg: 118.6, max: 500)
#
# Run: 354, exploration: 0.01, score: 81
# Scores: (min: 12, avg: 117.94, max: 500)
#
# Run: 355, exploration: 0.01, score: 26
# Scores: (min: 12, avg: 117.27, max: 500)
#
# Run: 356, exploration: 0.01, score: 128
# Scores: (min: 12, avg: 117.53, max: 500)
#
# Run: 357, exploration: 0.01, score: 231
# Scores: (min: 12, avg: 118.23, max: 500)
#
# Run: 358, exploration: 0.01, score: 132
# Scores: (min: 12, avg: 116.9, max: 500)
#
# Run: 359, exploration: 0.01, score: 101
# Scores: (min: 12, avg: 116.53, max: 500)
#
# Run: 360, exploration: 0.01, score: 126
# Scores: (min: 12, avg: 116.6, max: 500)
#
# Run: 361, exploration: 0.01, score: 120
# Scores: (min: 12, avg: 115.76, max: 500)
#
# Run: 362, exploration: 0.01, score: 158
# Scores: (min: 12, avg: 116.41, max: 500)
#
# Run: 363, exploration: 0.01, score: 135
# Scores: (min: 12, avg: 116.69, max: 500)
#
# Run: 364, exploration: 0.01, score: 37
# Scores: (min: 12, avg: 115.57, max: 500)
#
# Run: 365, exploration: 0.01, score: 27
# Scores: (min: 12, avg: 115.56, max: 500)
#
# Run: 366, exploration: 0.01, score: 60
# Scores: (min: 12, avg: 115.02, max: 500)
#
# Run: 367, exploration: 0.01, score: 109
# Scores: (min: 12, avg: 115.23, max: 500)
#
# Run: 368, exploration: 0.01, score: 11
# Scores: (min: 11, avg: 113.94, max: 500)
#
# Run: 369, exploration: 0.01, score: 11
# Scores: (min: 11, avg: 113.04, max: 500)
#
# Run: 370, exploration: 0.01, score: 76
# Scores: (min: 11, avg: 113.04, max: 500)
#
# Run: 371, exploration: 0.01, score: 120
# Scores: (min: 11, avg: 113.29, max: 500)
#
# Run: 372, exploration: 0.01, score: 101
# Scores: (min: 11, avg: 113.5, max: 500)
#
# Run: 373, exploration: 0.01, score: 100
# Scores: (min: 11, avg: 113.5, max: 500)
#
# Run: 374, exploration: 0.01, score: 102
# Scores: (min: 11, avg: 112.5, max: 500)
#
# Run: 375, exploration: 0.01, score: 273
# Scores: (min: 11, avg: 114.31, max: 500)
#
# Run: 376, exploration: 0.01, score: 64
# Scores: (min: 11, avg: 113.98, max: 500)
#
# Run: 377, exploration: 0.01, score: 86
# Scores: (min: 11, avg: 114.2, max: 500)
#
# Run: 378, exploration: 0.01, score: 72
# Scores: (min: 11, avg: 113.84, max: 500)
#
# Run: 379, exploration: 0.01, score: 136
# Scores: (min: 11, avg: 113.76, max: 500)
#
# Run: 380, exploration: 0.01, score: 33
# Scores: (min: 11, avg: 113.35, max: 500)
#
# Run: 381, exploration: 0.01, score: 94
# Scores: (min: 11, avg: 113.17, max: 500)
#
# Run: 382, exploration: 0.01, score: 38
# Scores: (min: 11, avg: 112.37, max: 500)
#
# Run: 383, exploration: 0.01, score: 136
# Scores: (min: 11, avg: 112.09, max: 500)
#
# Run: 384, exploration: 0.01, score: 60
# Scores: (min: 11, avg: 112.23, max: 500)
#
# Run: 385, exploration: 0.01, score: 89
# Scores: (min: 11, avg: 109.81, max: 500)
#
# Run: 386, exploration: 0.01, score: 100
# Scores: (min: 11, avg: 107.94, max: 500)
#
# Run: 387, exploration: 0.01, score: 50
# Scores: (min: 11, avg: 108.06, max: 500)
#
# Run: 388, exploration: 0.01, score: 172
# Scores: (min: 11, avg: 109.26, max: 500)
#
# Run: 389, exploration: 0.01, score: 51
# Scores: (min: 11, avg: 108.78, max: 500)
#
# Run: 390, exploration: 0.01, score: 144
# Scores: (min: 11, avg: 108.62, max: 500)
#
# Run: 391, exploration: 0.01, score: 37
# Scores: (min: 11, avg: 108.82, max: 500)
#
# Run: 392, exploration: 0.01, score: 165
# Scores: (min: 11, avg: 109.53, max: 500)
#
# Run: 393, exploration: 0.01, score: 81
# Scores: (min: 11, avg: 108.58, max: 500)
#
# Run: 394, exploration: 0.01, score: 35
# Scores: (min: 11, avg: 108.06, max: 500)
#
# Run: 395, exploration: 0.01, score: 108
# Scores: (min: 11, avg: 107.08, max: 500)
# Run: 396, exploration: 0.01, score: 83
# Scores: (min: 11, avg: 105.88, max: 500)
#
# Run: 397, exploration: 0.01, score: 192
# Scores: (min: 11, avg: 106.25, max: 500)
#
# Run: 398, exploration: 0.01, score: 84
# Scores: (min: 11, avg: 105.52, max: 500)
#
# Run: 399, exploration: 0.01, score: 113
# Scores: (min: 11, avg: 106.3, max: 500)
#
# Run: 400, exploration: 0.01, score: 112
# Scores: (min: 11, avg: 107.1, max: 500)
#
# Run: 401, exploration: 0.01, score: 92
# Scores: (min: 11, avg: 107.9, max: 500)
#
# Run: 402, exploration: 0.01, score: 46
# Scores: (min: 11, avg: 103.36, max: 368)
#
# Run: 403, exploration: 0.01, score: 74
# Scores: (min: 11, avg: 103.74, max: 368)
#
# Run: 404, exploration: 0.01, score: 96
# Scores: (min: 11, avg: 101.78, max: 368)
#
# Run: 405, exploration: 0.01, score: 34
# Scores: (min: 11, avg: 100.04, max: 368)
#
# Run: 406, exploration: 0.01, score: 35
# Scores: (min: 11, avg: 99.17, max: 368)
#
# Run: 407, exploration: 0.01, score: 210
# Scores: (min: 11, avg: 97.59, max: 285)
#
# Run: 408, exploration: 0.01, score: 197
# Scores: (min: 11, avg: 98.34, max: 285)
#
# Run: 409, exploration: 0.01, score: 61
# Scores: (min: 11, avg: 96.67, max: 285)
#
# Run: 410, exploration: 0.01, score: 123
# Scores: (min: 11, avg: 95.05, max: 273)
#
# Run: 411, exploration: 0.01, score: 33
# Scores: (min: 11, avg: 93.31, max: 273)
#
# Run: 412, exploration: 0.01, score: 284
# Scores: (min: 11, avg: 95.06, max: 284)
#
# Run: 413, exploration: 0.01, score: 32
# Scores: (min: 11, avg: 95.09, max: 284)
#
# Run: 414, exploration: 0.01, score: 97
# Scores: (min: 11, avg: 95.09, max: 284)
#
# Run: 415, exploration: 0.01, score: 63
# Scores: (min: 11, avg: 94.7, max: 284)
#
# Run: 416, exploration: 0.01, score: 89
# Scores: (min: 11, avg: 94.38, max: 284)
#
# Run: 417, exploration: 0.01, score: 85
# Scores: (min: 11, avg: 93.44, max: 284)
#
# Run: 418, exploration: 0.01, score: 47
# Scores: (min: 11, avg: 93.27, max: 284)
#
# Run: 419, exploration: 0.01, score: 122
# Scores: (min: 11, avg: 93.17, max: 284)
#
# Run: 420, exploration: 0.01, score: 233
# Scores: (min: 11, avg: 94.35, max: 284)
#
# Run: 421, exploration: 0.01, score: 251
# Scores: (min: 11, avg: 96.55, max: 284)
#
# Run: 422, exploration: 0.01, score: 98
# Scores: (min: 11, avg: 96.79, max: 284)
#
# Run: 423, exploration: 0.01, score: 36
# Scores: (min: 11, avg: 96.95, max: 284)
#
# Run: 424, exploration: 0.01, score: 69
# Scores: (min: 11, avg: 97.36, max: 284)
#
# Run: 425, exploration: 0.01, score: 64
# Scores: (min: 11, avg: 96.51, max: 284)
#
# Run: 426, exploration: 0.01, score: 12
# Scores: (min: 11, avg: 95.98, max: 284)
#
# Run: 427, exploration: 0.01, score: 11
# Scores: (min: 11, avg: 95.58, max: 284)
#
# Run: 428, exploration: 0.01, score: 131
# Scores: (min: 11, avg: 95.07, max: 284)
#
# Run: 429, exploration: 0.01, score: 192
# Scores: (min: 11, avg: 95.67, max: 284)
#
# Run: 430, exploration: 0.01, score: 118
# Scores: (min: 11, avg: 96.51, max: 284)
#
# Run: 431, exploration: 0.01, score: 136
# Scores: (min: 11, avg: 97.52, max: 284)
#
# Run: 432, exploration: 0.01, score: 71
# Scores: (min: 11, avg: 97.59, max: 284)
#
# Run: 433, exploration: 0.01, score: 116
# Scores: (min: 11, avg: 97.79, max: 284)
#
# Run: 434, exploration: 0.01, score: 119
# Scores: (min: 11, avg: 97.74, max: 284)
#
# Run: 435, exploration: 0.01, score: 122
# Scores: (min: 11, avg: 97.7, max: 284)
#
# Run: 436, exploration: 0.01, score: 128
# Scores: (min: 11, avg: 98.33, max: 284)
#
# Run: 437, exploration: 0.01, score: 21
# Scores: (min: 11, avg: 97.39, max: 284)
#
# Run: 438, exploration: 0.01, score: 74
# Scores: (min: 11, avg: 96.81, max: 284)
#
# Run: 439, exploration: 0.01, score: 92
# Scores: (min: 11, avg: 97.4, max: 284)
#
# Run: 440, exploration: 0.01, score: 109
# Scores: (min: 11, avg: 97.6, max: 284)
#
# Run: 441, exploration: 0.01, score: 31
# Scores: (min: 11, avg: 96.49, max: 284)
#
# Run: 442, exploration: 0.01, score: 30
# Scores: (min: 11, avg: 95.76, max: 284)
#
# Run: 443, exploration: 0.01, score: 117
# Scores: (min: 11, avg: 96.04, max: 284)
#
# Run: 444, exploration: 0.01, score: 101
# Scores: (min: 11, avg: 95.81, max: 284)
#
# Run: 445, exploration: 0.01, score: 135
# Scores: (min: 11, avg: 96.12, max: 284)
#
# Run: 446, exploration: 0.01, score: 146
# Scores: (min: 11, avg: 97.25, max: 284)
#
# Run: 447, exploration: 0.01, score: 56
# Scores: (min: 11, avg: 97.17, max: 284)
#
# Run: 448, exploration: 0.01, score: 45
# Scores: (min: 11, avg: 96.64, max: 284)
#
# Run: 449, exploration: 0.01, score: 44
# Scores: (min: 11, avg: 96.15, max: 284)
#
# Run: 450, exploration: 0.01, score: 54
# Scores: (min: 11, avg: 96.27, max: 284)
#
# Run: 451, exploration: 0.01, score: 113
# Scores: (min: 11, avg: 97.24, max: 284)
#
# Run: 452, exploration: 0.01, score: 16
# Scores: (min: 11, avg: 96.25, max: 284)
#
# Run: 453, exploration: 0.01, score: 158
# Scores: (min: 11, avg: 96.69, max: 284)
#
# Run: 454, exploration: 0.01, score: 83
# Scores: (min: 11, avg: 96.71, max: 284)
#
# Run: 455, exploration: 0.01, score: 53
# Scores: (min: 11, avg: 96.98, max: 284)
#
# Run: 456, exploration: 0.01, score: 172
# Scores: (min: 11, avg: 97.42, max: 284)
#
# Run: 457, exploration: 0.01, score: 74
# Scores: (min: 11, avg: 95.85, max: 284)
#
# Run: 458, exploration: 0.01, score: 52
# Scores: (min: 11, avg: 95.05, max: 284)
#
# Run: 459, exploration: 0.01, score: 29
# Scores: (min: 11, avg: 94.33, max: 284)
#
# Run: 460, exploration: 0.01, score: 28
# Scores: (min: 11, avg: 93.35, max: 284)
#
# Run: 461, exploration: 0.01, score: 85
# Scores: (min: 11, avg: 93, max: 284)
#
# Run: 462, exploration: 0.01, score: 148
# Scores: (min: 11, avg: 92.9, max: 284)
#
# Run: 463, exploration: 0.01, score: 90
# Scores: (min: 11, avg: 92.45, max: 284)
#
# Run: 464, exploration: 0.01, score: 77
# Scores: (min: 11, avg: 92.85, max: 284)
#
# Run: 465, exploration: 0.01, score: 94
# Scores: (min: 11, avg: 93.52, max: 284)
#
# Run: 466, exploration: 0.01, score: 38
# Scores: (min: 11, avg: 93.3, max: 284)
#
# Run: 467, exploration: 0.01, score: 132
# Scores: (min: 11, avg: 93.53, max: 284)
#
# Run: 468, exploration: 0.01, score: 98
# Scores: (min: 11, avg: 94.4, max: 284)
#
# Run: 469, exploration: 0.01, score: 63
# Scores: (min: 11, avg: 94.92, max: 284)
#
# Run: 470, exploration: 0.01, score: 72
# Scores: (min: 11, avg: 94.88, max: 284)
#
# Run: 471, exploration: 0.01, score: 52
# Scores: (min: 11, avg: 94.2, max: 284)
#
# Run: 472, exploration: 0.01, score: 15
# Scores: (min: 11, avg: 93.34, max: 284)
#
# Run: 473, exploration: 0.01, score: 48
# Scores: (min: 11, avg: 92.82, max: 284)
#
# Run: 474, exploration: 0.01, score: 42
# Scores: (min: 11, avg: 92.22, max: 284)
#
# Run: 475, exploration: 0.01, score: 24
# Scores: (min: 11, avg: 89.73, max: 284)
#
# Run: 476, exploration: 0.01, score: 44
# Scores: (min: 11, avg: 89.53, max: 284)
#
# Run: 477, exploration: 0.01, score: 107
# Scores: (min: 11, avg: 89.74, max: 284)
#
# Run: 478, exploration: 0.01, score: 155
# Scores: (min: 11, avg: 90.57, max: 284)
#
# Run: 479, exploration: 0.01, score: 105
# Scores: (min: 11, avg: 90.26, max: 284)
#
# Run: 480, exploration: 0.01, score: 74
# Scores: (min: 11, avg: 90.67, max: 284)
#
# Run: 481, exploration: 0.01, score: 41
# Scores: (min: 11, avg: 90.14, max: 284)
#
# Run: 482, exploration: 0.01, score: 90
# Scores: (min: 11, avg: 90.66, max: 284)
#
# Run: 483, exploration: 0.01, score: 182
# Scores: (min: 11, avg: 91.12, max: 284)
#
# Run: 484, exploration: 0.01, score: 32
# Scores: (min: 11, avg: 90.84, max: 284)
#
# Run: 485, exploration: 0.01, score: 13
# Scores: (min: 11, avg: 90.08, max: 284)
#
# Run: 486, exploration: 0.01, score: 31
# Scores: (min: 11, avg: 89.39, max: 284)
#
# Run: 487, exploration: 0.01, score: 77
# Scores: (min: 11, avg: 89.66, max: 284)
#
# Run: 488, exploration: 0.01, score: 71
# Scores: (min: 11, avg: 88.65, max: 284)
#
# Run: 489, exploration: 0.01, score: 12
# Scores: (min: 11, avg: 88.26, max: 284)
#
# Run: 490, exploration: 0.01, score: 103
# Scores: (min: 11, avg: 87.85, max: 284)
#
# Run: 491, exploration: 0.01, score: 36
# Scores: (min: 11, avg: 87.84, max: 284)
#
# Run: 492, exploration: 0.01, score: 73
# Scores: (min: 11, avg: 86.92, max: 284)
#
# Run: 493, exploration: 0.01, score: 113
# Scores: (min: 11, avg: 87.24, max: 284)
#
# Run: 494, exploration: 0.01, score: 39
# Scores: (min: 11, avg: 87.28, max: 284)
#
# Run: 495, exploration: 0.01, score: 18
# Scores: (min: 11, avg: 86.38, max: 284)
#
# Run: 496, exploration: 0.01, score: 11
# Scores: (min: 11, avg: 85.66, max: 284)
#
# Run: 497, exploration: 0.01, score: 63
# Scores: (min: 11, avg: 84.37, max: 284)
#
# Run: 498, exploration: 0.01, score: 41
# Scores: (min: 11, avg: 83.94, max: 284)
# Run: 499, exploration: 0.01, score: 291
# Scores: (min: 11, avg: 85.72, max: 291)
#
# Run: 500, exploration: 0.01, score: 92
# Scores: (min: 11, avg: 85.52, max: 291)
#
# Run: 501, exploration: 0.01, score: 41
# Scores: (min: 11, avg: 85.01, max: 291)
#
# Run: 502, exploration: 0.01, score: 51
# Scores: (min: 11, avg: 85.06, max: 291)
#
# Run: 503, exploration: 0.01, score: 197
# Scores: (min: 11, avg: 86.29, max: 291)
#
# Run: 504, exploration: 0.01, score: 33
# Scores: (min: 11, avg: 85.66, max: 291)
#
# Run: 505, exploration: 0.01, score: 237
# Scores: (min: 11, avg: 87.69, max: 291)
#
# Run: 506, exploration: 0.01, score: 58
# Scores: (min: 11, avg: 87.92, max: 291)
#
# Run: 507, exploration: 0.01, score: 99
# Scores: (min: 11, avg: 86.81, max: 291)
#
# Run: 508, exploration: 0.01, score: 18
# Scores: (min: 11, avg: 85.02, max: 291)
#
# Run: 509, exploration: 0.01, score: 19
# Scores: (min: 11, avg: 84.6, max: 291)
#
# Run: 510, exploration: 0.01, score: 25
# Scores: (min: 11, avg: 83.62, max: 291)
#
# Run: 511, exploration: 0.01, score: 66
# Scores: (min: 11, avg: 83.95, max: 291)
#
# Run: 512, exploration: 0.01, score: 70
# Scores: (min: 11, avg: 81.81, max: 291)
#
# Run: 513, exploration: 0.01, score: 86
# Scores: (min: 11, avg: 82.35, max: 291)
#
# Run: 514, exploration: 0.01, score: 374
# Scores: (min: 11, avg: 85.12, max: 374)
#
# Run: 515, exploration: 0.01, score: 11
# Scores: (min: 11, avg: 84.6, max: 374)
#
# Run: 516, exploration: 0.01, score: 195
# Scores: (min: 11, avg: 85.66, max: 374)
#
# Run: 517, exploration: 0.01, score: 203
# Scores: (min: 11, avg: 86.84, max: 374)
#
# Run: 518, exploration: 0.01, score: 58
# Scores: (min: 11, avg: 86.95, max: 374)
#
# Run: 519, exploration: 0.01, score: 33
# Scores: (min: 11, avg: 86.06, max: 374)
#
# Run: 520, exploration: 0.01, score: 58
# Scores: (min: 11, avg: 84.31, max: 374)
#
# Run: 521, exploration: 0.01, score: 12
# Scores: (min: 11, avg: 81.92, max: 374)
#
# Run: 522, exploration: 0.01, score: 28
# Scores: (min: 11, avg: 81.22, max: 374)
#
# Run: 523, exploration: 0.01, score: 130
# Scores: (min: 11, avg: 82.16, max: 374)
#
# Run: 524, exploration: 0.01, score: 31
# Scores: (min: 11, avg: 81.78, max: 374)
#
# Run: 525, exploration: 0.01, score: 74
# Scores: (min: 11, avg: 81.88, max: 374)
#
# Run: 526, exploration: 0.01, score: 27
# Scores: (min: 11, avg: 82.03, max: 374)
#
# Run: 527, exploration: 0.01, score: 132
# Scores: (min: 11, avg: 83.24, max: 374)
#
# Run: 528, exploration: 0.01, score: 121
# Scores: (min: 11, avg: 83.14, max: 374)
#
# Run: 529, exploration: 0.01, score: 90
# Scores: (min: 11, avg: 82.12, max: 374)
#
# Run: 530, exploration: 0.01, score: 33
# Scores: (min: 11, avg: 81.27, max: 374)
#
# Run: 531, exploration: 0.01, score: 19
# Scores: (min: 11, avg: 80.1, max: 374)
#
# Run: 532, exploration: 0.01, score: 70
# Scores: (min: 11, avg: 80.09, max: 374)
#
# Run: 533, exploration: 0.01, score: 100
# Scores: (min: 11, avg: 79.93, max: 374)
#
# Run: 534, exploration: 0.01, score: 56
# Scores: (min: 11, avg: 79.3, max: 374)
#
# Run: 535, exploration: 0.01, score: 60
# Scores: (min: 11, avg: 78.68, max: 374)
#
# Run: 536, exploration: 0.01, score: 19
# Scores: (min: 11, avg: 77.59, max: 374)
#
# Run: 537, exploration: 0.01, score: 42
# Scores: (min: 11, avg: 77.8, max: 374)
#
# Run: 538, exploration: 0.01, score: 138
# Scores: (min: 11, avg: 78.44, max: 374)
#
# Run: 539, exploration: 0.01, score: 94
# Scores: (min: 11, avg: 78.46, max: 374)
#
# Run: 540, exploration: 0.01, score: 119
# Scores: (min: 11, avg: 78.56, max: 374)
#
# Run: 541, exploration: 0.01, score: 53
# Scores: (min: 11, avg: 78.78, max: 374)
#
# Run: 542, exploration: 0.01, score: 149
# Scores: (min: 11, avg: 79.97, max: 374)
#
# Run: 543, exploration: 0.01, score: 45
# Scores: (min: 11, avg: 79.25, max: 374)
#
# Run: 544, exploration: 0.01, score: 33
# Scores: (min: 11, avg: 78.57, max: 374)
#
# Run: 545, exploration: 0.01, score: 124
# Scores: (min: 11, avg: 78.46, max: 374)
#
# Run: 546, exploration: 0.01, score: 12
# Scores: (min: 11, avg: 77.12, max: 374)
#
# Run: 547, exploration: 0.01, score: 107
# Scores: (min: 11, avg: 77.63, max: 374)
#
# Run: 548, exploration: 0.01, score: 91
# Scores: (min: 11, avg: 78.09, max: 374)
#
# Run: 549, exploration: 0.01, score: 152
# Scores: (min: 11, avg: 79.17, max: 374)
#
# Run: 550, exploration: 0.01, score: 84
# Scores: (min: 11, avg: 79.47, max: 374)
#
# Run: 551, exploration: 0.01, score: 212
# Scores: (min: 11, avg: 80.46, max: 374)
#
# Run: 552, exploration: 0.01, score: 22
# Scores: (min: 11, avg: 80.52, max: 374)
#
# Run: 553, exploration: 0.01, score: 98
# Scores: (min: 11, avg: 79.92, max: 374)
#
# Run: 554, exploration: 0.01, score: 126
# Scores: (min: 11, avg: 80.35, max: 374)
#
# Run: 555, exploration: 0.01, score: 59
# Scores: (min: 11, avg: 80.41, max: 374)
#
# Run: 556, exploration: 0.01, score: 115
# Scores: (min: 11, avg: 79.84, max: 374)
#
# Run: 557, exploration: 0.01, score: 19
# Scores: (min: 11, avg: 79.29, max: 374)
#
# Run: 558, exploration: 0.01, score: 43
# Scores: (min: 11, avg: 79.2, max: 374)
#
# Run: 559, exploration: 0.01, score: 23
# Scores: (min: 11, avg: 79.14, max: 374)
#
# Run: 560, exploration: 0.01, score: 25
# Scores: (min: 11, avg: 79.11, max: 374)
#
# Run: 561, exploration: 0.01, score: 52
# Scores: (min: 11, avg: 78.78, max: 374)
#
# Run: 562, exploration: 0.01, score: 155
# Scores: (min: 11, avg: 78.85, max: 374)
#
# Run: 563, exploration: 0.01, score: 137
# Scores: (min: 11, avg: 79.32, max: 374)
#
# Run: 564, exploration: 0.01, score: 88
# Scores: (min: 11, avg: 79.43, max: 374)
#
# Run: 565, exploration: 0.01, score: 432
# Scores: (min: 11, avg: 82.81, max: 432)
#
# Run: 566, exploration: 0.01, score: 129
# Scores: (min: 11, avg: 83.72, max: 432)
#
# Run: 567, exploration: 0.01, score: 58
# Scores: (min: 11, avg: 82.98, max: 432)
#
# Run: 568, exploration: 0.01, score: 36
# Scores: (min: 11, avg: 82.36, max: 432)
#
# Run: 569, exploration: 0.01, score: 98
# Scores: (min: 11, avg: 82.71, max: 432)
#
# Run: 570, exploration: 0.01, score: 42
# Scores: (min: 11, avg: 82.41, max: 432)
#
# Run: 571, exploration: 0.01, score: 75
# Scores: (min: 11, avg: 82.64, max: 432)
#
# Run: 572, exploration: 0.01, score: 29
# Scores: (min: 11, avg: 82.78, max: 432)
#
# Run: 573, exploration: 0.01, score: 152
# Scores: (min: 11, avg: 83.82, max: 432)
#
# Run: 574, exploration: 0.01, score: 12
# Scores: (min: 11, avg: 83.52, max: 432)
#
# Run: 575, exploration: 0.01, score: 33
# Scores: (min: 11, avg: 83.61, max: 432)
#
# Run: 576, exploration: 0.01, score: 36
# Scores: (min: 11, avg: 83.53, max: 432)
#
# Run: 577, exploration: 0.01, score: 71
# Scores: (min: 11, avg: 83.17, max: 432)
#
# Run: 578, exploration: 0.01, score: 41
# Scores: (min: 11, avg: 82.03, max: 432)
#
# Run: 579, exploration: 0.01, score: 62
# Scores: (min: 11, avg: 81.6, max: 432)
#
# Run: 580, exploration: 0.01, score: 38
# Scores: (min: 11, avg: 81.24, max: 432)
#
# Run: 581, exploration: 0.01, score: 132
# Scores: (min: 11, avg: 82.15, max: 432)
#
# Run: 582, exploration: 0.01, score: 14
# Scores: (min: 11, avg: 81.39, max: 432)
#
# ...
# Scores: (min: 12, avg: 79.8, max: 282)
#
# Run: 1389, exploration: 0.01, score: 144
# Scores: (min: 12, avg: 80.81, max: 282)
#
# Run: 1390, exploration: 0.01, score: 69
# Scores: (min: 12, avg: 81.22, max: 282)
#
# Run: 1391, exploration: 0.01, score: 101
# Scores: (min: 12, avg: 81.33, max: 282)
#
# Run: 1392, exploration: 0.01, score: 97
# Scores: (min: 12, avg: 82.17, max: 282)
#
# Run: 1393, exploration: 0.01, score: 29
# Scores: (min: 12, avg: 82.01, max: 282)
#
# Run: 1394, exploration: 0.01, score: 26
# Scores: (min: 12, avg: 81.87, max: 282)
#
# Run: 1395, exploration: 0.01, score: 95
# Scores: (min: 12, avg: 82.21, max: 282)
#
# Run: 1396, exploration: 0.01, score: 33
# Scores: (min: 12, avg: 81.17, max: 282)
#
# Run: 1397, exploration: 0.01, score: 115
# Scores: (min: 12, avg: 82.01, max: 282)
#
# Run: 1398, exploration: 0.01, score: 33
# Scores: (min: 12, avg: 81.49, max: 282)
#
# Run: 1399, exploration: 0.01, score: 206
# Scores: (min: 12, avg: 82.69, max: 282)
#
# Run: 1400, exploration: 0.01, score: 107
# Scores: (min: 12, avg: 82.01, max: 282)
#
# Run: 1401, exploration: 0.01, score: 69
# Scores: (min: 12, avg: 81.84, max: 282)
#
# Run: 1402, exploration: 0.01, score: 95
# Scores: (min: 12, avg: 81.65, max: 282)
#
# Run: 1403, exploration: 0.01, score: 31
# Scores: (min: 12, avg: 81.2, max: 282)
#
# Run: 1404, exploration: 0.01, score: 28
# Scores: (min: 12, avg: 80.96, max: 282)
#
# Run: 1405, exploration: 0.01, score: 72
# Scores: (min: 12, avg: 81.15, max: 282)
#
# Run: 1406, exploration: 0.01, score: 80
# Scores: (min: 12, avg: 79.97, max: 282)
#
# Run: 1407, exploration: 0.01, score: 44
# Scores: (min: 12, avg: 80.24, max: 282)
#
# Run: 1408, exploration: 0.01, score: 60
# Scores: (min: 12, avg: 80.31, max: 282)
#
# Run: 1409, exploration: 0.01, score: 70
# Scores: (min: 12, avg: 79.82, max: 282)
#
# Run: 1410, exploration: 0.01, score: 47
# Scores: (min: 12, avg: 79.36, max: 282)
#
# Run: 1411, exploration: 0.01, score: 102
# Scores: (min: 12, avg: 80.01, max: 282)
#
# Run: 1412, exploration: 0.01, score: 51
# Scores: (min: 12, avg: 78.16, max: 282)
#
# Run: 1413, exploration: 0.01, score: 107
# Scores: (min: 12, avg: 78.91, max: 282)
#
# Run: 1414, exploration: 0.01, score: 303
# Scores: (min: 12, avg: 80.67, max: 303)
#
# Run: 1415, exploration: 0.01, score: 90
# Scores: (min: 12, avg: 81.3, max: 303)
# Run: 1416, exploration: 0.01, score: 45
# Scores: (min: 12, avg: 81.57, max: 303)
#
# Run: 1417, exploration: 0.01, score: 84
# Scores: (min: 12, avg: 81.9, max: 303)
#
# Run: 1418, exploration: 0.01, score: 61
# Scores: (min: 12, avg: 82.11, max: 303)
#
# Run: 1419, exploration: 0.01, score: 74
# Scores: (min: 12, avg: 82.29, max: 303)
#
# Run: 1420, exploration: 0.01, score: 23
# Scores: (min: 12, avg: 81.58, max: 303)
#
# Run: 1421, exploration: 0.01, score: 69
# Scores: (min: 12, avg: 81.35, max: 303)
#
# Run: 1422, exploration: 0.01, score: 36
# Scores: (min: 12, avg: 81.59, max: 303)
#
# Run: 1423, exploration: 0.01, score: 91
# Scores: (min: 12, avg: 81.36, max: 303)
#
# Run: 1424, exploration: 0.01, score: 34
# Scores: (min: 12, avg: 80.91, max: 303)
#
# Run: 1425, exploration: 0.01, score: 108
# Scores: (min: 12, avg: 79.17, max: 303)
#
# Run: 1426, exploration: 0.01, score: 27
# Scores: (min: 12, avg: 78.73, max: 303)
#
# Run: 1427, exploration: 0.01, score: 39
# Scores: (min: 12, avg: 77.89, max: 303)
#
# Run: 1428, exploration: 0.01, score: 165
# Scores: (min: 12, avg: 79.2, max: 303)
#
# Run: 1429, exploration: 0.01, score: 42
# Scores: (min: 12, avg: 78.4, max: 303)
#
# Run: 1430, exploration: 0.01, score: 58
# Scores: (min: 12, avg: 78.55, max: 303)
#
# Run: 1431, exploration: 0.01, score: 28
# Scores: (min: 12, avg: 77.61, max: 303)
#
# Run: 1432, exploration: 0.01, score: 95
# Scores: (min: 12, avg: 78.29, max: 303)
#
# Run: 1433, exploration: 0.01, score: 79
# Scores: (min: 12, avg: 78.16, max: 303)
#
# Run: 1434, exploration: 0.01, score: 21
# Scores: (min: 12, avg: 77.95, max: 303)
#
# Run: 1435, exploration: 0.01, score: 12
# Scores: (min: 12, avg: 77.34, max: 303)
#
# Run: 1436, exploration: 0.01, score: 168
# Scores: (min: 12, avg: 77.58, max: 303)
#
# Run: 1437, exploration: 0.01, score: 62
# Scores: (min: 12, avg: 77.22, max: 303)
#
# Run: 1438, exploration: 0.01, score: 32
# Scores: (min: 12, avg: 76.59, max: 303)
#
# Run: 1439, exploration: 0.01, score: 46
# Scores: (min: 12, avg: 76.26, max: 303)
#
# Run: 1440, exploration: 0.01, score: 28
# Scores: (min: 12, avg: 75.71, max: 303)
#
# Run: 1441, exploration: 0.01, score: 135
# Scores: (min: 12, avg: 76.68, max: 303)
#
# Run: 1442, exploration: 0.01, score: 12
# Scores: (min: 12, avg: 76.4, max: 303)
#
# Run: 1443, exploration: 0.01, score: 109
# Scores: (min: 12, avg: 76.4, max: 303)
#
# Run: 1444, exploration: 0.01, score: 15
# Scores: (min: 12, avg: 75.83, max: 303)
#
# Run: 1445, exploration: 0.01, score: 26
# Scores: (min: 12, avg: 75.63, max: 303)
#
# Run: 1446, exploration: 0.01, score: 40
# Scores: (min: 12, avg: 75.45, max: 303)
#
# Run: 1447, exploration: 0.01, score: 32
# Scores: (min: 12, avg: 74.91, max: 303)
#
# Run: 1448, exploration: 0.01, score: 63
# Scores: (min: 12, avg: 74.4, max: 303)
#
# Run: 1449, exploration: 0.01, score: 51
# Scores: (min: 12, avg: 74.04, max: 303)
#
# Run: 1450, exploration: 0.01, score: 56
# Scores: (min: 12, avg: 74.09, max: 303)
#
# Run: 1451, exploration: 0.01, score: 27
# Scores: (min: 12, avg: 74.23, max: 303)
#
# Run: 1452, exploration: 0.01, score: 15
# Scores: (min: 12, avg: 73.3, max: 303)
#
# Run: 1453, exploration: 0.01, score: 220
# Scores: (min: 12, avg: 75.12, max: 303)
#
# Run: 1454, exploration: 0.01, score: 45
# Scores: (min: 12, avg: 74.68, max: 303)
#
# Run: 1455, exploration: 0.01, score: 290
# Scores: (min: 12, avg: 76.5, max: 303)
#
# Run: 1456, exploration: 0.01, score: 20
# Scores: (min: 12, avg: 74.55, max: 303)
#
# Run: 1457, exploration: 0.01, score: 105
# Scores: (min: 12, avg: 74.5, max: 303)
#
# Run: 1458, exploration: 0.01, score: 76
# Scores: (min: 12, avg: 75.13, max: 303)
#
# Run: 1459, exploration: 0.01, score: 69
# Scores: (min: 12, avg: 74.97, max: 303)
#
# Run: 1460, exploration: 0.01, score: 170
# Scores: (min: 12, avg: 75.12, max: 303)
#
# Run: 1461, exploration: 0.01, score: 36
# Scores: (min: 12, avg: 74.08, max: 303)
#
# Run: 1462, exploration: 0.01, score: 94
# Scores: (min: 12, avg: 73.67, max: 303)
#
# Run: 1463, exploration: 0.01, score: 78
# Scores: (min: 12, avg: 73.55, max: 303)
#
# Run: 1464, exploration: 0.01, score: 83
# Scores: (min: 12, avg: 73.76, max: 303)
#
# Run: 1465, exploration: 0.01, score: 36
# Scores: (min: 12, avg: 73.8, max: 303)
#
# Run: 1466, exploration: 0.01, score: 91
# Scores: (min: 12, avg: 73.85, max: 303)
#
# Run: 1467, exploration: 0.01, score: 93
# Scores: (min: 12, avg: 74.53, max: 303)
#
# Run: 1468, exploration: 0.01, score: 24
# Scores: (min: 12, avg: 73.75, max: 303)
#
# Run: 1469, exploration: 0.01, score: 30
# Scores: (min: 12, avg: 72.42, max: 303)
#
# Run: 1470, exploration: 0.01, score: 28
# Scores: (min: 12, avg: 72.4, max: 303)
#
# Run: 1471, exploration: 0.01, score: 95
# Scores: (min: 12, avg: 72.87, max: 303)
#
# Run: 1472, exploration: 0.01, score: 121
# Scores: (min: 12, avg: 73.87, max: 303)
#
# Run: 1473, exploration: 0.01, score: 38
# Scores: (min: 12, avg: 73.16, max: 303)
#
# Run: 1474, exploration: 0.01, score: 159
# Scores: (min: 12, avg: 73.89, max: 303)
#
# Run: 1475, exploration: 0.01, score: 107
# Scores: (min: 12, avg: 74.78, max: 303)
#
# Run: 1476, exploration: 0.01, score: 138
# Scores: (min: 12, avg: 75.78, max: 303)
#
# Run: 1477, exploration: 0.01, score: 109
# Scores: (min: 12, avg: 75.89, max: 303)
#
# Run: 1478, exploration: 0.01, score: 101
# Scores: (min: 12, avg: 76.49, max: 303)
#
# Run: 1479, exploration: 0.01, score: 85
# Scores: (min: 12, avg: 76.76, max: 303)
#
# Run: 1480, exploration: 0.01, score: 111
# Scores: (min: 12, avg: 77.46, max: 303)
#
# Run: 1481, exploration: 0.01, score: 68
# Scores: (min: 12, avg: 77.39, max: 303)
#
# Run: 1482, exploration: 0.01, score: 32
# Scores: (min: 12, avg: 75.56, max: 303)
#
# Run: 1483, exploration: 0.01, score: 89
# Scores: (min: 12, avg: 76.11, max: 303)
#
# Run: 1484, exploration: 0.01, score: 91
# Scores: (min: 12, avg: 76.9, max: 303)
#
# Run: 1485, exploration: 0.01, score: 45
# Scores: (min: 12, avg: 76.25, max: 303)
#
# Run: 1486, exploration: 0.01, score: 29
# Scores: (min: 12, avg: 75.57, max: 303)
#
# Run: 1487, exploration: 0.01, score: 93
# Scores: (min: 12, avg: 75.44, max: 303)
#
# Run: 1488, exploration: 0.01, score: 95
# Scores: (min: 12, avg: 76.06, max: 303)
#
# Run: 1489, exploration: 0.01, score: 161
# Scores: (min: 12, avg: 76.23, max: 303)
#
# Run: 1490, exploration: 0.01, score: 46
# Scores: (min: 12, avg: 76, max: 303)
#
# Run: 1491, exploration: 0.01, score: 98
# Scores: (min: 12, avg: 75.97, max: 303)
#
# Run: 1492, exploration: 0.01, score: 40
# Scores: (min: 12, avg: 75.4, max: 303)
#
# Run: 1493, exploration: 0.01, score: 84
# Scores: (min: 12, avg: 75.95, max: 303)
#
# Run: 1494, exploration: 0.01, score: 79
# Scores: (min: 12, avg: 76.48, max: 303)
#
# Run: 1495, exploration: 0.01, score: 105
# Scores: (min: 12, avg: 76.58, max: 303)
#
# Run: 1496, exploration: 0.01, score: 15
# Scores: (min: 12, avg: 76.4, max: 303)
#
# Run: 1497, exploration: 0.01, score: 71
# Scores: (min: 12, avg: 75.96, max: 303)
#
# Run: 1498, exploration: 0.01, score: 36
# Scores: (min: 12, avg: 75.99, max: 303)
#
# Run: 1499, exploration: 0.01, score: 156
# Scores: (min: 12, avg: 75.49, max: 303)
#
# Run: 1500, exploration: 0.01, score: 45
# Scores: (min: 12, avg: 74.87, max: 303)
#
# Run: 1501, exploration: 0.01, score: 68
# Scores: (min: 12, avg: 74.86, max: 303)
#
# Run: 1502, exploration: 0.01, score: 60
# Scores: (min: 12, avg: 74.51, max: 303)
#
# Run: 1503, exploration: 0.01, score: 33
# Scores: (min: 12, avg: 74.53, max: 303)
#
# Run: 1504, exploration: 0.01, score: 31
# Scores: (min: 12, avg: 74.56, max: 303)
#
# Run: 1505, exploration: 0.01, score: 80
# Scores: (min: 12, avg: 74.64, max: 303)
#
# Run: 1506, exploration: 0.01, score: 19
# Scores: (min: 12, avg: 74.03, max: 303)
#
# Run: 1507, exploration: 0.01, score: 24
# Scores: (min: 12, avg: 73.83, max: 303)
#
# Run: 1508, exploration: 0.01, score: 97
# Scores: (min: 12, avg: 74.2, max: 303)
#
# Run: 1509, exploration: 0.01, score: 99
# Scores: (min: 12, avg: 74.49, max: 303)
#
# Run: 1510, exploration: 0.01, score: 23
# Scores: (min: 12, avg: 74.25, max: 303)
#
# Run: 1511, exploration: 0.01, score: 85
# Scores: (min: 12, avg: 74.08, max: 303)
#
# Run: 1512, exploration: 0.01, score: 30
# Scores: (min: 12, avg: 73.87, max: 303)
#
# Run: 1513, exploration: 0.01, score: 73
# Scores: (min: 12, avg: 73.53, max: 303)
#
# Run: 1514, exploration: 0.01, score: 106
# Scores: (min: 12, avg: 71.56, max: 290)
#
# Run: 1515, exploration: 0.01, score: 41
# Scores: (min: 12, avg: 71.07, max: 290)
#
# Run: 1516, exploration: 0.01, score: 71
# Scores: (min: 12, avg: 71.33, max: 290)
#
# Run: 1517, exploration: 0.01, score: 145
# Scores: (min: 12, avg: 71.94, max: 290)
# Run: 1518, exploration: 0.01, score: 186
# Scores: (min: 12, avg: 73.19, max: 290)
#
# Run: 1519, exploration: 0.01, score: 94
# Scores: (min: 12, avg: 73.39, max: 290)
#
# Run: 1520, exploration: 0.01, score: 51
# Scores: (min: 12, avg: 73.67, max: 290)
#
# Run: 1521, exploration: 0.01, score: 130
# Scores: (min: 12, avg: 74.28, max: 290)
#
# Run: 1522, exploration: 0.01, score: 54
# Scores: (min: 12, avg: 74.46, max: 290)
#
# Run: 1523, exploration: 0.01, score: 52
# Scores: (min: 12, avg: 74.07, max: 290)
#
# Run: 1524, exploration: 0.01, score: 117
# Scores: (min: 12, avg: 74.9, max: 290)
#
# Run: 1525, exploration: 0.01, score: 156
# Scores: (min: 12, avg: 75.38, max: 290)
#
# Run: 1526, exploration: 0.01, score: 39
# Scores: (min: 12, avg: 75.5, max: 290)
#
# Run: 1527, exploration: 0.01, score: 27
# Scores: (min: 12, avg: 75.38, max: 290)
#
# Run: 1528, exploration: 0.01, score: 47
# Scores: (min: 12, avg: 74.2, max: 290)
#
# Run: 1529, exploration: 0.01, score: 96
# Scores: (min: 12, avg: 74.74, max: 290)
#
# Run: 1530, exploration: 0.01, score: 78
# Scores: (min: 12, avg: 74.94, max: 290)
#
# Run: 1531, exploration: 0.01, score: 164
# Scores: (min: 12, avg: 76.3, max: 290)
#
# Run: 1532, exploration: 0.01, score: 198
# Scores: (min: 12, avg: 77.33, max: 290)
#
# Run: 1533, exploration: 0.01, score: 83
# Scores: (min: 12, avg: 77.37, max: 290)
#
# Run: 1534, exploration: 0.01, score: 14
# Scores: (min: 12, avg: 77.3, max: 290)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-1-abb838182a1a> in cartpole()
#      88                 score_logger.add_score(step, run)
#      89                 break
# ---> 90             dqn_solver.experience_replay()
#      91
#
# <ipython-input-1-abb838182a1a> in experience_replay(self)
#      56             if not terminal:
#      57                 q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))
# ---> 58             q_values = self.model.predict(state)
#      59             q_values[0][action] = q_update
#      60             self.model.fit(state, q_values, verbose=0)
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1460                                             verbose=verbose,
#    1461                                             steps=steps,
# -> 1462                                             callbacks=callbacks)
#    1463
#    1464     def train_on_batch(self, x, y,
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps, callbacks)
#     322             batch_logs = {'batch': batch_index, 'size': len(batch_ids)}
#     323             callbacks._call_batch_hook('predict', 'begin', batch_index, batch_logs)
# --> 324             batch_outs = f(ins_batch)
#     325             batch_outs = to_list(batch_outs)
#     326             if batch_index == 0:
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\keras\backend.py in __call__(self, inputs)
#    3725         value = math_ops.cast(value, tensor.dtype)
#    3726       converted_inputs.append(value)
# -> 3727     outputs = self._graph_fn(*converted_inputs)
#    3728
#    3729     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in __call__(self, *args, **kwargs)
#    1549       TypeError: For invalid positional/keyword argument combinations.
#    1550     """
# -> 1551     return self._call_impl(args, kwargs)
#    1552
#    1553   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1589       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1590           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1591     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1592
#    1593   def _filtered_call(self, args, kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Analysis of the cartpole problem and code
# The agent of the "cartpole" problem is tasked with balancing a pole on it's center. It does this by moving a cart left or right (the only possible actions to take) and attempting to prevent the pole from moving either direction by more than 15 degrees. The cart is expected to stay within 2.4 units of center. If either threshold is broken, the agent has failed. Each time the agent takes an action it is given feedback from the environment in form of a reward (increase in score) and a change to the next state of the environment.
#
# To solve the cartpole problem we have employed the use of Deep Q-Learning. This learning style differs from standard Q-Learning in that a DQN uses a **Neural Network**. Where Q-Learning updates it's Q-values in the Q-table manually, the DQN uses the NN to approximate the values. With standard Q-learning the Q-value for all possible state-action pairs is manually placed in the Q-table, but with larger amounts of state-actions pairs (think thousands or even millions) this becomes infeasible. Instead, the NN is used to approximate the Q-values in the Q-table, and thus a DQN is created. The architecture of the NN is such that the states of the environment act as input while pairs of actions and Q-values are the outputs. The best possible action for the given state is represented by the output with the highest Q-value.
#
# In order to update the weights in the NN after each run, we use the `LEARNING_RATE` variable. Changing the LR will affect the rate of change in the weights within the model. A low learning rate typically results in more reliable training but slower optimization. Higher learning rates beget higher losses during training (see 'Modified Run 1' above). Since the goal is ultimately a decrease in loss over time, lower learning rates are preferred.
#
# To increase the long-term learning of the agent in the cartpole problem, Experience Replay is used within the DQN. To do this, a random sample of “experiences” is taken from the batch during each run (regulated by the `BATCH_SIZE` variable). These experiences are used to train the agent in small batches, which prevents the agent from having to train from scratch each time. This process also reduces correlation between subsequent actions, and ensures the generated Q-values are of highest quality. A discount factor (`GAMMA`) helps the agent perform better in the long-term. This is done by giving the agent a sort of “future-thinking” when considering it's actions (Wang, 2021). What this really translates to is giving the agent concern for distant future rewards as opposed to short-term rewards. An agent will consider the sum total of all future rewards forthcoming when evaluating its actions, if the gamma is equal to 1 (or very close to it); this keeps the agent “working” to always improve its own total score. A gamma of 0 will make an agent that is only concerned with actions that produce an immediate reward.

# %% [markdown]
# ### References
# * Beysolow, T. (2019). Chapter 3. In Applied Reinforcement Learning with python: With Openai Gym, tensorflow, and keras. essay, Apress.
#
# * Gulli, A., & Pal, S. (2017). Chapter 8: AI Game Playing. In Deep learning with keras: Implement neural networks with Keras on Theano and tensorflow (pp. 271–274). essay, Packt.
#
# * Gupta, A. (2022, May 13). Deep Q-learning. GeeksforGeeks. Retrieved September 23, 2022, from https://www.geeksforgeeks.org/deep-q-learning/
#
# * Surma, G. (2019, November 10). Cartpole - introduction to reinforcement learning (DQN - deep Q-learning). Medium. Retrieved September 23, 2022, from https://gsurma.medium.com/cartpole-introduction-to-reinforcement-learning-ed0eb5b58288
#
# * Surmenok, P. (2021, April 19). Estimating an optimal learning rate for a deep neural network. Medium. Retrieved September 23, 2022, from https://towardsdatascience.com/estimating-optimal-learning-rate-for-a-deep-neural-network-ce32f2556ce0
#
# * Wang, M. (2021, October 3). Deep Q-learning tutorial: Mindqn. Medium. Retrieved September 23, 2022, from https://towardsdatascience.com/deep-q-learning-tutorial-mindqn-2a4c855abffc
